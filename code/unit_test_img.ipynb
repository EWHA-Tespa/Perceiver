# %% [markdown]
# # Setting

# %%
import os
import glob
import random
import time
import torch
import torch.nn as nn
import torch.optim as optim
import pickle
import copy, math

import torch.nn.functional as F
from torch.nn.modules.utils import _pair
from torch.nn.parameter import Parameter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from collections import Counter
from sklearn.preprocessing import LabelEncoder

from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

import torchvision.transforms as T

from models.shared_perceiver import crop, patchify, get_patch_coords, ImageDataset, PerceiverBlock, Perceiver

# %%
def seed_everything(seed):
    torch.manual_seed(seed) #torch를 거치는 모든 난수들의 생성순서를 고정한다
    torch.cuda.manual_seed(seed) #cuda를 사용하는 메소드들의 난수시드는 따로 고정해줘야한다 
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True #딥러닝에 특화된 CuDNN의 난수시드도 고정 
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed) #numpy를 사용할 경우 고정
    random.seed(seed) #파이썬 자체 모듈 random 모듈의 시드 고정
seed_everything(42)

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# # Functions

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, epochs, device, scheduler=None):
    best_model = None 
    best_val_score = 0
    model.train()
    train_losses = []
    val_accuracies = []
    start = time.perf_counter()
    
    for epoch in range(epochs):
        total_loss = 0.0
        for images, labels in train_loader:
            # GPU로 옮기기
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        accuracy = evaluate_model(model, valid_loader, device=device, log_results=False)
        val_accuracies.append(accuracy)

        # Scheduler step 추가
        if scheduler:
            scheduler.step()

        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}, Val Accuracy: {accuracy:.2f}%")
        if accuracy > best_val_score:
            best_val_score = accuracy
            best_model_state = model.state_dict()  # 모델 상태 저장
            best_model = copy.deepcopy(model) 
            print(f"New best model found at epoch {epoch+1} with accuracy: {best_val_score:.2f}%")

    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Total Train time: {hour}h {min}m {sec}s")

    return train_losses, val_accuracies, best_model

def evaluate_model(model, data_loader, device, log_results=True):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        start = time.perf_counter()
        for images, labels in data_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        end = time.perf_counter()
        hour = (end-start) // 3600
        min = ((end-start) % 3600) // 60
        sec = (end-start) % 60
        print(f"Elapsed time on CPU: {hour}h {min}m {sec}s")

    accuracy = 100.0 * correct / total
    if log_results:
        print(f"Test Accuracy: {accuracy:.2f}%")
    return accuracy

# %% [markdown]
# # Load Model

# %%
data_dir = '/home/youlee/n24news/n24news/image'
crop_size = 0
patch_size = 16
batch_size = 32
epochs = 30
group_class = 3
LR = 1e-4

# %%
#random.shuffle(target_classes)
target_classes = [ # 임의로 순서지정
    "Opinion", "Art & Design", "Television",
    "Music", "Travel", "Real Estate",
    "Books", "Theater", "Health",
    "Sports", "Science", "Food",
    "Fashion & Style", "Movies", "Technology",
    "Dance", "Media", "Style"
]
target_classes
# Out:
# ['Opinion',
#  'Art & Design',
#  'Television',
#  'Music',
#  'Travel',
#  'Real Estate',
#  'Books',
#  'Theater',
#  'Health',
#  'Sports',
#  'Science',
#  'Food',
#  'Fashion & Style',
#  'Movies',
#  'Technology',
#  'Dance',
#  'Media',
#  'Style']

# %%
output_path = '/home/Minju/Perceiver/shared_layer_model'
loader_path = '/home/Minju/Perceiver/shared_layer_loader'
group_class
# Out:
# 3

# %% [markdown]
# # Train Loop

# %%
for i in range(0, len(target_classes), group_class):  
    print(f"실험 {i//group_class + 1} 시작")
    selected_classes = target_classes[i:i+group_class]
    print(f"Selected Feature: {selected_classes}")

    filtered_dataset = ImageDataset(root_dir=data_dir, 
                                    transform=transform, 
                                    crop_size=crop_size, 
                                    patch_size=patch_size,
                                    selected_classes=selected_classes)
    all_labels = [label_idx for (_, label_idx) in filtered_dataset.data]

    # 1) 유니크 라벨과 개수
    unique_label_ids = np.unique(all_labels)
    print("Unique numeric labels:", unique_label_ids)
    print("Number of unique numeric labels:", len(unique_label_ids))

    # 2) 라벨별 개수 (분포)
    label_counts = Counter(all_labels)
    print("Label distribution (index: count):", label_counts)
    
    train_ratio = 0.8
    train_size = int(len(filtered_dataset) * train_ratio)
    valid_size = len(filtered_dataset) - train_size

    train_dataset, valid_dataset = random_split(filtered_dataset, [train_size, valid_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

    print(f"train: {train_size}, valid: {valid_size}")
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    NUM_CLASSES = len(filtered_dataset.label_encoder.classes_)
    model = Perceiver(input_dim=(patch_size**2) * 3 + 2,
                        latent_dim=128, 
                        latent_size=64, 
                        num_classes=NUM_CLASSES, 
                        num_blocks=4, 
                        self_attn_layers_per_block=10).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)  # Learning rate decay 추가

    start = time.perf_counter()
    train_losses, val_accuracies, best_model = train_model(
        model, train_loader, valid_loader,
        criterion, optimizer, epochs,
        device=device,
        scheduler=scheduler  
    )
    
    final_acc = evaluate_model(best_model, valid_loader, device=device, log_results=True)
    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Train time: {hour}h {min}m {sec}s")
    print(f"Final Validation Accuracy: {final_acc:.2f}%")
    print("----------------------------------------------------------")
    
    torch.save(best_model, f'{output_path}/image_model_{i//group_class+1}.pkl')

    val_loader_save_path = f"{loader_path}/image_val_loader_{i//group_class+1}.pkl"
    with open(val_loader_save_path, 'wb') as f:
        pickle.dump(valid_dataset, f)
# Out:
# 실험 1 시작
# Selected Feature: ['Opinion', 'Art & Design', 'Television']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(1): 2437, np.int64(0): 2431, np.int64(2): 2419})
# train: 5829, valid: 1458
# Elapsed time on CPU: 0.0h 0.0m 13.537625045981258s
# Epoch 1/30, Loss: 1.0701, Val Accuracy: 41.77%
# New best model found at epoch 1 with accuracy: 41.77%
# Elapsed time on CPU: 0.0h 0.0m 8.766788154141977s
# Epoch 2/30, Loss: 1.0562, Val Accuracy: 42.87%
# New best model found at epoch 2 with accuracy: 42.87%
# Elapsed time on CPU: 0.0h 0.0m 8.94611339084804s
# Epoch 3/30, Loss: 1.0509, Val Accuracy: 42.94%
# New best model found at epoch 3 with accuracy: 42.94%
# Elapsed time on CPU: 0.0h 0.0m 8.801492888014764s
# Epoch 4/30, Loss: 1.0536, Val Accuracy: 42.73%
# Elapsed time on CPU: 0.0h 0.0m 8.950938659952953s
# Epoch 5/30, Loss: 1.0516, Val Accuracy: 42.11%
# Elapsed time on CPU: 0.0h 0.0m 8.866248819977045s
# Epoch 6/30, Loss: 1.0517, Val Accuracy: 43.14%
# New best model found at epoch 6 with accuracy: 43.14%
# Elapsed time on CPU: 0.0h 0.0m 9.741750900866464s
# Epoch 7/30, Loss: 1.0475, Val Accuracy: 41.70%
# Elapsed time on CPU: 0.0h 0.0m 9.03478795196861s
# Epoch 8/30, Loss: 1.0481, Val Accuracy: 42.59%
# Elapsed time on CPU: 0.0h 0.0m 8.759756915969774s
# Epoch 9/30, Loss: 1.0458, Val Accuracy: 42.25%
# Elapsed time on CPU: 0.0h 0.0m 9.255779915954918s
# Epoch 10/30, Loss: 1.0430, Val Accuracy: 41.63%
# Elapsed time on CPU: 0.0h 0.0m 9.039672068785876s
# Epoch 11/30, Loss: 1.0365, Val Accuracy: 40.81%
# Elapsed time on CPU: 0.0h 0.0m 9.079091290012002s
# Epoch 12/30, Loss: 1.0365, Val Accuracy: 42.39%
# Elapsed time on CPU: 0.0h 0.0m 8.943774515995756s
# Epoch 13/30, Loss: 1.0324, Val Accuracy: 42.32%
# Elapsed time on CPU: 0.0h 0.0m 9.09443051321432s
# Epoch 14/30, Loss: 1.0297, Val Accuracy: 41.29%
# Elapsed time on CPU: 0.0h 0.0m 9.06474038399756s
# Epoch 15/30, Loss: 1.0272, Val Accuracy: 42.18%
# Elapsed time on CPU: 0.0h 0.0m 9.139626801013947s
# Epoch 16/30, Loss: 1.0201, Val Accuracy: 43.76%
# New best model found at epoch 16 with accuracy: 43.76%
# Elapsed time on CPU: 0.0h 0.0m 8.814142445102334s
# Epoch 17/30, Loss: 1.0105, Val Accuracy: 46.23%
# New best model found at epoch 17 with accuracy: 46.23%
# Elapsed time on CPU: 0.0h 0.0m 8.903296304866672s
# Epoch 18/30, Loss: 0.9750, Val Accuracy: 60.91%
# New best model found at epoch 18 with accuracy: 60.91%
# Elapsed time on CPU: 0.0h 0.0m 9.158523097867146s
# Epoch 19/30, Loss: 0.8353, Val Accuracy: 62.96%
# New best model found at epoch 19 with accuracy: 62.96%
# Elapsed time on CPU: 0.0h 0.0m 9.197303516091779s
# Epoch 20/30, Loss: 0.8099, Val Accuracy: 63.51%
# New best model found at epoch 20 with accuracy: 63.51%
# Elapsed time on CPU: 0.0h 0.0m 8.800926882075146s
# Epoch 21/30, Loss: 0.8015, Val Accuracy: 63.44%
# Elapsed time on CPU: 0.0h 0.0m 9.03517521196045s
# Epoch 22/30, Loss: 0.7970, Val Accuracy: 63.72%
# New best model found at epoch 22 with accuracy: 63.72%
# Elapsed time on CPU: 0.0h 0.0m 9.502476905006915s
# Epoch 23/30, Loss: 0.7960, Val Accuracy: 63.72%
# Elapsed time on CPU: 0.0h 0.0m 8.778110570972785s
# Epoch 24/30, Loss: 0.7912, Val Accuracy: 64.33%
# New best model found at epoch 24 with accuracy: 64.33%
# Elapsed time on CPU: 0.0h 0.0m 8.788077221950516s
# Epoch 25/30, Loss: 0.7882, Val Accuracy: 63.99%
# Elapsed time on CPU: 0.0h 0.0m 8.734312938991934s
# Epoch 26/30, Loss: 0.7836, Val Accuracy: 64.88%
# New best model found at epoch 26 with accuracy: 64.88%
# Elapsed time on CPU: 0.0h 0.0m 9.040685523068532s
# Epoch 27/30, Loss: 0.7793, Val Accuracy: 65.02%
# New best model found at epoch 27 with accuracy: 65.02%
# Elapsed time on CPU: 0.0h 0.0m 9.046111097093672s
# Epoch 28/30, Loss: 0.7786, Val Accuracy: 65.50%
# New best model found at epoch 28 with accuracy: 65.50%
# Elapsed time on CPU: 0.0h 0.0m 9.024245409062132s
# Epoch 29/30, Loss: 0.7764, Val Accuracy: 65.43%
# Elapsed time on CPU: 0.0h 0.0m 8.730249535059556s
# Epoch 30/30, Loss: 0.7714, Val Accuracy: 65.50%
# Total Train time: 0.0h 29.0m 59s
# Elapsed time on CPU: 0.0h 0.0m 9.134539959952235s
# Test Accuracy: 65.50%
# Train time: 0.0h 30.0m 8s
# Final Validation Accuracy: 65.50%
# ----------------------------------------------------------
# 실험 2 시작
# Selected Feature: ['Music', 'Travel', 'Real Estate']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2416, np.int64(2): 2413, np.int64(1): 2413})
# train: 5793, valid: 1449
# Elapsed time on CPU: 0.0h 0.0m 13.158644610084593s
# Epoch 1/30, Loss: 1.0084, Val Accuracy: 48.86%
# New best model found at epoch 1 with accuracy: 48.86%
# Elapsed time on CPU: 0.0h 0.0m 8.538438561139628s
# Epoch 2/30, Loss: 0.9828, Val Accuracy: 49.76%
# New best model found at epoch 2 with accuracy: 49.76%
# Elapsed time on CPU: 0.0h 0.0m 8.378247812157497s
# Epoch 3/30, Loss: 0.9646, Val Accuracy: 42.17%
# Elapsed time on CPU: 0.0h 0.0m 8.009846565080807s
# Epoch 4/30, Loss: 0.9903, Val Accuracy: 48.10%
# Elapsed time on CPU: 0.0h 0.0m 8.263887092936784s
# Epoch 5/30, Loss: 0.9972, Val Accuracy: 46.17%
# Elapsed time on CPU: 0.0h 0.0m 8.003573186928406s
# Epoch 6/30, Loss: 0.9579, Val Accuracy: 49.00%
# Elapsed time on CPU: 0.0h 0.0m 8.276285181054845s
# Epoch 7/30, Loss: 0.9466, Val Accuracy: 49.69%
# Elapsed time on CPU: 0.0h 0.0m 8.283231334062293s
# Epoch 8/30, Loss: 0.9374, Val Accuracy: 49.55%
# Elapsed time on CPU: 0.0h 0.0m 8.25655929511413s
# Epoch 9/30, Loss: 0.9278, Val Accuracy: 50.38%
# New best model found at epoch 9 with accuracy: 50.38%
# Elapsed time on CPU: 0.0h 0.0m 8.51915061287582s
# Epoch 10/30, Loss: 0.9202, Val Accuracy: 52.04%
# New best model found at epoch 10 with accuracy: 52.04%
# Elapsed time on CPU: 0.0h 0.0m 8.509220174048096s
# Epoch 11/30, Loss: 0.9033, Val Accuracy: 51.21%
# Elapsed time on CPU: 0.0h 0.0m 8.619027443928644s
# Epoch 12/30, Loss: 0.8925, Val Accuracy: 51.35%
# Elapsed time on CPU: 0.0h 0.0m 8.5223151340615s
# Epoch 13/30, Loss: 0.8765, Val Accuracy: 56.18%
# New best model found at epoch 13 with accuracy: 56.18%
# Elapsed time on CPU: 0.0h 0.0m 8.512314903084189s
# Epoch 14/30, Loss: 0.8477, Val Accuracy: 57.35%
# New best model found at epoch 14 with accuracy: 57.35%
# Elapsed time on CPU: 0.0h 0.0m 8.252769405022264s
# Epoch 15/30, Loss: 0.8179, Val Accuracy: 58.52%
# New best model found at epoch 15 with accuracy: 58.52%
# Elapsed time on CPU: 0.0h 0.0m 8.220223664073274s
# Epoch 16/30, Loss: 0.7844, Val Accuracy: 62.53%
# New best model found at epoch 16 with accuracy: 62.53%
# Elapsed time on CPU: 0.0h 0.0m 8.502536614891142s
# Epoch 17/30, Loss: 0.7683, Val Accuracy: 63.29%
# New best model found at epoch 17 with accuracy: 63.29%
# Elapsed time on CPU: 0.0h 0.0m 8.217416642000899s
# Epoch 18/30, Loss: 0.7514, Val Accuracy: 64.04%
# New best model found at epoch 18 with accuracy: 64.04%
# Elapsed time on CPU: 0.0h 0.0m 8.467337484005839s
# Epoch 19/30, Loss: 0.7383, Val Accuracy: 63.91%
# Elapsed time on CPU: 0.0h 0.0m 8.482939461944625s
# Epoch 20/30, Loss: 0.7297, Val Accuracy: 64.11%
# New best model found at epoch 20 with accuracy: 64.11%
# Elapsed time on CPU: 0.0h 0.0m 8.528007548069581s
# Epoch 21/30, Loss: 0.7170, Val Accuracy: 65.91%
# New best model found at epoch 21 with accuracy: 65.91%
# Elapsed time on CPU: 0.0h 0.0m 8.242796187987551s
# Epoch 22/30, Loss: 0.7184, Val Accuracy: 63.63%
# Elapsed time on CPU: 0.0h 0.0m 8.261367409024388s
# Epoch 23/30, Loss: 0.7175, Val Accuracy: 66.32%
# New best model found at epoch 23 with accuracy: 66.32%
# Elapsed time on CPU: 0.0h 0.0m 8.259075317066163s
# Epoch 24/30, Loss: 0.7121, Val Accuracy: 65.49%
# Elapsed time on CPU: 0.0h 0.0m 8.498931455193087s
# Epoch 25/30, Loss: 0.7007, Val Accuracy: 65.42%
# Elapsed time on CPU: 0.0h 0.0m 8.528977889101952s
# Epoch 26/30, Loss: 0.6935, Val Accuracy: 66.46%
# New best model found at epoch 26 with accuracy: 66.46%
# Elapsed time on CPU: 0.0h 0.0m 8.502860250882804s
# Epoch 27/30, Loss: 0.6946, Val Accuracy: 66.74%
# New best model found at epoch 27 with accuracy: 66.74%
# Elapsed time on CPU: 0.0h 0.0m 8.513218856183812s
# Epoch 28/30, Loss: 0.6887, Val Accuracy: 66.25%
# Elapsed time on CPU: 0.0h 0.0m 8.314674969995394s
# Epoch 29/30, Loss: 0.6893, Val Accuracy: 66.80%
# New best model found at epoch 29 with accuracy: 66.80%
# Elapsed time on CPU: 0.0h 0.0m 8.473076371010393s
# Epoch 30/30, Loss: 0.6890, Val Accuracy: 66.87%
# New best model found at epoch 30 with accuracy: 66.87%
# Total Train time: 0.0h 28.0m 6s
# Elapsed time on CPU: 0.0h 0.0m 8.486006318824366s
# Test Accuracy: 66.87%
# Train time: 0.0h 28.0m 14s
# Final Validation Accuracy: 66.87%
# ----------------------------------------------------------
# 실험 3 시작
# Selected Feature: ['Books', 'Theater', 'Health']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2412, np.int64(1): 2409, np.int64(2): 2409})
# train: 5784, valid: 1446
# Elapsed time on CPU: 0.0h 0.0m 13.528693136991933s
# Epoch 1/30, Loss: 1.0196, Val Accuracy: 47.37%
# New best model found at epoch 1 with accuracy: 47.37%
# Elapsed time on CPU: 0.0h 0.0m 8.37067917897366s
# Epoch 2/30, Loss: 0.9998, Val Accuracy: 48.27%
# New best model found at epoch 2 with accuracy: 48.27%
# Elapsed time on CPU: 0.0h 0.0m 8.339423783123493s
# Epoch 3/30, Loss: 0.9825, Val Accuracy: 51.24%
# New best model found at epoch 3 with accuracy: 51.24%
# Elapsed time on CPU: 0.0h 0.0m 9.798381722066551s
# Epoch 4/30, Loss: 0.9660, Val Accuracy: 51.04%
# Elapsed time on CPU: 0.0h 0.0m 10.077209778828546s
# Epoch 5/30, Loss: 0.9639, Val Accuracy: 52.07%
# New best model found at epoch 5 with accuracy: 52.07%
# Elapsed time on CPU: 0.0h 0.0m 8.05041323788464s
# Epoch 6/30, Loss: 0.9337, Val Accuracy: 53.53%
# New best model found at epoch 6 with accuracy: 53.53%
# Elapsed time on CPU: 0.0h 0.0m 8.340022471966222s
# Epoch 7/30, Loss: 0.9241, Val Accuracy: 52.07%
# Elapsed time on CPU: 0.0h 0.0m 8.339714747155085s
# Epoch 8/30, Loss: 0.9134, Val Accuracy: 55.26%
# New best model found at epoch 8 with accuracy: 55.26%
# Elapsed time on CPU: 0.0h 0.0m 8.053684065118432s
# Epoch 9/30, Loss: 0.9143, Val Accuracy: 57.12%
# New best model found at epoch 9 with accuracy: 57.12%
# Elapsed time on CPU: 0.0h 0.0m 8.347145671956241s
# Epoch 10/30, Loss: 0.9085, Val Accuracy: 53.94%
# Elapsed time on CPU: 0.0h 0.0m 8.343905539950356s
# Epoch 11/30, Loss: 0.8941, Val Accuracy: 57.12%
# Elapsed time on CPU: 0.0h 0.0m 8.361422463087365s
# Epoch 12/30, Loss: 0.8868, Val Accuracy: 56.02%
# Elapsed time on CPU: 0.0h 0.0m 8.058021344942972s
# Epoch 13/30, Loss: 0.8788, Val Accuracy: 57.88%
# New best model found at epoch 13 with accuracy: 57.88%
# Elapsed time on CPU: 0.0h 0.0m 8.336690475931391s
# Epoch 14/30, Loss: 0.8731, Val Accuracy: 55.81%
# Elapsed time on CPU: 0.0h 0.0m 8.34653293993324s
# Epoch 15/30, Loss: 0.8665, Val Accuracy: 58.44%
# New best model found at epoch 15 with accuracy: 58.44%
# Elapsed time on CPU: 0.0h 0.0m 8.342986939009279s
# Epoch 16/30, Loss: 0.8554, Val Accuracy: 58.23%
# Elapsed time on CPU: 0.0h 0.0m 8.349467278225347s
# Epoch 17/30, Loss: 0.8508, Val Accuracy: 56.22%
# Elapsed time on CPU: 0.0h 0.0m 8.318558039842173s
# Epoch 18/30, Loss: 0.8486, Val Accuracy: 57.88%
# Elapsed time on CPU: 0.0h 0.0m 9.298157582059503s
# Epoch 19/30, Loss: 0.8434, Val Accuracy: 56.98%
# Elapsed time on CPU: 0.0h 0.0m 8.31591918412596s
# Epoch 20/30, Loss: 0.8410, Val Accuracy: 57.61%
# Elapsed time on CPU: 0.0h 0.0m 8.327149594202638s
# Epoch 21/30, Loss: 0.8332, Val Accuracy: 58.02%
# Elapsed time on CPU: 0.0h 0.0m 8.340124159120023s
# Epoch 22/30, Loss: 0.8314, Val Accuracy: 58.37%
# Elapsed time on CPU: 0.0h 0.0m 8.32643214915879s
# Epoch 23/30, Loss: 0.8276, Val Accuracy: 58.09%
# Elapsed time on CPU: 0.0h 0.0m 8.343541112961248s
# Epoch 24/30, Loss: 0.8249, Val Accuracy: 58.71%
# New best model found at epoch 24 with accuracy: 58.71%
# Elapsed time on CPU: 0.0h 0.0m 8.061101682018489s
# Epoch 25/30, Loss: 0.8239, Val Accuracy: 59.34%
# New best model found at epoch 25 with accuracy: 59.34%
# Elapsed time on CPU: 0.0h 0.0m 8.336868650978431s
# Epoch 26/30, Loss: 0.8185, Val Accuracy: 58.99%
# Elapsed time on CPU: 0.0h 0.0m 8.365492848912254s
# Epoch 27/30, Loss: 0.8179, Val Accuracy: 59.27%
# Elapsed time on CPU: 0.0h 0.0m 8.436942799948156s
# Epoch 28/30, Loss: 0.8161, Val Accuracy: 58.71%
# Elapsed time on CPU: 0.0h 0.0m 8.338127895025536s
# Epoch 29/30, Loss: 0.8149, Val Accuracy: 58.78%
# Elapsed time on CPU: 0.0h 0.0m 8.354639059863985s
# Epoch 30/30, Loss: 0.8129, Val Accuracy: 59.06%
# Total Train time: 0.0h 27.0m 55s
# Elapsed time on CPU: 0.0h 0.0m 8.408453331096098s
# Test Accuracy: 59.34%
# Train time: 0.0h 28.0m 4s
# Final Validation Accuracy: 59.34%
# ----------------------------------------------------------
# 실험 4 시작
# Selected Feature: ['Sports', 'Science', 'Food']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(2): 2407, np.int64(1): 2387, np.int64(0): 2385})
# train: 5743, valid: 1436
# Elapsed time on CPU: 0.0h 0.0m 13.856381047982723s
# Epoch 1/30, Loss: 1.0811, Val Accuracy: 42.83%
# New best model found at epoch 1 with accuracy: 42.83%
# Elapsed time on CPU: 0.0h 0.0m 8.442646828945726s
# Epoch 2/30, Loss: 1.0651, Val Accuracy: 45.54%
# New best model found at epoch 2 with accuracy: 45.54%
# Elapsed time on CPU: 0.0h 0.0m 8.745017152978107s
# Epoch 3/30, Loss: 1.0655, Val Accuracy: 44.29%
# Elapsed time on CPU: 0.0h 0.0m 8.75162399187684s
# Epoch 4/30, Loss: 1.0584, Val Accuracy: 44.15%
# Elapsed time on CPU: 0.0h 0.0m 8.795818342128769s
# Epoch 5/30, Loss: 1.0383, Val Accuracy: 47.21%
# New best model found at epoch 5 with accuracy: 47.21%
# Elapsed time on CPU: 0.0h 0.0m 8.466895207995549s
# Epoch 6/30, Loss: 1.0184, Val Accuracy: 48.33%
# New best model found at epoch 6 with accuracy: 48.33%
# Elapsed time on CPU: 0.0h 0.0m 8.766437860904261s
# Epoch 7/30, Loss: 1.0042, Val Accuracy: 48.75%
# New best model found at epoch 7 with accuracy: 48.75%
# Elapsed time on CPU: 0.0h 0.0m 9.061195238027722s
# Epoch 8/30, Loss: 0.9942, Val Accuracy: 51.88%
# New best model found at epoch 8 with accuracy: 51.88%
# Elapsed time on CPU: 0.0h 0.0m 8.744649672182277s
# Epoch 9/30, Loss: 0.9809, Val Accuracy: 52.37%
# New best model found at epoch 9 with accuracy: 52.37%
# Elapsed time on CPU: 0.0h 0.0m 8.42725082510151s
# Epoch 10/30, Loss: 0.9773, Val Accuracy: 49.30%
# Elapsed time on CPU: 0.0h 0.0m 8.42296524392441s
# Epoch 11/30, Loss: 0.9583, Val Accuracy: 52.37%
# Elapsed time on CPU: 0.0h 0.0m 8.430086699780077s
# Epoch 12/30, Loss: 0.9552, Val Accuracy: 52.58%
# New best model found at epoch 12 with accuracy: 52.58%
# Elapsed time on CPU: 0.0h 0.0m 8.459403177024797s
# Epoch 13/30, Loss: 0.9444, Val Accuracy: 53.76%
# New best model found at epoch 13 with accuracy: 53.76%
# Elapsed time on CPU: 0.0h 0.0m 8.74534135311842s
# Epoch 14/30, Loss: 0.9389, Val Accuracy: 54.25%
# New best model found at epoch 14 with accuracy: 54.25%
# Elapsed time on CPU: 0.0h 0.0m 8.526895834133029s
# Epoch 15/30, Loss: 0.9230, Val Accuracy: 54.81%
# New best model found at epoch 15 with accuracy: 54.81%
# Elapsed time on CPU: 0.0h 0.0m 8.714707188075408s
# Epoch 16/30, Loss: 0.9016, Val Accuracy: 54.94%
# New best model found at epoch 16 with accuracy: 54.94%
# Elapsed time on CPU: 0.0h 0.0m 8.782838797895238s
# Epoch 17/30, Loss: 0.8945, Val Accuracy: 57.80%
# New best model found at epoch 17 with accuracy: 57.80%
# Elapsed time on CPU: 0.0h 0.0m 8.423428939189762s
# Epoch 18/30, Loss: 0.8825, Val Accuracy: 58.29%
# New best model found at epoch 18 with accuracy: 58.29%
# Elapsed time on CPU: 0.0h 0.0m 8.763364458922297s
# Epoch 19/30, Loss: 0.8730, Val Accuracy: 58.57%
# New best model found at epoch 19 with accuracy: 58.57%
# Elapsed time on CPU: 0.0h 0.0m 8.74956501298584s
# Epoch 20/30, Loss: 0.8646, Val Accuracy: 58.77%
# New best model found at epoch 20 with accuracy: 58.77%
# Elapsed time on CPU: 0.0h 0.0m 8.474855417851359s
# Epoch 21/30, Loss: 0.8549, Val Accuracy: 60.03%
# New best model found at epoch 21 with accuracy: 60.03%
# Elapsed time on CPU: 0.0h 0.0m 8.942513613030314s
# Epoch 22/30, Loss: 0.8493, Val Accuracy: 59.40%
# Elapsed time on CPU: 0.0h 0.0m 8.590849824016914s
# Epoch 23/30, Loss: 0.8455, Val Accuracy: 59.40%
# Elapsed time on CPU: 0.0h 0.0m 8.576538501074538s
# Epoch 24/30, Loss: 0.8394, Val Accuracy: 59.82%
# Elapsed time on CPU: 0.0h 0.0m 8.572053116979077s
# Epoch 25/30, Loss: 0.8369, Val Accuracy: 61.00%
# New best model found at epoch 25 with accuracy: 61.00%
# Elapsed time on CPU: 0.0h 0.0m 8.776348656974733s
# Epoch 26/30, Loss: 0.8296, Val Accuracy: 61.63%
# New best model found at epoch 26 with accuracy: 61.63%
# Elapsed time on CPU: 0.0h 0.0m 8.79677252098918s
# Epoch 27/30, Loss: 0.8278, Val Accuracy: 60.65%
# Elapsed time on CPU: 0.0h 0.0m 8.983725988073274s
# Epoch 28/30, Loss: 0.8257, Val Accuracy: 61.42%
# Elapsed time on CPU: 0.0h 0.0m 8.729576456127688s
# Epoch 29/30, Loss: 0.8241, Val Accuracy: 61.28%
# Elapsed time on CPU: 0.0h 0.0m 8.751505929976702s
# Epoch 30/30, Loss: 0.8222, Val Accuracy: 61.21%
# Total Train time: 0.0h 28.0m 34s
# Elapsed time on CPU: 0.0h 0.0m 8.807660446036607s
# Test Accuracy: 61.63%
# Train time: 0.0h 28.0m 43s
# Final Validation Accuracy: 61.63%
# ----------------------------------------------------------
# 실험 5 시작
# Selected Feature: ['Fashion & Style', 'Movies', 'Technology']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2385, np.int64(1): 2384, np.int64(2): 2376})
# train: 5716, valid: 1429
# Elapsed time on CPU: 0.0h 0.0m 13.395588044077158s
# Epoch 1/30, Loss: 1.0920, Val Accuracy: 38.00%
# New best model found at epoch 1 with accuracy: 38.00%
# Elapsed time on CPU: 0.0h 0.0m 8.006865964038298s
# Epoch 2/30, Loss: 1.0857, Val Accuracy: 41.71%
# New best model found at epoch 2 with accuracy: 41.71%
# Elapsed time on CPU: 0.0h 0.0m 8.289853076916188s
# Epoch 3/30, Loss: 1.0864, Val Accuracy: 39.96%
# Elapsed time on CPU: 0.0h 0.0m 8.290306010982022s
# Epoch 4/30, Loss: 1.0877, Val Accuracy: 38.07%
# Elapsed time on CPU: 0.0h 0.0m 8.319187853019685s
# Epoch 5/30, Loss: 1.1010, Val Accuracy: 33.66%
# Elapsed time on CPU: 0.0h 0.0m 8.296420437050983s
# Epoch 6/30, Loss: 1.0992, Val Accuracy: 33.66%
# Elapsed time on CPU: 0.0h 0.0m 8.282660475000739s
# Epoch 7/30, Loss: 1.0993, Val Accuracy: 33.38%
# Elapsed time on CPU: 0.0h 0.0m 8.288668100954965s
# Epoch 8/30, Loss: 1.0983, Val Accuracy: 38.07%
# Elapsed time on CPU: 0.0h 0.0m 8.291413633152843s
# Epoch 9/30, Loss: 1.0975, Val Accuracy: 33.66%
# Elapsed time on CPU: 0.0h 0.0m 8.276035795919597s
# Epoch 10/30, Loss: 1.0991, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.301315532065928s
# Epoch 11/30, Loss: 1.0990, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.295155718922615s
# Epoch 12/30, Loss: 1.0990, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.268126680981368s
# Epoch 13/30, Loss: 1.0990, Val Accuracy: 33.66%
# Elapsed time on CPU: 0.0h 0.0m 8.257023551035672s
# Epoch 14/30, Loss: 1.0990, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.28288474609144s
# Epoch 15/30, Loss: 1.0990, Val Accuracy: 33.38%
# Elapsed time on CPU: 0.0h 0.0m 8.269573278957978s
# Epoch 16/30, Loss: 1.0989, Val Accuracy: 33.66%
# Elapsed time on CPU: 0.0h 0.0m 8.74122362700291s
# Epoch 17/30, Loss: 1.0988, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.272915098117664s
# Epoch 18/30, Loss: 1.0988, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.252800256945193s
# Epoch 19/30, Loss: 1.0989, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.247487762011588s
# Epoch 20/30, Loss: 1.0988, Val Accuracy: 33.38%
# Elapsed time on CPU: 0.0h 0.0m 8.246844275156036s
# Epoch 21/30, Loss: 1.0987, Val Accuracy: 33.38%
# Elapsed time on CPU: 0.0h 0.0m 8.251293102977797s
# Epoch 22/30, Loss: 1.0987, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.262398303020746s
# Epoch 23/30, Loss: 1.0988, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.264592174906284s
# Epoch 24/30, Loss: 1.0987, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.467333341017365s
# Epoch 25/30, Loss: 1.0987, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.248180694878101s
# Epoch 26/30, Loss: 1.0987, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.252888234099373s
# Epoch 27/30, Loss: 1.0987, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.270078416913748s
# Epoch 28/30, Loss: 1.0987, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.291065444936976s
# Epoch 29/30, Loss: 1.0986, Val Accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 8.235607226146385s
# Epoch 30/30, Loss: 1.0987, Val Accuracy: 32.96%
# Total Train time: 0.0h 27.0m 57s
# Elapsed time on CPU: 0.0h 0.0m 8.280323982005939s
# Test Accuracy: 41.71%
# Train time: 0.0h 28.0m 6s
# Final Validation Accuracy: 41.71%
# ----------------------------------------------------------
# 실험 6 시작
# Selected Feature: ['Dance', 'Media', 'Style']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2365, np.int64(1): 2363, np.int64(2): 2147})
# train: 5500, valid: 1375
# Elapsed time on CPU: 0.0h 0.0m 11.475135665154085s
# Epoch 1/30, Loss: 1.0462, Val Accuracy: 47.35%
# New best model found at epoch 1 with accuracy: 47.35%
# Elapsed time on CPU: 0.0h 0.0m 7.5489435729105026s
# Epoch 2/30, Loss: 1.0242, Val Accuracy: 45.82%
# Elapsed time on CPU: 0.0h 0.0m 7.437690285034478s
# Epoch 3/30, Loss: 1.0537, Val Accuracy: 42.11%
# Elapsed time on CPU: 0.0h 0.0m 7.678706061094999s
# Epoch 4/30, Loss: 1.0762, Val Accuracy: 38.98%
# Elapsed time on CPU: 0.0h 0.0m 7.45394292101264s
# Epoch 5/30, Loss: 1.0794, Val Accuracy: 37.60%
# Elapsed time on CPU: 0.0h 0.0m 7.403725421987474s
# Epoch 6/30, Loss: 1.0860, Val Accuracy: 37.60%
# Elapsed time on CPU: 0.0h 0.0m 7.458755064988509s
# Epoch 7/30, Loss: 1.0863, Val Accuracy: 37.53%
# Elapsed time on CPU: 0.0h 0.0m 7.472160340053961s
# Epoch 8/30, Loss: 1.0860, Val Accuracy: 36.36%
# Elapsed time on CPU: 0.0h 0.0m 7.400353936944157s
# Epoch 9/30, Loss: 1.0971, Val Accuracy: 35.13%
# Elapsed time on CPU: 0.0h 0.0m 7.407264665002003s
# Epoch 10/30, Loss: 1.0985, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.695721908006817s
# Epoch 11/30, Loss: 1.0983, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.679126885952428s
# Epoch 12/30, Loss: 1.0980, Val Accuracy: 35.13%
# Elapsed time on CPU: 0.0h 0.0m 7.454383161850274s
# Epoch 13/30, Loss: 1.0981, Val Accuracy: 35.13%
# Elapsed time on CPU: 0.0h 0.0m 7.6678411739412695s
# Epoch 14/30, Loss: 1.0980, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.436387831810862s
# Epoch 15/30, Loss: 1.0980, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.4149426319636405s
# Epoch 16/30, Loss: 1.0978, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.447128593921661s
# Epoch 17/30, Loss: 1.0979, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.405099618015811s
# Epoch 18/30, Loss: 1.0978, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.410272371955216s
# Epoch 19/30, Loss: 1.0979, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.449748195009306s
# Epoch 20/30, Loss: 1.0978, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.4332100411411375s
# Epoch 21/30, Loss: 1.0978, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.431794871808961s
# Epoch 22/30, Loss: 1.0978, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.47829235997051s
# Epoch 23/30, Loss: 1.0978, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.462315205018967s
# Epoch 24/30, Loss: 1.0978, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.432584078982472s
# Epoch 25/30, Loss: 1.0978, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.407594817923382s
# Epoch 26/30, Loss: 1.0977, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.406273341039196s
# Epoch 27/30, Loss: 1.0977, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.692526052007452s
# Epoch 28/30, Loss: 1.0977, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.426689566811547s
# Epoch 29/30, Loss: 1.0977, Val Accuracy: 33.89%
# Elapsed time on CPU: 0.0h 0.0m 7.408454902004451s
# Epoch 30/30, Loss: 1.0977, Val Accuracy: 33.89%
# Total Train time: 0.0h 25.0m 58s
# Elapsed time on CPU: 0.0h 0.0m 7.699110052082688s
# Test Accuracy: 47.35%
# Train time: 0.0h 26.0m 6s
# Final Validation Accuracy: 47.35%
# ----------------------------------------------------------

# %%
# def clones(module, N):
#     return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %%
# def attention(query, key, value, mask=None, dropout=None):
#   d_k = query.size(-1)
#   scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(d_k)
#   if mask is not None:
#     scores =scores.masked_fill(mask==0, -1e9)
#   p_attn = scores.softmax(dim=-1)
#   if dropout is not None:
#     p_attn = dropout(p_attn)
#   return torch.matmul(p_attn, value), p_attn

# %%
# class SharableMultiheadAttention(nn.Module):
#     def __init__(self, embed_dim, num_heads, dropout=0.1):
#         super(SharableMultiheadAttention, self).__init__()
#         self.embed_dim = embed_dim
#         self.num_heads = num_heads
#         self.d_k = embed_dim // num_heads
#         self.linears = clones(nn.Linear(embed_dim))
#         self.attn = None
#         self.dropout = nn.Dropout(dropout)

#         self.qkv_proj = nn.Linear(embed_dim, embed_dim * 3)
#         self.out_proj = nn.Linear(embed_dim, embed_dim)
#         self.scale = self.d_k  ** -0.5

#     def forward(self, query, key, value, mask=None):
#         if mask is not None:
#             mask = mask.unsqueeze(1)
#         batch_size, seq_length, embed_dim = query.shape
#         qkv = self.qkv_proj(torch.cat[query, key, value], dim=1)
#         qkv = qkv.view(batch_size, seq_length, 3, self.num_heads, self.head_dim)
#         q, k, v = qkv.permute(2, 0, 3, 1, 4)
#         self.attn = attention(query, key, value, mask=mask, dropout=self.dropout)

#         x = (
#             x.transpose(1,2)
#             .contiguous()
#             .view(batch_size, -1, self.num_heads * self.d_k)
#         )
#         del query
#         del key
#         del value
#         return self.linears[-1](x)

# %%
# DEFAULT_THRESHOLD = 5e-3
# class SharableMultiheadAttention(nn.Module):
#     def __init__(self, embed_dim, num_heads, bias=True, 
#                  dropout=0., mask_init='1s', mask_scale=1e-2,
#                  threshold_fn='binarizer', threshold=None):
#         super(SharableMultiheadAttention, self).__init__()
#         self.embed_dim = embed_dim
#         self.num_heads = num_heads
#         self.dropout = dropout
#         self.mask_init= mask_init
#         self.mask_scale = mask_scale

#         if threshold is not None:
#             threshold = DEFAULT_THRESHOLD
#         self.info = {
#             'threshold_fn': threshold_fn,
#             'threshold': threshold,
#         }

#         self.weight = Parameter(torch.Tensor()) # 이 부분 맞춰주어야함함
#         if bias:
#             self.bias = Parameter(torch.Tensor())   # 이 부분 맞춰주어야함
#         else:
#             self.register_parameter()
#         self.piggymask = None

#         if threshold_fn == 'binarizer':
#             self.threshold_fn = Binarizer.apply
#         elif threshold_fn == 'tenarizer':
#             self.threshold_fn = Tenarizer(threshold=threshold)

#         self.q_proj = SharableLinear(embed_dim, embed_dim)
#         self.k_proj = SharableLinear(embed_dim, embed_dim)
#         self.v_proj = SharableLinear(embed_dim, embed_dim)
#         self.out_proj = SharableLinear(embed_dim, embed_dim)

#     def forward(self, query, key, value, attn_mask=None):
#         Q = self.q_proj(query)
#         K = self.k_proj(key)
#         V = self.v_proj(value)

#         if self.piggymask is not None:
#             mask_thresholded = self.threshold_fn(self.piggymask, self.info['threshold'])
#             weight = mask_thresholded * self.weight
#         else:
#             weight = self.weight ########일단 여기까지 따라침.

#         attn_output, _ = F.multi_head_attention_forward(
#             Q, K, V,
#             self.embed_dim, self.num_heads,
#             None, None, None,  # Scaling 및 Bias 없음
#             attn_mask,
#             dropout_p=self.dropout,
#             out_proj_weight=self.out_proj.weight * self.out_proj.mask,
#             out_proj_bias=self.out_proj.bias,
#             training=self.training,
#             need_weights=False
#         )
#         return attn_output
