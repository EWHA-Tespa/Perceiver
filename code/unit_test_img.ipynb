# %% [markdown]
# # Setting

# %%
import os
import glob
import random
import time
import torch
import torch.nn as nn
import torch.optim as optim
import pickle
import copy, math

import torch.nn.functional as F
from torch.nn.modules.utils import _pair
from torch.nn.parameter import Parameter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from collections import Counter
from sklearn.preprocessing import LabelEncoder

from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

import torchvision.transforms as T

from models.shared_perceiver import crop, patchify, get_patch_coords, ImageDataset, PerceiverBlock, Perceiver

# %%
def seed_everything(seed):
    torch.manual_seed(seed) #torch를 거치는 모든 난수들의 생성순서를 고정한다
    torch.cuda.manual_seed(seed) #cuda를 사용하는 메소드들의 난수시드는 따로 고정해줘야한다 
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True #딥러닝에 특화된 CuDNN의 난수시드도 고정 
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed) #numpy를 사용할 경우 고정
    random.seed(seed) #파이썬 자체 모듈 random 모듈의 시드 고정
seed_everything(42)

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# # Functions

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, epochs, device, scheduler=None):
    best_model = None 
    best_val_score = 0
    model.train()
    train_losses = []
    val_accuracies = []
    start = time.perf_counter()
    
    for epoch in range(epochs):
        total_loss = 0.0
        for images, labels in train_loader:
            # GPU로 옮기기
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        accuracy = evaluate_model(model, valid_loader, device=device, log_results=False)
        val_accuracies.append(accuracy)

        # Scheduler step 추가
        if scheduler:
            scheduler.step()

        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}, Val Accuracy: {accuracy:.2f}%")
        if accuracy > best_val_score:
            best_val_score = accuracy
            best_model_state = model.state_dict()  # 모델 상태 저장
            best_model = copy.deepcopy(model) 
            print(f"New best model found at epoch {epoch+1} with accuracy: {best_val_score:.2f}%")

    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Total Train time: {hour}h {min}m {sec}s")

    return train_losses, val_accuracies, best_model

def evaluate_model(model, data_loader, device, log_results=True):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        start = time.perf_counter()
        for images, labels in data_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        end = time.perf_counter()
        hour = (end-start) // 3600
        min = ((end-start) % 3600) // 60
        sec = (end-start) % 60
        print(f"Elapsed time on CPU: {hour}h {min}m {sec}s")

    accuracy = 100.0 * correct / total
    if log_results:
        print(f"Test Accuracy: {accuracy:.2f}%")
    return accuracy

# %% [markdown]
# # Load Model

# %%
data_dir = '/home/youlee/n24news/n24news/image'
crop_size = 0
patch_size = 16
batch_size = 32
epochs = 30
group_class = 3
LR = 5e-5

# %%
#random.shuffle(target_classes)
target_classes = [ # 임의로 순서지정
    "Opinion", "Art & Design", "Television",
    "Music", "Travel", "Real Estate",
    "Books", "Theater", "Health",
    "Sports", "Science", "Food",
    "Fashion & Style", "Movies", "Technology",
    "Dance", "Media", "Style"
]
target_classes
# Out:
# ['Opinion',
#  'Art & Design',
#  'Television',
#  'Music',
#  'Travel',
#  'Real Estate',
#  'Books',
#  'Theater',
#  'Health',
#  'Sports',
#  'Science',
#  'Food',
#  'Fashion & Style',
#  'Movies',
#  'Technology',
#  'Dance',
#  'Media',
#  'Style']

# %%
output_path = '/home/Minju/Perceiver/shared_layer_model'
loader_path = '/home/Minju/Perceiver/shared_layer_loader'
group_class
# Out:
# 3

# %% [markdown]
# # Train Loop

# %%
for i in range(0, len(target_classes), group_class):  
    print(f"실험 {i//group_class + 1} 시작")
    selected_classes = target_classes[i:i+group_class]
    print(f"Selected Feature: {selected_classes}")

    filtered_dataset = ImageDataset(root_dir=data_dir, 
                                    transform=transform, 
                                    crop_size=crop_size, 
                                    patch_size=patch_size,
                                    selected_classes=selected_classes)
    all_labels = [label_idx for (_, label_idx) in filtered_dataset.data]

    # 1) 유니크 라벨과 개수
    unique_label_ids = np.unique(all_labels)
    print("Unique numeric labels:", unique_label_ids)
    print("Number of unique numeric labels:", len(unique_label_ids))

    # 2) 라벨별 개수 (분포)
    label_counts = Counter(all_labels)
    print("Label distribution (index: count):", label_counts)
    
    train_ratio = 0.8
    train_size = int(len(filtered_dataset) * train_ratio)
    valid_size = len(filtered_dataset) - train_size

    train_dataset, valid_dataset = random_split(filtered_dataset, [train_size, valid_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

    print(f"train: {train_size}, valid: {valid_size}")
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    NUM_CLASSES = len(filtered_dataset.label_encoder.classes_)
    model = Perceiver(input_dim=(patch_size**2) * 3 + 2,
                        latent_dim=64, 
                        latent_size=64, 
                        num_classes=NUM_CLASSES, 
                        num_blocks=4, 
                        self_attn_layers_per_block=10).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)  # Learning rate decay 추가

    start = time.perf_counter()
    train_losses, val_accuracies, best_model = train_model(
        model, train_loader, valid_loader,
        criterion, optimizer, epochs,
        device=device,
        scheduler=scheduler  
    )
    
    final_acc = evaluate_model(best_model, valid_loader, device=device, log_results=True)
    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Train time: {hour}h {min}m {sec}s")
    print(f"Final Validation Accuracy: {final_acc:.2f}%")
    print("----------------------------------------------------------")
    
    torch.save(best_model, f'{output_path}/image_model_{i//group_class+1}.pkl')

    val_loader_save_path = f"{loader_path}/image_val_loader_{i//group_class+1}.pkl"
    with open(val_loader_save_path, 'wb') as f:
        pickle.dump(valid_dataset, f)
# Out:
# 실험 1 시작
# Selected Feature: ['Opinion', 'Art & Design', 'Television']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(1): 2437, np.int64(0): 2431, np.int64(2): 2419})
# train: 5829, valid: 1458
# Elapsed time on CPU: 0.0h 0.0m 8.747583600925282s
# Epoch 1/30, Loss: 1.0775, Val Accuracy: 42.52%
# New best model found at epoch 1 with accuracy: 42.52%
# Elapsed time on CPU: 0.0h 0.0m 8.964212890015915s
# Epoch 2/30, Loss: 1.0563, Val Accuracy: 43.55%
# New best model found at epoch 2 with accuracy: 43.55%
# Elapsed time on CPU: 0.0h 0.0m 8.689605055144057s
# Epoch 3/30, Loss: 1.0523, Val Accuracy: 42.59%
# Elapsed time on CPU: 0.0h 0.0m 8.804248178144917s
# Epoch 4/30, Loss: 1.0495, Val Accuracy: 41.70%
# Elapsed time on CPU: 0.0h 0.0m 8.977516054175794s
# Epoch 5/30, Loss: 1.0460, Val Accuracy: 42.46%
# Elapsed time on CPU: 0.0h 0.0m 8.808417147956789s
# Epoch 6/30, Loss: 1.0410, Val Accuracy: 43.69%
# New best model found at epoch 6 with accuracy: 43.69%
# Elapsed time on CPU: 0.0h 0.0m 8.703023126116022s
# Epoch 7/30, Loss: 1.0378, Val Accuracy: 44.38%
# New best model found at epoch 7 with accuracy: 44.38%
# Elapsed time on CPU: 0.0h 0.0m 8.839018048951402s
# Epoch 8/30, Loss: 1.0352, Val Accuracy: 43.90%
# Elapsed time on CPU: 0.0h 0.0m 8.671863966155797s
# Epoch 9/30, Loss: 1.0331, Val Accuracy: 46.57%
# New best model found at epoch 9 with accuracy: 46.57%
# Elapsed time on CPU: 0.0h 0.0m 8.750919218175113s
# Epoch 10/30, Loss: 1.0277, Val Accuracy: 47.87%
# New best model found at epoch 10 with accuracy: 47.87%
# Elapsed time on CPU: 0.0h 0.0m 8.89163010311313s
# Epoch 11/30, Loss: 1.0159, Val Accuracy: 47.74%
# Elapsed time on CPU: 0.0h 0.0m 8.932359127793461s
# Epoch 12/30, Loss: 1.0032, Val Accuracy: 49.04%
# New best model found at epoch 12 with accuracy: 49.04%
# Elapsed time on CPU: 0.0h 0.0m 9.075193936005235s
# Epoch 13/30, Loss: 0.9340, Val Accuracy: 61.18%
# New best model found at epoch 13 with accuracy: 61.18%
# Elapsed time on CPU: 0.0h 0.0m 8.67209470202215s
# Epoch 14/30, Loss: 0.8471, Val Accuracy: 61.73%
# New best model found at epoch 14 with accuracy: 61.73%
# Elapsed time on CPU: 0.0h 0.0m 9.042392099043354s
# Epoch 15/30, Loss: 0.8310, Val Accuracy: 60.01%
# Elapsed time on CPU: 0.0h 0.0m 8.820502924965695s
# Epoch 16/30, Loss: 0.8217, Val Accuracy: 62.62%
# New best model found at epoch 16 with accuracy: 62.62%
# Elapsed time on CPU: 0.0h 0.0m 8.438127188943326s
# Epoch 17/30, Loss: 0.8148, Val Accuracy: 62.21%
# Elapsed time on CPU: 0.0h 0.0m 8.935010546119884s
# Epoch 18/30, Loss: 0.8103, Val Accuracy: 62.28%
# Elapsed time on CPU: 0.0h 0.0m 8.610741227166727s
# Epoch 19/30, Loss: 0.8077, Val Accuracy: 60.63%
# Elapsed time on CPU: 0.0h 0.0m 8.619653183966875s
# Epoch 20/30, Loss: 0.8064, Val Accuracy: 62.83%
# New best model found at epoch 20 with accuracy: 62.83%
# Elapsed time on CPU: 0.0h 0.0m 8.716335494071245s
# Epoch 21/30, Loss: 0.8020, Val Accuracy: 62.69%
# Elapsed time on CPU: 0.0h 0.0m 8.817517718067393s
# Epoch 22/30, Loss: 0.7991, Val Accuracy: 61.93%
# Elapsed time on CPU: 0.0h 0.0m 8.730636725900695s
# Epoch 23/30, Loss: 0.7981, Val Accuracy: 61.93%
# Elapsed time on CPU: 0.0h 0.0m 9.071760536869988s
# Epoch 24/30, Loss: 0.7993, Val Accuracy: 61.45%
# Elapsed time on CPU: 0.0h 0.0m 8.756266127107665s
# Epoch 25/30, Loss: 0.7988, Val Accuracy: 62.28%
# Elapsed time on CPU: 0.0h 0.0m 8.748785553965718s
# Epoch 26/30, Loss: 0.7978, Val Accuracy: 62.48%
# Elapsed time on CPU: 0.0h 0.0m 8.74544757604599s
# Epoch 27/30, Loss: 0.7929, Val Accuracy: 62.48%
# Elapsed time on CPU: 0.0h 0.0m 8.715822562109679s
# Epoch 28/30, Loss: 0.7935, Val Accuracy: 62.21%
# Elapsed time on CPU: 0.0h 0.0m 8.853872584877536s
# Epoch 29/30, Loss: 0.7921, Val Accuracy: 62.55%
# Elapsed time on CPU: 0.0h 0.0m 8.780671468935907s
# Epoch 30/30, Loss: 0.7901, Val Accuracy: 62.62%
# Total Train time: 0.0h 26.0m 49s
# Elapsed time on CPU: 0.0h 0.0m 9.011515259975567s
# Test Accuracy: 62.83%
# Train time: 0.0h 26.0m 58s
# Final Validation Accuracy: 62.83%
# ----------------------------------------------------------
# 실험 2 시작
# Selected Feature: ['Music', 'Travel', 'Real Estate']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2416, np.int64(2): 2413, np.int64(1): 2413})
# train: 5793, valid: 1449
# Elapsed time on CPU: 0.0h 0.0m 8.129515304928645s
# Epoch 1/30, Loss: 1.0356, Val Accuracy: 47.96%
# New best model found at epoch 1 with accuracy: 47.96%
# Elapsed time on CPU: 0.0h 0.0m 7.679707357892767s
# Epoch 2/30, Loss: 0.9858, Val Accuracy: 48.72%
# New best model found at epoch 2 with accuracy: 48.72%
# Elapsed time on CPU: 0.0h 0.0m 7.9361002701334655s
# Epoch 3/30, Loss: 0.9873, Val Accuracy: 50.93%
# New best model found at epoch 3 with accuracy: 50.93%
# Elapsed time on CPU: 0.0h 0.0m 7.992037356132641s
# Epoch 4/30, Loss: 0.9684, Val Accuracy: 49.48%
# Elapsed time on CPU: 0.0h 0.0m 7.679907215060666s
# Epoch 5/30, Loss: 0.9602, Val Accuracy: 50.03%
# Elapsed time on CPU: 0.0h 0.0m 7.724691916024312s
# Epoch 6/30, Loss: 0.9499, Val Accuracy: 50.79%
# Elapsed time on CPU: 0.0h 0.0m 7.784021785017103s
# Epoch 7/30, Loss: 0.9423, Val Accuracy: 48.79%
# Elapsed time on CPU: 0.0h 0.0m 7.806182786123827s
# Epoch 8/30, Loss: 0.9387, Val Accuracy: 50.17%
# Elapsed time on CPU: 0.0h 0.0m 7.83085198700428s
# Epoch 9/30, Loss: 0.9312, Val Accuracy: 50.45%
# Elapsed time on CPU: 0.0h 0.0m 7.852450072998181s
# Epoch 10/30, Loss: 0.9289, Val Accuracy: 50.86%
# Elapsed time on CPU: 0.0h 0.0m 7.7618798890616745s
# Epoch 11/30, Loss: 0.9202, Val Accuracy: 51.48%
# New best model found at epoch 11 with accuracy: 51.48%
# Elapsed time on CPU: 0.0h 0.0m 7.938649605959654s
# Epoch 12/30, Loss: 0.9192, Val Accuracy: 51.62%
# New best model found at epoch 12 with accuracy: 51.62%
# Elapsed time on CPU: 0.0h 0.0m 7.705796496942639s
# Epoch 13/30, Loss: 0.9160, Val Accuracy: 51.21%
# Elapsed time on CPU: 0.0h 0.0m 7.762216218048707s
# Epoch 14/30, Loss: 0.9114, Val Accuracy: 51.55%
# Elapsed time on CPU: 0.0h 0.0m 7.692463808925822s
# Epoch 15/30, Loss: 0.9063, Val Accuracy: 49.90%
# Elapsed time on CPU: 0.0h 0.0m 7.735386591870338s
# Epoch 16/30, Loss: 0.9020, Val Accuracy: 52.66%
# New best model found at epoch 16 with accuracy: 52.66%
# Elapsed time on CPU: 0.0h 0.0m 7.90732129313983s
# Epoch 17/30, Loss: 0.9024, Val Accuracy: 52.24%
# Elapsed time on CPU: 0.0h 0.0m 7.962701122043654s
# Epoch 18/30, Loss: 0.8967, Val Accuracy: 51.90%
# Elapsed time on CPU: 0.0h 0.0m 7.93332738801837s
# Epoch 19/30, Loss: 0.8928, Val Accuracy: 52.24%
# Elapsed time on CPU: 0.0h 0.0m 7.9353323159739375s
# Epoch 20/30, Loss: 0.8920, Val Accuracy: 52.80%
# New best model found at epoch 20 with accuracy: 52.80%
# Elapsed time on CPU: 0.0h 0.0m 7.752153915120289s
# Epoch 21/30, Loss: 0.8873, Val Accuracy: 52.45%
# Elapsed time on CPU: 0.0h 0.0m 8.081753249047324s
# Epoch 22/30, Loss: 0.8824, Val Accuracy: 52.59%
# Elapsed time on CPU: 0.0h 0.0m 8.11869674292393s
# Epoch 23/30, Loss: 0.8826, Val Accuracy: 51.97%
# Elapsed time on CPU: 0.0h 0.0m 8.086322595132515s
# Epoch 24/30, Loss: 0.8802, Val Accuracy: 52.52%
# Elapsed time on CPU: 0.0h 0.0m 8.036271627992392s
# Epoch 25/30, Loss: 0.8792, Val Accuracy: 51.83%
# Elapsed time on CPU: 0.0h 0.0m 8.002522037131712s
# Epoch 26/30, Loss: 0.8760, Val Accuracy: 52.04%
# Elapsed time on CPU: 0.0h 0.0m 7.993079565931112s
# Epoch 27/30, Loss: 0.8765, Val Accuracy: 52.66%
# Elapsed time on CPU: 0.0h 0.0m 7.937019537901506s
# Epoch 28/30, Loss: 0.8743, Val Accuracy: 52.52%
# Elapsed time on CPU: 0.0h 0.0m 8.009628575993702s
# Epoch 29/30, Loss: 0.8727, Val Accuracy: 51.62%
# Elapsed time on CPU: 0.0h 0.0m 7.942076334962621s
# Epoch 30/30, Loss: 0.8713, Val Accuracy: 52.66%
# Total Train time: 0.0h 24.0m 34s
# Elapsed time on CPU: 0.0h 0.0m 7.826857842039317s
# Test Accuracy: 52.80%
# Train time: 0.0h 24.0m 41s
# Final Validation Accuracy: 52.80%
# ----------------------------------------------------------
# 실험 3 시작
# Selected Feature: ['Books', 'Theater', 'Health']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2412, np.int64(1): 2409, np.int64(2): 2409})
# train: 5784, valid: 1446
# Elapsed time on CPU: 0.0h 0.0m 7.520628957077861s
# Epoch 1/30, Loss: 1.0253, Val Accuracy: 48.13%
# New best model found at epoch 1 with accuracy: 48.13%
# Elapsed time on CPU: 0.0h 0.0m 7.537235282128677s
# Epoch 2/30, Loss: 0.9967, Val Accuracy: 49.86%
# New best model found at epoch 2 with accuracy: 49.86%
# Elapsed time on CPU: 0.0h 0.0m 7.507217837963253s
# Epoch 3/30, Loss: 0.9846, Val Accuracy: 49.93%
# New best model found at epoch 3 with accuracy: 49.93%
# Elapsed time on CPU: 0.0h 0.0m 7.7969361250288785s
# Epoch 4/30, Loss: 0.9765, Val Accuracy: 49.31%
# Elapsed time on CPU: 0.0h 0.0m 8.66843526205048s
# Epoch 5/30, Loss: 0.9692, Val Accuracy: 50.97%
# New best model found at epoch 5 with accuracy: 50.97%
# Elapsed time on CPU: 0.0h 0.0m 7.790408621774986s
# Epoch 6/30, Loss: 0.9553, Val Accuracy: 51.52%
# New best model found at epoch 6 with accuracy: 51.52%
# Elapsed time on CPU: 0.0h 0.0m 7.770107141928747s
# Epoch 7/30, Loss: 0.9490, Val Accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 7.7662067748606205s
# Epoch 8/30, Loss: 0.9443, Val Accuracy: 50.62%
# Elapsed time on CPU: 0.0h 0.0m 7.799743128940463s
# Epoch 9/30, Loss: 0.9430, Val Accuracy: 52.07%
# New best model found at epoch 9 with accuracy: 52.07%
# Elapsed time on CPU: 0.0h 0.0m 7.81814427790232s
# Epoch 10/30, Loss: 0.9406, Val Accuracy: 52.90%
# New best model found at epoch 10 with accuracy: 52.90%
# Elapsed time on CPU: 0.0h 0.0m 7.807495803106576s
# Epoch 11/30, Loss: 0.9321, Val Accuracy: 53.94%
# New best model found at epoch 11 with accuracy: 53.94%
# Elapsed time on CPU: 0.0h 0.0m 7.811488228151575s
# Epoch 12/30, Loss: 0.9324, Val Accuracy: 53.39%
# Elapsed time on CPU: 0.0h 0.0m 7.518814563052729s
# Epoch 13/30, Loss: 0.9282, Val Accuracy: 53.39%
# Elapsed time on CPU: 0.0h 0.0m 7.517919650999829s
# Epoch 14/30, Loss: 0.9259, Val Accuracy: 53.32%
# Elapsed time on CPU: 0.0h 0.0m 7.810904595069587s
# Epoch 15/30, Loss: 0.9251, Val Accuracy: 52.56%
# Elapsed time on CPU: 0.0h 0.0m 7.523611641023308s
# Epoch 16/30, Loss: 0.9223, Val Accuracy: 53.11%
# Elapsed time on CPU: 0.0h 0.0m 7.523996572010219s
# Epoch 17/30, Loss: 0.9196, Val Accuracy: 53.46%
# Elapsed time on CPU: 0.0h 0.0m 7.50371457496658s
# Epoch 18/30, Loss: 0.9199, Val Accuracy: 54.29%
# New best model found at epoch 18 with accuracy: 54.29%
# Elapsed time on CPU: 0.0h 0.0m 7.539315644884482s
# Epoch 19/30, Loss: 0.9176, Val Accuracy: 54.01%
# Elapsed time on CPU: 0.0h 0.0m 7.539359902963042s
# Epoch 20/30, Loss: 0.9172, Val Accuracy: 53.53%
# Elapsed time on CPU: 0.0h 0.0m 7.547222615918145s
# Epoch 21/30, Loss: 0.9139, Val Accuracy: 54.36%
# New best model found at epoch 21 with accuracy: 54.36%
# Elapsed time on CPU: 0.0h 0.0m 7.54999912600033s
# Epoch 22/30, Loss: 0.9132, Val Accuracy: 54.29%
# Elapsed time on CPU: 0.0h 0.0m 7.828441916033626s
# Epoch 23/30, Loss: 0.9127, Val Accuracy: 53.67%
# Elapsed time on CPU: 0.0h 0.0m 7.918592179892585s
# Epoch 24/30, Loss: 0.9113, Val Accuracy: 53.80%
# Elapsed time on CPU: 0.0h 0.0m 7.519975405884907s
# Epoch 25/30, Loss: 0.9113, Val Accuracy: 54.43%
# New best model found at epoch 25 with accuracy: 54.43%
# Elapsed time on CPU: 0.0h 0.0m 7.551553099183366s
# Epoch 26/30, Loss: 0.9094, Val Accuracy: 54.70%
# New best model found at epoch 26 with accuracy: 54.70%
# Elapsed time on CPU: 0.0h 0.0m 8.417152694892138s
# Epoch 27/30, Loss: 0.9092, Val Accuracy: 54.15%
# Elapsed time on CPU: 0.0h 0.0m 7.580642194952816s
# Epoch 28/30, Loss: 0.9083, Val Accuracy: 53.67%
# Elapsed time on CPU: 0.0h 0.0m 7.603585629025474s
# Epoch 29/30, Loss: 0.9086, Val Accuracy: 54.50%
# Elapsed time on CPU: 0.0h 0.0m 7.612314332043752s
# Epoch 30/30, Loss: 0.9083, Val Accuracy: 54.08%
# Total Train time: 0.0h 24.0m 13s
# Elapsed time on CPU: 0.0h 0.0m 7.638410603161901s
# Test Accuracy: 54.70%
# Train time: 0.0h 24.0m 21s
# Final Validation Accuracy: 54.70%
# ----------------------------------------------------------
# 실험 4 시작
# Selected Feature: ['Sports', 'Science', 'Food']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(2): 2407, np.int64(1): 2387, np.int64(0): 2385})
# train: 5743, valid: 1436
# Elapsed time on CPU: 0.0h 0.0m 7.942739446880296s
# Epoch 1/30, Loss: 1.0844, Val Accuracy: 40.74%
# New best model found at epoch 1 with accuracy: 40.74%
# Elapsed time on CPU: 0.0h 0.0m 8.304475735174492s
# Epoch 2/30, Loss: 1.0665, Val Accuracy: 42.48%
# New best model found at epoch 2 with accuracy: 42.48%
# Elapsed time on CPU: 0.0h 0.0m 8.212039758916944s
# Epoch 3/30, Loss: 1.0655, Val Accuracy: 41.57%
# Elapsed time on CPU: 0.0h 0.0m 8.313805081881583s
# Epoch 4/30, Loss: 1.0591, Val Accuracy: 42.90%
# New best model found at epoch 4 with accuracy: 42.90%
# Elapsed time on CPU: 0.0h 0.0m 7.962756806053221s
# Epoch 5/30, Loss: 1.0530, Val Accuracy: 44.15%
# New best model found at epoch 5 with accuracy: 44.15%
# Elapsed time on CPU: 0.0h 0.0m 8.302624518983066s
# Epoch 6/30, Loss: 1.0414, Val Accuracy: 46.17%
# New best model found at epoch 6 with accuracy: 46.17%
# Elapsed time on CPU: 0.0h 0.0m 7.9084642310626805s
# Epoch 7/30, Loss: 1.0240, Val Accuracy: 47.14%
# New best model found at epoch 7 with accuracy: 47.14%
# Elapsed time on CPU: 0.0h 0.0m 7.897604183992371s
# Epoch 8/30, Loss: 1.0116, Val Accuracy: 48.05%
# New best model found at epoch 8 with accuracy: 48.05%
# Elapsed time on CPU: 0.0h 0.0m 7.9076810870319605s
# Epoch 9/30, Loss: 1.0043, Val Accuracy: 48.96%
# New best model found at epoch 9 with accuracy: 48.96%
# Elapsed time on CPU: 0.0h 0.0m 7.949507704935968s
# Epoch 10/30, Loss: 0.9981, Val Accuracy: 48.12%
# Elapsed time on CPU: 0.0h 0.0m 7.953372925054282s
# Epoch 11/30, Loss: 0.9862, Val Accuracy: 48.96%
# Elapsed time on CPU: 0.0h 0.0m 7.928913571173325s
# Epoch 12/30, Loss: 0.9824, Val Accuracy: 49.65%
# New best model found at epoch 12 with accuracy: 49.65%
# Elapsed time on CPU: 0.0h 0.0m 7.952294978080317s
# Epoch 13/30, Loss: 0.9793, Val Accuracy: 48.96%
# Elapsed time on CPU: 0.0h 0.0m 7.859667158918455s
# Epoch 14/30, Loss: 0.9785, Val Accuracy: 50.21%
# New best model found at epoch 14 with accuracy: 50.21%
# Elapsed time on CPU: 0.0h 0.0m 7.954320492921397s
# Epoch 15/30, Loss: 0.9748, Val Accuracy: 48.96%
# Elapsed time on CPU: 0.0h 0.0m 9.167626299196854s
# Epoch 16/30, Loss: 0.9692, Val Accuracy: 50.28%
# New best model found at epoch 16 with accuracy: 50.28%
# Elapsed time on CPU: 0.0h 0.0m 8.189123468939215s
# Epoch 17/30, Loss: 0.9679, Val Accuracy: 50.42%
# New best model found at epoch 17 with accuracy: 50.42%
# Elapsed time on CPU: 0.0h 0.0m 7.917721381876618s
# Epoch 18/30, Loss: 0.9662, Val Accuracy: 51.04%
# New best model found at epoch 18 with accuracy: 51.04%
# Elapsed time on CPU: 0.0h 0.0m 7.937118404079229s
# Epoch 19/30, Loss: 0.9646, Val Accuracy: 50.49%
# Elapsed time on CPU: 0.0h 0.0m 7.9471033019945025s
# Epoch 20/30, Loss: 0.9635, Val Accuracy: 49.30%
# Elapsed time on CPU: 0.0h 0.0m 7.899814838077873s
# Epoch 21/30, Loss: 0.9616, Val Accuracy: 50.28%
# Elapsed time on CPU: 0.0h 0.0m 7.871382726822048s
# Epoch 22/30, Loss: 0.9594, Val Accuracy: 51.04%
# Elapsed time on CPU: 0.0h 0.0m 7.946566445985809s
# Epoch 23/30, Loss: 0.9595, Val Accuracy: 50.28%
# Elapsed time on CPU: 0.0h 0.0m 8.99460564297624s
# Epoch 24/30, Loss: 0.9585, Val Accuracy: 50.35%
# Elapsed time on CPU: 0.0h 0.0m 7.943224340910092s
# Epoch 25/30, Loss: 0.9577, Val Accuracy: 50.28%
# Elapsed time on CPU: 0.0h 0.0m 7.904156791977584s
# Epoch 26/30, Loss: 0.9565, Val Accuracy: 50.63%
# Elapsed time on CPU: 0.0h 0.0m 7.893277059076354s
# Epoch 27/30, Loss: 0.9560, Val Accuracy: 50.70%
# Elapsed time on CPU: 0.0h 0.0m 7.839427103055641s
# Epoch 28/30, Loss: 0.9555, Val Accuracy: 50.70%
# Elapsed time on CPU: 0.0h 0.0m 7.863040952011943s
# Epoch 29/30, Loss: 0.9559, Val Accuracy: 50.70%
# Elapsed time on CPU: 0.0h 0.0m 7.895060088019818s
# Epoch 30/30, Loss: 0.9549, Val Accuracy: 50.91%
# Total Train time: 0.0h 24.0m 54s
# Elapsed time on CPU: 0.0h 0.0m 8.14819122897461s
# Test Accuracy: 51.04%
# Train time: 0.0h 25.0m 2s
# Final Validation Accuracy: 51.04%
# ----------------------------------------------------------
# 실험 5 시작
# Selected Feature: ['Fashion & Style', 'Movies', 'Technology']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2385, np.int64(1): 2384, np.int64(2): 2376})
# train: 5716, valid: 1429
# Elapsed time on CPU: 0.0h 0.0m 7.7967934908811s
# Epoch 1/30, Loss: 1.0915, Val Accuracy: 39.89%
# New best model found at epoch 1 with accuracy: 39.89%
# Elapsed time on CPU: 0.0h 0.0m 7.8210112389642745s
# Epoch 2/30, Loss: 1.0832, Val Accuracy: 39.05%
# Elapsed time on CPU: 0.0h 0.0m 8.15473087807186s
# Epoch 3/30, Loss: 1.0795, Val Accuracy: 38.42%
# Elapsed time on CPU: 0.0h 0.0m 8.04650825704448s
# Epoch 4/30, Loss: 1.0806, Val Accuracy: 39.33%
# Elapsed time on CPU: 0.0h 0.0m 7.782132781110704s
# Epoch 5/30, Loss: 1.0764, Val Accuracy: 39.40%
# Elapsed time on CPU: 0.0h 0.0m 7.784581457963213s
# Epoch 6/30, Loss: 1.0709, Val Accuracy: 41.57%
# New best model found at epoch 6 with accuracy: 41.57%
# Elapsed time on CPU: 0.0h 0.0m 8.067640483146533s
# Epoch 7/30, Loss: 1.0637, Val Accuracy: 41.50%
# Elapsed time on CPU: 0.0h 0.0m 8.091193669941276s
# Epoch 8/30, Loss: 1.0592, Val Accuracy: 43.25%
# New best model found at epoch 8 with accuracy: 43.25%
# Elapsed time on CPU: 0.0h 0.0m 8.094903758959845s
# Epoch 9/30, Loss: 1.0575, Val Accuracy: 43.67%
# New best model found at epoch 9 with accuracy: 43.67%
# Elapsed time on CPU: 0.0h 0.0m 7.814107994083315s
# Epoch 10/30, Loss: 1.0536, Val Accuracy: 44.16%
# New best model found at epoch 10 with accuracy: 44.16%
# Elapsed time on CPU: 0.0h 0.0m 7.695768386125565s
# Epoch 11/30, Loss: 1.0486, Val Accuracy: 44.51%
# New best model found at epoch 11 with accuracy: 44.51%
# Elapsed time on CPU: 0.0h 0.0m 8.077149449847639s
# Epoch 12/30, Loss: 1.0461, Val Accuracy: 45.42%
# New best model found at epoch 12 with accuracy: 45.42%
# Elapsed time on CPU: 0.0h 0.0m 8.09725693310611s
# Epoch 13/30, Loss: 1.0439, Val Accuracy: 44.30%
# Elapsed time on CPU: 0.0h 0.0m 8.098467841977254s
# Epoch 14/30, Loss: 1.0440, Val Accuracy: 44.37%
# Elapsed time on CPU: 0.0h 0.0m 8.098289068089798s
# Epoch 15/30, Loss: 1.0407, Val Accuracy: 45.00%
# Elapsed time on CPU: 0.0h 0.0m 8.065284142969176s
# Epoch 16/30, Loss: 1.0378, Val Accuracy: 44.44%
# Elapsed time on CPU: 0.0h 0.0m 8.097394137876108s
# Epoch 17/30, Loss: 1.0358, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 8.057904429035261s
# Epoch 18/30, Loss: 1.0365, Val Accuracy: 44.23%
# Elapsed time on CPU: 0.0h 0.0m 8.038789944024757s
# Epoch 19/30, Loss: 1.0350, Val Accuracy: 44.16%
# Elapsed time on CPU: 0.0h 0.0m 8.044656968908384s
# Epoch 20/30, Loss: 1.0353, Val Accuracy: 44.37%
# Elapsed time on CPU: 0.0h 0.0m 8.073868297971785s
# Epoch 21/30, Loss: 1.0328, Val Accuracy: 44.37%
# Elapsed time on CPU: 0.0h 0.0m 8.211220036959276s
# Epoch 22/30, Loss: 1.0320, Val Accuracy: 43.81%
# Elapsed time on CPU: 0.0h 0.0m 8.057951310183853s
# Epoch 23/30, Loss: 1.0318, Val Accuracy: 44.30%
# Elapsed time on CPU: 0.0h 0.0m 8.067796522984281s
# Epoch 24/30, Loss: 1.0319, Val Accuracy: 44.30%
# Elapsed time on CPU: 0.0h 0.0m 8.053440267918631s
# Epoch 25/30, Loss: 1.0305, Val Accuracy: 44.30%
# Elapsed time on CPU: 0.0h 0.0m 8.054626002907753s
# Epoch 26/30, Loss: 1.0297, Val Accuracy: 44.51%
# Elapsed time on CPU: 0.0h 0.0m 8.109575405949727s
# Epoch 27/30, Loss: 1.0291, Val Accuracy: 43.81%
# Elapsed time on CPU: 0.0h 0.0m 8.076835094951093s
# Epoch 28/30, Loss: 1.0292, Val Accuracy: 44.09%
# Elapsed time on CPU: 0.0h 0.0m 8.088339088950306s
# Epoch 29/30, Loss: 1.0289, Val Accuracy: 44.16%
# Elapsed time on CPU: 0.0h 0.0m 8.094112414168194s
# Epoch 30/30, Loss: 1.0286, Val Accuracy: 44.30%
# Total Train time: 0.0h 24.0m 39s
# Elapsed time on CPU: 0.0h 0.0m 8.08926665619947s
# Test Accuracy: 45.42%
# Train time: 0.0h 24.0m 47s
# Final Validation Accuracy: 45.42%
# ----------------------------------------------------------
# 실험 6 시작
# Selected Feature: ['Dance', 'Media', 'Style']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2365, np.int64(1): 2363, np.int64(2): 2147})
# train: 5500, valid: 1375
# Elapsed time on CPU: 0.0h 0.0m 9.75121072283946s
# Epoch 1/30, Loss: 1.0560, Val Accuracy: 47.56%
# New best model found at epoch 1 with accuracy: 47.56%
# Elapsed time on CPU: 0.0h 0.0m 7.420253193937242s
# Epoch 2/30, Loss: 1.0336, Val Accuracy: 46.55%
# Elapsed time on CPU: 0.0h 0.0m 7.168556818040088s
# Epoch 3/30, Loss: 1.0217, Val Accuracy: 48.80%
# New best model found at epoch 3 with accuracy: 48.80%
# Elapsed time on CPU: 0.0h 0.0m 7.983174551976845s
# Epoch 4/30, Loss: 1.0179, Val Accuracy: 48.73%
# Elapsed time on CPU: 0.0h 0.0m 7.1642216260079294s
# Epoch 5/30, Loss: 1.0123, Val Accuracy: 48.95%
# New best model found at epoch 5 with accuracy: 48.95%
# Elapsed time on CPU: 0.0h 0.0m 7.398366332985461s
# Epoch 6/30, Loss: 1.0082, Val Accuracy: 48.00%
# Elapsed time on CPU: 0.0h 0.0m 7.396409370005131s
# Epoch 7/30, Loss: 1.0073, Val Accuracy: 48.36%
# Elapsed time on CPU: 0.0h 0.0m 7.393456276040524s
# Epoch 8/30, Loss: 1.0052, Val Accuracy: 48.95%
# Elapsed time on CPU: 0.0h 0.0m 7.410588955972344s
# Epoch 9/30, Loss: 1.0050, Val Accuracy: 49.02%
# New best model found at epoch 9 with accuracy: 49.02%
# Elapsed time on CPU: 0.0h 0.0m 7.168081432115287s
# Epoch 10/30, Loss: 1.0047, Val Accuracy: 48.87%
# Elapsed time on CPU: 0.0h 0.0m 7.199147406034172s
# Epoch 11/30, Loss: 1.0005, Val Accuracy: 49.24%
# New best model found at epoch 11 with accuracy: 49.24%
# Elapsed time on CPU: 0.0h 0.0m 7.285416336962953s
# Epoch 12/30, Loss: 0.9996, Val Accuracy: 49.09%
# Elapsed time on CPU: 0.0h 0.0m 7.186403223080561s
# Epoch 13/30, Loss: 0.9979, Val Accuracy: 49.38%
# New best model found at epoch 13 with accuracy: 49.38%
# Elapsed time on CPU: 0.0h 0.0m 7.1966140060685575s
# Epoch 14/30, Loss: 0.9974, Val Accuracy: 49.31%
# Elapsed time on CPU: 0.0h 0.0m 7.190126309171319s
# Epoch 15/30, Loss: 0.9962, Val Accuracy: 49.09%
# Elapsed time on CPU: 0.0h 0.0m 7.192380364052951s
# Epoch 16/30, Loss: 0.9952, Val Accuracy: 49.60%
# New best model found at epoch 16 with accuracy: 49.60%
# Elapsed time on CPU: 0.0h 0.0m 7.162936270004138s
# Epoch 17/30, Loss: 0.9949, Val Accuracy: 49.60%
# Elapsed time on CPU: 0.0h 0.0m 7.424763161921874s
# Epoch 18/30, Loss: 0.9951, Val Accuracy: 49.09%
# Elapsed time on CPU: 0.0h 0.0m 7.097193734021857s
# Epoch 19/30, Loss: 0.9941, Val Accuracy: 49.75%
# New best model found at epoch 19 with accuracy: 49.75%
# Elapsed time on CPU: 0.0h 0.0m 7.418725459836423s
# Epoch 20/30, Loss: 0.9940, Val Accuracy: 49.16%
# Elapsed time on CPU: 0.0h 0.0m 7.411043359898031s
# Epoch 21/30, Loss: 0.9925, Val Accuracy: 49.45%
# Elapsed time on CPU: 0.0h 0.0m 7.381374871823937s
# Epoch 22/30, Loss: 0.9922, Val Accuracy: 49.38%
# Elapsed time on CPU: 0.0h 0.0m 7.4091815950814635s
# Epoch 23/30, Loss: 0.9923, Val Accuracy: 49.60%
# Elapsed time on CPU: 0.0h 0.0m 7.120200202101842s
# Epoch 24/30, Loss: 0.9905, Val Accuracy: 49.82%
# New best model found at epoch 24 with accuracy: 49.82%
# Elapsed time on CPU: 0.0h 0.0m 7.118883298011497s
# Epoch 25/30, Loss: 0.9898, Val Accuracy: 49.24%
# Elapsed time on CPU: 0.0h 0.0m 7.129721425008029s
# Epoch 26/30, Loss: 0.9891, Val Accuracy: 49.45%
# Elapsed time on CPU: 0.0h 0.0m 7.123101531993598s
# Epoch 27/30, Loss: 0.9878, Val Accuracy: 49.82%
# Elapsed time on CPU: 0.0h 0.0m 7.149059658171609s
# Epoch 28/30, Loss: 0.9877, Val Accuracy: 49.53%
# Elapsed time on CPU: 0.0h 0.0m 7.129026474896818s
# Epoch 29/30, Loss: 0.9871, Val Accuracy: 49.82%
# Elapsed time on CPU: 0.0h 0.0m 7.1763793639838696s
# Epoch 30/30, Loss: 0.9866, Val Accuracy: 49.75%
# Total Train time: 0.0h 22.0m 48s
# Elapsed time on CPU: 0.0h 0.0m 7.414000818040222s
# Test Accuracy: 49.82%
# Train time: 0.0h 22.0m 56s
# Final Validation Accuracy: 49.82%
# ----------------------------------------------------------
