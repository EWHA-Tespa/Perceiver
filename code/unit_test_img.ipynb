# %% [markdown]
# # Setting

# %%
import os
import glob
import random
import time
import torch
import torch.nn as nn
import torch.optim as optim
import pickle
import copy, math

import torch.nn.functional as F
from torch.nn.modules.utils import _pair
from torch.nn.parameter import Parameter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from collections import Counter
from sklearn.preprocessing import LabelEncoder

from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

import torchvision.transforms as T

from models.shared_perceiver import crop, patchify, get_patch_coords, ImageDataset, PerceiverBlock, Perceiver

# %%
def seed_everything(seed):
    torch.manual_seed(seed) #torch를 거치는 모든 난수들의 생성순서를 고정한다
    torch.cuda.manual_seed(seed) #cuda를 사용하는 메소드들의 난수시드는 따로 고정해줘야한다 
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True #딥러닝에 특화된 CuDNN의 난수시드도 고정 
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed) #numpy를 사용할 경우 고정
    random.seed(seed) #파이썬 자체 모듈 random 모듈의 시드 고정

def seed_worker(worker_id): #데이터로더 난수고정
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

seed_everything(42)
g = torch.Generator()
g.manual_seed(42)
NUM_WORKERS = 4 # 서브프로세스관리자 수. 난수생성과 관련있습니다. 일단은 4로 고정합니다.

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# # Functions

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, epochs, device, scheduler=None):
    best_model = None 
    best_val_score = 0
    model.train()
    train_losses = []
    val_accuracies = []
    start = time.perf_counter()
    
    for epoch in range(epochs):
        total_loss = 0.0
        for images, labels in train_loader:
            # GPU로 옮기기
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        accuracy = evaluate_model(model, valid_loader, device=device, log_results=False)
        val_accuracies.append(accuracy)

        # Scheduler step 추가
        if scheduler:
            scheduler.step()

        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}, Val Accuracy: {accuracy:.2f}%")
        if accuracy > best_val_score:
            best_val_score = accuracy
            best_model_state = model.state_dict()  # 모델 상태 저장
            best_model = copy.deepcopy(model) 
            print(f"New best model found at epoch {epoch+1} with accuracy: {best_val_score:.2f}%")

    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Total Train time: {hour}h {min}m {sec}s")

    return train_losses, val_accuracies, best_model

def evaluate_model(model, data_loader, device, log_results=True):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        start = time.perf_counter()
        for images, labels in data_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        end = time.perf_counter()
        hour = (end-start) // 3600
        min = ((end-start) % 3600) // 60
        sec = (end-start) % 60
        print(f"Elapsed time on CPU: {hour}h {min}m {sec}s")

    accuracy = 100.0 * correct / total
    if log_results:
        print(f"Test Accuracy: {accuracy:.2f}%")
    return accuracy

# %% [markdown]
# # Load Model

# %%
data_dir = '/home/youlee/n24news/n24news/image'
crop_size = 16
patch_size = 16
batch_size = 32
epochs = 40
group_class = 3
LR = 5e-5

# %%
#random.shuffle(target_classes)
target_classes = [ # 임의로 순서지정
    "Opinion", "Art & Design", "Television",
    "Music", "Travel", "Real Estate",
    "Books", "Theater", "Health",
    "Sports", "Science", "Food",
    "Fashion & Style", "Movies", "Technology",
    "Dance", "Media", "Style"
]
target_classes
# Out:
# ['Opinion',
#  'Art & Design',
#  'Television',
#  'Music',
#  'Travel',
#  'Real Estate',
#  'Books',
#  'Theater',
#  'Health',
#  'Sports',
#  'Science',
#  'Food',
#  'Fashion & Style',
#  'Movies',
#  'Technology',
#  'Dance',
#  'Media',
#  'Style']

# %%
output_path = '/home/Minju/Perceiver/shared_layer_model'
loader_path = '/home/Minju/Perceiver/shared_layer_loader'
group_class
# Out:
# 3

# %% [markdown]
# # Train Loop

# %%
for i in range(0, len(target_classes), group_class):  
    print(f"실험 {i//group_class + 1} 시작")
    selected_classes = target_classes[i:i+group_class]
    print(f"Selected Feature: {selected_classes}")

    filtered_dataset = ImageDataset(root_dir=data_dir, 
                                    transform=transform, 
                                    crop_size=crop_size, 
                                    patch_size=patch_size,
                                    selected_classes=selected_classes)
    all_labels = [label_idx for (_, label_idx) in filtered_dataset.data]

    # 1) 유니크 라벨과 개수
    unique_label_ids = np.unique(all_labels)
    print("Unique numeric labels:", unique_label_ids)
    print("Number of unique numeric labels:", len(unique_label_ids))

    # 2) 라벨별 개수 (분포)
    label_counts = Counter(all_labels)
    print("Label distribution (index: count):", label_counts)
    
    train_ratio = 0.8
    train_size = int(len(filtered_dataset) * train_ratio)
    valid_size = len(filtered_dataset) - train_size

    train_dataset, valid_dataset = random_split(filtered_dataset, [train_size, valid_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
                              num_workers=NUM_WORKERS, worker_init_fn=seed_worker, generator=g)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,
                              num_workers=NUM_WORKERS, worker_init_fn=seed_worker, generator=g)

    print(f"train: {train_size}, valid: {valid_size}")
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    NUM_CLASSES = len(filtered_dataset.label_encoder.classes_)
    model = Perceiver(input_dim=(patch_size**2) * 3 + 2,
                        latent_dim=64, 
                        latent_size=64, 
                        num_classes=NUM_CLASSES, 
                        num_blocks=4, 
                        self_attn_layers_per_block=10).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)  # Learning rate decay 추가

    start = time.perf_counter()
    train_losses, val_accuracies, best_model = train_model(
        model, train_loader, valid_loader,
        criterion, optimizer, epochs,
        device=device,
        scheduler=scheduler  
    )
    
    final_acc = evaluate_model(best_model, valid_loader, device=device, log_results=True)
    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Train time: {hour}h {min}m {sec}s")
    print(f"Final Validation Accuracy: {final_acc:.2f}%")
    print("----------------------------------------------------------")
    
    torch.save(best_model, f'{output_path}/image_model_{i//group_class+1}.pkl')

    val_loader_save_path = f"{loader_path}/image_val_loader_{i//group_class+1}.pkl"
    with open(val_loader_save_path, 'wb') as f:
        pickle.dump(valid_dataset, f)
# Out:
# 실험 1 시작
# Selected Feature: ['Opinion', 'Art & Design', 'Television']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(1): 2437, np.int64(0): 2431, np.int64(2): 2419})
# train: 5829, valid: 1458
# Elapsed time on CPU: 0.0h 0.0m 2.1848452487029135s
# Epoch 1/40, Loss: 1.0971, Val Accuracy: 42.80%
# New best model found at epoch 1 with accuracy: 42.80%
# Elapsed time on CPU: 0.0h 0.0m 1.9893387989141047s
# Epoch 2/40, Loss: 1.0586, Val Accuracy: 42.25%
# Elapsed time on CPU: 0.0h 0.0m 1.9807624462991953s
# Epoch 3/40, Loss: 1.0491, Val Accuracy: 41.70%
# Elapsed time on CPU: 0.0h 0.0m 2.162348170299083s
# Epoch 4/40, Loss: 1.0482, Val Accuracy: 41.22%
# Elapsed time on CPU: 0.0h 0.0m 2.153007079847157s
# Epoch 5/40, Loss: 1.0489, Val Accuracy: 41.77%
# Elapsed time on CPU: 0.0h 0.0m 2.182460173033178s
# Epoch 6/40, Loss: 1.0470, Val Accuracy: 41.29%
# Elapsed time on CPU: 0.0h 0.0m 2.16618640627712s
# Epoch 7/40, Loss: 1.0443, Val Accuracy: 41.36%
# Elapsed time on CPU: 0.0h 0.0m 2.1491563939489424s
# Epoch 8/40, Loss: 1.0448, Val Accuracy: 42.25%
# Elapsed time on CPU: 0.0h 0.0m 2.178241058252752s
# Epoch 9/40, Loss: 1.0446, Val Accuracy: 42.39%
# Elapsed time on CPU: 0.0h 0.0m 2.158107961062342s
# Epoch 10/40, Loss: 1.0436, Val Accuracy: 41.91%
# Elapsed time on CPU: 0.0h 0.0m 2.1826924211345613s
# Epoch 11/40, Loss: 1.0434, Val Accuracy: 41.36%
# Elapsed time on CPU: 0.0h 0.0m 2.1710921921767294s
# Epoch 12/40, Loss: 1.0430, Val Accuracy: 41.91%
# Elapsed time on CPU: 0.0h 0.0m 2.167722800280899s
# Epoch 13/40, Loss: 1.0428, Val Accuracy: 41.50%
# Elapsed time on CPU: 0.0h 0.0m 2.1730949422344565s
# Epoch 14/40, Loss: 1.0410, Val Accuracy: 41.50%
# Elapsed time on CPU: 0.0h 0.0m 2.257806485053152s
# Epoch 15/40, Loss: 1.0438, Val Accuracy: 42.11%
# Elapsed time on CPU: 0.0h 0.0m 2.23842853307724s
# Epoch 16/40, Loss: 1.0418, Val Accuracy: 42.32%
# Elapsed time on CPU: 0.0h 0.0m 2.276440823916346s
# Epoch 17/40, Loss: 1.0411, Val Accuracy: 41.70%
# Elapsed time on CPU: 0.0h 0.0m 2.2877415269613266s
# Epoch 18/40, Loss: 1.0408, Val Accuracy: 41.70%
# Elapsed time on CPU: 0.0h 0.0m 2.2644468815997243s
# Epoch 19/40, Loss: 1.0415, Val Accuracy: 41.91%
# Elapsed time on CPU: 0.0h 0.0m 2.275623066816479s
# Epoch 20/40, Loss: 1.0406, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.2520295078866184s
# Epoch 21/40, Loss: 1.0401, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.2778178369626403s
# Epoch 22/40, Loss: 1.0404, Val Accuracy: 41.91%
# Elapsed time on CPU: 0.0h 0.0m 2.273865388240665s
# Epoch 23/40, Loss: 1.0404, Val Accuracy: 42.11%
# Elapsed time on CPU: 0.0h 0.0m 2.26336384518072s
# Epoch 24/40, Loss: 1.0403, Val Accuracy: 41.70%
# Elapsed time on CPU: 0.0h 0.0m 2.2603428601287305s
# Epoch 25/40, Loss: 1.0407, Val Accuracy: 42.04%
# Elapsed time on CPU: 0.0h 0.0m 2.2790044089779258s
# Epoch 26/40, Loss: 1.0395, Val Accuracy: 41.77%
# Elapsed time on CPU: 0.0h 0.0m 2.2887788410298526s
# Epoch 27/40, Loss: 1.0403, Val Accuracy: 41.77%
# Elapsed time on CPU: 0.0h 0.0m 2.256184731144458s
# Epoch 28/40, Loss: 1.0399, Val Accuracy: 42.25%
# Elapsed time on CPU: 0.0h 0.0m 2.313268302939832s
# Epoch 29/40, Loss: 1.0407, Val Accuracy: 42.11%
# Elapsed time on CPU: 0.0h 0.0m 2.285311949905008s
# Epoch 30/40, Loss: 1.0413, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.2595860338769853s
# Epoch 31/40, Loss: 1.0400, Val Accuracy: 42.11%
# Elapsed time on CPU: 0.0h 0.0m 2.2727874401025474s
# Epoch 32/40, Loss: 1.0388, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.302804701961577s
# Epoch 33/40, Loss: 1.0392, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.275841221679002s
# Epoch 34/40, Loss: 1.0396, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.2999098948203027s
# Epoch 35/40, Loss: 1.0394, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.2681136690080166s
# Epoch 36/40, Loss: 1.0400, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.2819134439341724s
# Epoch 37/40, Loss: 1.0399, Val Accuracy: 41.91%
# Elapsed time on CPU: 0.0h 0.0m 2.282354705967009s
# Epoch 38/40, Loss: 1.0388, Val Accuracy: 42.04%
# Elapsed time on CPU: 0.0h 0.0m 2.2867378210648894s
# Epoch 39/40, Loss: 1.0402, Val Accuracy: 41.91%
# Elapsed time on CPU: 0.0h 0.0m 2.2993396897800267s
# Epoch 40/40, Loss: 1.0396, Val Accuracy: 42.04%
# Total Train time: 0.0h 11.0m 35s
# Elapsed time on CPU: 0.0h 0.0m 2.3330703247338533s
# Test Accuracy: 42.80%
# Train time: 0.0h 11.0m 37s
# Final Validation Accuracy: 42.80%
# ----------------------------------------------------------
# 실험 2 시작
# Selected Feature: ['Music', 'Travel', 'Real Estate']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2416, np.int64(2): 2413, np.int64(1): 2413})
# train: 5793, valid: 1449
# Elapsed time on CPU: 0.0h 0.0m 2.335814395453781s
# Epoch 1/40, Loss: 1.0746, Val Accuracy: 44.86%
# New best model found at epoch 1 with accuracy: 44.86%
# Elapsed time on CPU: 0.0h 0.0m 2.1312321722507477s
# Epoch 2/40, Loss: 0.9974, Val Accuracy: 46.72%
# New best model found at epoch 2 with accuracy: 46.72%
# Elapsed time on CPU: 0.0h 0.0m 2.1648708381690085s
# Epoch 3/40, Loss: 0.9831, Val Accuracy: 47.41%
# New best model found at epoch 3 with accuracy: 47.41%
# Elapsed time on CPU: 0.0h 0.0m 2.0901487921364605s
# Epoch 4/40, Loss: 0.9769, Val Accuracy: 47.76%
# New best model found at epoch 4 with accuracy: 47.76%
# Elapsed time on CPU: 0.0h 0.0m 2.1974630248732865s
# Epoch 5/40, Loss: 0.9784, Val Accuracy: 47.83%
# New best model found at epoch 5 with accuracy: 47.83%
# Elapsed time on CPU: 0.0h 0.0m 2.1941945301368833s
# Epoch 6/40, Loss: 0.9685, Val Accuracy: 47.34%
# Elapsed time on CPU: 0.0h 0.0m 2.1432330729439855s
# Epoch 7/40, Loss: 0.9681, Val Accuracy: 47.69%
# Elapsed time on CPU: 0.0h 0.0m 2.1800423399545252s
# Epoch 8/40, Loss: 0.9620, Val Accuracy: 47.83%
# Elapsed time on CPU: 0.0h 0.0m 2.12202051281929s
# Epoch 9/40, Loss: 0.9652, Val Accuracy: 47.55%
# Elapsed time on CPU: 0.0h 0.0m 2.096318401861936s
# Epoch 10/40, Loss: 0.9619, Val Accuracy: 47.83%
# Elapsed time on CPU: 0.0h 0.0m 2.104459394235164s
# Epoch 11/40, Loss: 0.9624, Val Accuracy: 47.76%
# Elapsed time on CPU: 0.0h 0.0m 2.1130157448351383s
# Epoch 12/40, Loss: 0.9574, Val Accuracy: 47.27%
# Elapsed time on CPU: 0.0h 0.0m 2.1069688010029495s
# Epoch 13/40, Loss: 0.9596, Val Accuracy: 47.83%
# Elapsed time on CPU: 0.0h 0.0m 2.1184807401150465s
# Epoch 14/40, Loss: 0.9565, Val Accuracy: 47.20%
# Elapsed time on CPU: 0.0h 0.0m 2.1018820479512215s
# Epoch 15/40, Loss: 0.9602, Val Accuracy: 47.34%
# Elapsed time on CPU: 0.0h 0.0m 2.1282718470320106s
# Epoch 16/40, Loss: 0.9550, Val Accuracy: 47.83%
# Elapsed time on CPU: 0.0h 0.0m 2.1014721342362463s
# Epoch 17/40, Loss: 0.9574, Val Accuracy: 48.17%
# New best model found at epoch 17 with accuracy: 48.17%
# Elapsed time on CPU: 0.0h 0.0m 2.1168556110933423s
# Epoch 18/40, Loss: 0.9573, Val Accuracy: 47.83%
# Elapsed time on CPU: 0.0h 0.0m 2.1802695742808282s
# Epoch 19/40, Loss: 0.9569, Val Accuracy: 47.48%
# Elapsed time on CPU: 0.0h 0.0m 2.1114967660978436s
# Epoch 20/40, Loss: 0.9564, Val Accuracy: 47.76%
# Elapsed time on CPU: 0.0h 0.0m 2.1176729747094214s
# Epoch 21/40, Loss: 0.9534, Val Accuracy: 47.69%
# Elapsed time on CPU: 0.0h 0.0m 2.214830215089023s
# Epoch 22/40, Loss: 0.9566, Val Accuracy: 47.62%
# Elapsed time on CPU: 0.0h 0.0m 2.1125814388506114s
# Epoch 23/40, Loss: 0.9523, Val Accuracy: 47.20%
# Elapsed time on CPU: 0.0h 0.0m 2.182993968948722s
# Epoch 24/40, Loss: 0.9584, Val Accuracy: 47.62%
# Elapsed time on CPU: 0.0h 0.0m 2.1228474779054523s
# Epoch 25/40, Loss: 0.9548, Val Accuracy: 47.90%
# Elapsed time on CPU: 0.0h 0.0m 2.1214727694168687s
# Epoch 26/40, Loss: 0.9541, Val Accuracy: 47.69%
# Elapsed time on CPU: 0.0h 0.0m 2.1765206172131s
# Epoch 27/40, Loss: 0.9523, Val Accuracy: 47.34%
# Elapsed time on CPU: 0.0h 0.0m 2.172730179037899s
# Epoch 28/40, Loss: 0.9532, Val Accuracy: 47.62%
# Elapsed time on CPU: 0.0h 0.0m 2.1233580969274044s
# Epoch 29/40, Loss: 0.9583, Val Accuracy: 47.48%
# Elapsed time on CPU: 0.0h 0.0m 2.120380048174411s
# Epoch 30/40, Loss: 0.9525, Val Accuracy: 47.76%
# Elapsed time on CPU: 0.0h 0.0m 2.181673580314964s
# Epoch 31/40, Loss: 0.9530, Val Accuracy: 47.69%
# Elapsed time on CPU: 0.0h 0.0m 2.1038111089728773s
# Epoch 32/40, Loss: 0.9495, Val Accuracy: 47.62%
# Elapsed time on CPU: 0.0h 0.0m 2.186249380931258s
# Epoch 33/40, Loss: 0.9527, Val Accuracy: 47.48%
# Elapsed time on CPU: 0.0h 0.0m 2.209366518072784s
# Epoch 34/40, Loss: 0.9490, Val Accuracy: 47.48%
# Elapsed time on CPU: 0.0h 0.0m 2.134552009869367s
# Epoch 35/40, Loss: 0.9512, Val Accuracy: 47.48%
# Elapsed time on CPU: 0.0h 0.0m 2.1149480398744345s
# Epoch 36/40, Loss: 0.9481, Val Accuracy: 47.48%
# Elapsed time on CPU: 0.0h 0.0m 2.103631528094411s
# Epoch 37/40, Loss: 0.9520, Val Accuracy: 47.62%
# Elapsed time on CPU: 0.0h 0.0m 2.2205686732195318s
# Epoch 38/40, Loss: 0.9510, Val Accuracy: 47.41%
# Elapsed time on CPU: 0.0h 0.0m 2.1960826721042395s
# Epoch 39/40, Loss: 0.9507, Val Accuracy: 47.27%
# Elapsed time on CPU: 0.0h 0.0m 2.115372817032039s
# Epoch 40/40, Loss: 0.9479, Val Accuracy: 47.27%
# Total Train time: 0.0h 11.0m 37s
# Elapsed time on CPU: 0.0h 0.0m 2.2072616242803633s
# Test Accuracy: 48.17%
# Train time: 0.0h 11.0m 39s
# Final Validation Accuracy: 48.17%
# ----------------------------------------------------------
# 실험 3 시작
# Selected Feature: ['Books', 'Theater', 'Health']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2412, np.int64(1): 2409, np.int64(2): 2409})
# train: 5784, valid: 1446
# Elapsed time on CPU: 0.0h 0.0m 2.242326664272696s
# Epoch 1/40, Loss: 1.0941, Val Accuracy: 42.81%
# New best model found at epoch 1 with accuracy: 42.81%
# Elapsed time on CPU: 0.0h 0.0m 2.064572837203741s
# Epoch 2/40, Loss: 1.0162, Val Accuracy: 49.72%
# New best model found at epoch 2 with accuracy: 49.72%
# Elapsed time on CPU: 0.0h 0.0m 2.1104935370385647s
# Epoch 3/40, Loss: 1.0062, Val Accuracy: 49.10%
# Elapsed time on CPU: 0.0h 0.0m 2.0305875330232084s
# Epoch 4/40, Loss: 0.9990, Val Accuracy: 48.76%
# Elapsed time on CPU: 0.0h 0.0m 2.1677558729425073s
# Epoch 5/40, Loss: 0.9981, Val Accuracy: 50.00%
# New best model found at epoch 5 with accuracy: 50.00%
# Elapsed time on CPU: 0.0h 0.0m 2.069253835361451s
# Epoch 6/40, Loss: 0.9917, Val Accuracy: 50.41%
# New best model found at epoch 6 with accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 2.151483442168683s
# Epoch 7/40, Loss: 0.9906, Val Accuracy: 51.52%
# New best model found at epoch 7 with accuracy: 51.52%
# Elapsed time on CPU: 0.0h 0.0m 2.153321333229542s
# Epoch 8/40, Loss: 0.9874, Val Accuracy: 50.28%
# Elapsed time on CPU: 0.0h 0.0m 2.1050841039977968s
# Epoch 9/40, Loss: 0.9858, Val Accuracy: 51.66%
# New best model found at epoch 9 with accuracy: 51.66%
# Elapsed time on CPU: 0.0h 0.0m 2.1229417282156646s
# Epoch 10/40, Loss: 0.9858, Val Accuracy: 51.04%
# Elapsed time on CPU: 0.0h 0.0m 2.157324556261301s
# Epoch 11/40, Loss: 0.9812, Val Accuracy: 51.31%
# Elapsed time on CPU: 0.0h 0.0m 2.0768112391233444s
# Epoch 12/40, Loss: 0.9816, Val Accuracy: 51.45%
# Elapsed time on CPU: 0.0h 0.0m 2.1347997873090208s
# Epoch 13/40, Loss: 0.9802, Val Accuracy: 51.66%
# Elapsed time on CPU: 0.0h 0.0m 2.129650652874261s
# Epoch 14/40, Loss: 0.9794, Val Accuracy: 50.55%
# Elapsed time on CPU: 0.0h 0.0m 2.114529420156032s
# Epoch 15/40, Loss: 0.9786, Val Accuracy: 51.24%
# Elapsed time on CPU: 0.0h 0.0m 2.188278103247285s
# Epoch 16/40, Loss: 0.9768, Val Accuracy: 51.87%
# New best model found at epoch 16 with accuracy: 51.87%
# Elapsed time on CPU: 0.0h 0.0m 2.053235267754644s
# Epoch 17/40, Loss: 0.9762, Val Accuracy: 51.94%
# New best model found at epoch 17 with accuracy: 51.94%
# Elapsed time on CPU: 0.0h 0.0m 2.0635184007696807s
# Epoch 18/40, Loss: 0.9758, Val Accuracy: 51.18%
# Elapsed time on CPU: 0.0h 0.0m 2.121607065666467s
# Epoch 19/40, Loss: 0.9763, Val Accuracy: 50.28%
# Elapsed time on CPU: 0.0h 0.0m 2.0987671432085335s
# Epoch 20/40, Loss: 0.9759, Val Accuracy: 51.80%
# Elapsed time on CPU: 0.0h 0.0m 2.132390182930976s
# Epoch 21/40, Loss: 0.9744, Val Accuracy: 51.94%
# Elapsed time on CPU: 0.0h 0.0m 2.140762043185532s
# Epoch 22/40, Loss: 0.9742, Val Accuracy: 51.18%
# Elapsed time on CPU: 0.0h 0.0m 2.1303781089372933s
# Epoch 23/40, Loss: 0.9748, Val Accuracy: 50.83%
# Elapsed time on CPU: 0.0h 0.0m 2.1272018901072443s
# Epoch 24/40, Loss: 0.9742, Val Accuracy: 51.66%
# Elapsed time on CPU: 0.0h 0.0m 2.118864503223449s
# Epoch 25/40, Loss: 0.9740, Val Accuracy: 51.31%
# Elapsed time on CPU: 0.0h 0.0m 2.122725252993405s
# Epoch 26/40, Loss: 0.9732, Val Accuracy: 51.73%
# Elapsed time on CPU: 0.0h 0.0m 2.1212865319103003s
# Epoch 27/40, Loss: 0.9733, Val Accuracy: 51.38%
# Elapsed time on CPU: 0.0h 0.0m 2.122615755070001s
# Epoch 28/40, Loss: 0.9725, Val Accuracy: 50.83%
# Elapsed time on CPU: 0.0h 0.0m 2.150479221716523s
# Epoch 29/40, Loss: 0.9734, Val Accuracy: 51.45%
# Elapsed time on CPU: 0.0h 0.0m 2.1291564111597836s
# Epoch 30/40, Loss: 0.9730, Val Accuracy: 51.80%
# Elapsed time on CPU: 0.0h 0.0m 2.1127917328849435s
# Epoch 31/40, Loss: 0.9726, Val Accuracy: 51.38%
# Elapsed time on CPU: 0.0h 0.0m 2.132637167815119s
# Epoch 32/40, Loss: 0.9727, Val Accuracy: 51.45%
# Elapsed time on CPU: 0.0h 0.0m 2.1292328713461757s
# Epoch 33/40, Loss: 0.9730, Val Accuracy: 51.31%
# Elapsed time on CPU: 0.0h 0.0m 2.035190949216485s
# Epoch 34/40, Loss: 0.9725, Val Accuracy: 51.24%
# Elapsed time on CPU: 0.0h 0.0m 2.1344323442317545s
# Epoch 35/40, Loss: 0.9725, Val Accuracy: 51.04%
# Elapsed time on CPU: 0.0h 0.0m 2.131162529811263s
# Epoch 36/40, Loss: 0.9723, Val Accuracy: 51.11%
# Elapsed time on CPU: 0.0h 0.0m 2.0398068530485034s
# Epoch 37/40, Loss: 0.9725, Val Accuracy: 51.24%
# Elapsed time on CPU: 0.0h 0.0m 2.1176808211021125s
# Epoch 38/40, Loss: 0.9723, Val Accuracy: 51.24%
# Elapsed time on CPU: 0.0h 0.0m 2.124085227958858s
# Epoch 39/40, Loss: 0.9726, Val Accuracy: 51.18%
# Elapsed time on CPU: 0.0h 0.0m 2.0718721048906446s
# Epoch 40/40, Loss: 0.9722, Val Accuracy: 51.24%
# Total Train time: 0.0h 11.0m 34s
# Elapsed time on CPU: 0.0h 0.0m 2.142204403411597s
# Test Accuracy: 51.94%
# Train time: 0.0h 11.0m 36s
# Final Validation Accuracy: 51.94%
# ----------------------------------------------------------
# 실험 4 시작
# Selected Feature: ['Sports', 'Science', 'Food']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(2): 2407, np.int64(1): 2387, np.int64(0): 2385})
# train: 5743, valid: 1436
# Elapsed time on CPU: 0.0h 0.0m 2.1221600202843547s
# Epoch 1/40, Loss: 1.1001, Val Accuracy: 41.64%
# New best model found at epoch 1 with accuracy: 41.64%
# Elapsed time on CPU: 0.0h 0.0m 2.1150990929454565s
# Epoch 2/40, Loss: 1.0753, Val Accuracy: 41.50%
# Elapsed time on CPU: 0.0h 0.0m 2.1314043179154396s
# Epoch 3/40, Loss: 1.0712, Val Accuracy: 41.16%
# Elapsed time on CPU: 0.0h 0.0m 2.1125157228671014s
# Epoch 4/40, Loss: 1.0679, Val Accuracy: 41.23%
# Elapsed time on CPU: 0.0h 0.0m 2.1254810839891434s
# Epoch 5/40, Loss: 1.0688, Val Accuracy: 41.85%
# New best model found at epoch 5 with accuracy: 41.85%
# Elapsed time on CPU: 0.0h 0.0m 2.1498867203481495s
# Epoch 6/40, Loss: 1.0644, Val Accuracy: 40.60%
# Elapsed time on CPU: 0.0h 0.0m 2.21221044100821s
# Epoch 7/40, Loss: 1.0612, Val Accuracy: 40.46%
# Elapsed time on CPU: 0.0h 0.0m 2.133980239741504s
# Epoch 8/40, Loss: 1.0601, Val Accuracy: 42.41%
# New best model found at epoch 8 with accuracy: 42.41%
# Elapsed time on CPU: 0.0h 0.0m 2.21503072604537s
# Epoch 9/40, Loss: 1.0600, Val Accuracy: 41.99%
# Elapsed time on CPU: 0.0h 0.0m 2.220767649356276s
# Epoch 10/40, Loss: 1.0588, Val Accuracy: 42.27%
# Elapsed time on CPU: 0.0h 0.0m 2.223994460888207s
# Epoch 11/40, Loss: 1.0567, Val Accuracy: 43.73%
# New best model found at epoch 11 with accuracy: 43.73%
# Elapsed time on CPU: 0.0h 0.0m 2.223804729990661s
# Epoch 12/40, Loss: 1.0561, Val Accuracy: 43.31%
# Elapsed time on CPU: 0.0h 0.0m 2.225112175103277s
# Epoch 13/40, Loss: 1.0556, Val Accuracy: 43.66%
# Elapsed time on CPU: 0.0h 0.0m 2.210808162111789s
# Epoch 14/40, Loss: 1.0540, Val Accuracy: 44.29%
# New best model found at epoch 14 with accuracy: 44.29%
# Elapsed time on CPU: 0.0h 0.0m 2.247936606872827s
# Epoch 15/40, Loss: 1.0560, Val Accuracy: 43.59%
# Elapsed time on CPU: 0.0h 0.0m 2.1403946233913302s
# Epoch 16/40, Loss: 1.0545, Val Accuracy: 44.50%
# New best model found at epoch 16 with accuracy: 44.50%
# Elapsed time on CPU: 0.0h 0.0m 2.218274842016399s
# Epoch 17/40, Loss: 1.0534, Val Accuracy: 44.22%
# Elapsed time on CPU: 0.0h 0.0m 2.210812706965953s
# Epoch 18/40, Loss: 1.0537, Val Accuracy: 44.29%
# Elapsed time on CPU: 0.0h 0.0m 2.214981093071401s
# Epoch 19/40, Loss: 1.0531, Val Accuracy: 43.94%
# Elapsed time on CPU: 0.0h 0.0m 2.2185865179635584s
# Epoch 20/40, Loss: 1.0530, Val Accuracy: 43.73%
# Elapsed time on CPU: 0.0h 0.0m 2.2341072019189596s
# Epoch 21/40, Loss: 1.0525, Val Accuracy: 44.08%
# Elapsed time on CPU: 0.0h 0.0m 2.241406072396785s
# Epoch 22/40, Loss: 1.0520, Val Accuracy: 44.43%
# Elapsed time on CPU: 0.0h 0.0m 2.2195570436306298s
# Epoch 23/40, Loss: 1.0520, Val Accuracy: 44.01%
# Elapsed time on CPU: 0.0h 0.0m 2.227854708209634s
# Epoch 24/40, Loss: 1.0520, Val Accuracy: 44.08%
# Elapsed time on CPU: 0.0h 0.0m 2.2090436932630837s
# Epoch 25/40, Loss: 1.0518, Val Accuracy: 44.22%
# Elapsed time on CPU: 0.0h 0.0m 2.2128165564499795s
# Epoch 26/40, Loss: 1.0512, Val Accuracy: 44.01%
# Elapsed time on CPU: 0.0h 0.0m 2.2349214078858495s
# Epoch 27/40, Loss: 1.0513, Val Accuracy: 44.29%
# Elapsed time on CPU: 0.0h 0.0m 2.225364414975047s
# Epoch 28/40, Loss: 1.0514, Val Accuracy: 44.01%
# Elapsed time on CPU: 0.0h 0.0m 2.258214643690735s
# Epoch 29/40, Loss: 1.0514, Val Accuracy: 44.01%
# Elapsed time on CPU: 0.0h 0.0m 2.209357764106244s
# Epoch 30/40, Loss: 1.0509, Val Accuracy: 44.29%
# Elapsed time on CPU: 0.0h 0.0m 2.206177140120417s
# Epoch 31/40, Loss: 1.0508, Val Accuracy: 44.36%
# Elapsed time on CPU: 0.0h 0.0m 2.2153053148649633s
# Epoch 32/40, Loss: 1.0513, Val Accuracy: 44.43%
# Elapsed time on CPU: 0.0h 0.0m 2.2240527123212814s
# Epoch 33/40, Loss: 1.0508, Val Accuracy: 44.15%
# Elapsed time on CPU: 0.0h 0.0m 2.2091855062171817s
# Epoch 34/40, Loss: 1.0510, Val Accuracy: 44.29%
# Elapsed time on CPU: 0.0h 0.0m 2.2179660168476403s
# Epoch 35/40, Loss: 1.0507, Val Accuracy: 44.29%
# Elapsed time on CPU: 0.0h 0.0m 2.2141897520050406s
# Epoch 36/40, Loss: 1.0509, Val Accuracy: 44.36%
# Elapsed time on CPU: 0.0h 0.0m 2.235837281215936s
# Epoch 37/40, Loss: 1.0508, Val Accuracy: 44.43%
# Elapsed time on CPU: 0.0h 0.0m 2.2211072337813675s
# Epoch 38/40, Loss: 1.0504, Val Accuracy: 44.36%
# Elapsed time on CPU: 0.0h 0.0m 2.2171768988482654s
# Epoch 39/40, Loss: 1.0508, Val Accuracy: 44.15%
# Elapsed time on CPU: 0.0h 0.0m 2.2376337852329016s
# Epoch 40/40, Loss: 1.0511, Val Accuracy: 44.22%
# Total Train time: 0.0h 11.0m 34s
# Elapsed time on CPU: 0.0h 0.0m 2.21634110994637s
# Test Accuracy: 44.50%
# Train time: 0.0h 11.0m 36s
# Final Validation Accuracy: 44.50%
# ----------------------------------------------------------
# 실험 5 시작
# Selected Feature: ['Fashion & Style', 'Movies', 'Technology']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2385, np.int64(1): 2384, np.int64(2): 2376})
# train: 5716, valid: 1429
# Elapsed time on CPU: 0.0h 0.0m 2.0996651109308004s
# Epoch 1/40, Loss: 1.1005, Val Accuracy: 32.96%
# New best model found at epoch 1 with accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 2.0646979459561408s
# Epoch 2/40, Loss: 1.0832, Val Accuracy: 40.87%
# New best model found at epoch 2 with accuracy: 40.87%
# Elapsed time on CPU: 0.0h 0.0m 2.096064625773579s
# Epoch 3/40, Loss: 1.0765, Val Accuracy: 39.82%
# Elapsed time on CPU: 0.0h 0.0m 2.0740750171244144s
# Epoch 4/40, Loss: 1.0717, Val Accuracy: 41.22%
# New best model found at epoch 4 with accuracy: 41.22%
# Elapsed time on CPU: 0.0h 0.0m 2.084441495127976s
# Epoch 5/40, Loss: 1.0707, Val Accuracy: 41.29%
# New best model found at epoch 5 with accuracy: 41.29%
# Elapsed time on CPU: 0.0h 0.0m 2.0658360910601914s
# Epoch 6/40, Loss: 1.0633, Val Accuracy: 42.55%
# New best model found at epoch 6 with accuracy: 42.55%
# Elapsed time on CPU: 0.0h 0.0m 2.088567093014717s
# Epoch 7/40, Loss: 1.0617, Val Accuracy: 42.20%
# Elapsed time on CPU: 0.0h 0.0m 2.08575946604833s
# Epoch 8/40, Loss: 1.0612, Val Accuracy: 42.13%
# Elapsed time on CPU: 0.0h 0.0m 2.0732832178473473s
# Epoch 9/40, Loss: 1.0610, Val Accuracy: 42.90%
# New best model found at epoch 9 with accuracy: 42.90%
# Elapsed time on CPU: 0.0h 0.0m 2.06593962199986s
# Epoch 10/40, Loss: 1.0598, Val Accuracy: 40.66%
# Elapsed time on CPU: 0.0h 0.0m 2.132712892256677s
# Epoch 11/40, Loss: 1.0589, Val Accuracy: 42.34%
# Elapsed time on CPU: 0.0h 0.0m 2.0869325040839612s
# Epoch 12/40, Loss: 1.0573, Val Accuracy: 42.76%
# Elapsed time on CPU: 0.0h 0.0m 2.072347129229456s
# Epoch 13/40, Loss: 1.0583, Val Accuracy: 42.97%
# New best model found at epoch 13 with accuracy: 42.97%
# Elapsed time on CPU: 0.0h 0.0m 2.0721143251284957s
# Epoch 14/40, Loss: 1.0576, Val Accuracy: 41.50%
# Elapsed time on CPU: 0.0h 0.0m 2.085311036091298s
# Epoch 15/40, Loss: 1.0563, Val Accuracy: 42.55%
# Elapsed time on CPU: 0.0h 0.0m 2.15932369697839s
# Epoch 16/40, Loss: 1.0559, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 2.0900903972797096s
# Epoch 17/40, Loss: 1.0554, Val Accuracy: 42.41%
# Elapsed time on CPU: 0.0h 0.0m 2.1535070301033556s
# Epoch 18/40, Loss: 1.0556, Val Accuracy: 42.76%
# Elapsed time on CPU: 0.0h 0.0m 2.0683064446784556s
# Epoch 19/40, Loss: 1.0555, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 2.1594444499351084s
# Epoch 20/40, Loss: 1.0550, Val Accuracy: 42.55%
# Elapsed time on CPU: 0.0h 0.0m 2.0849160100333393s
# Epoch 21/40, Loss: 1.0547, Val Accuracy: 42.83%
# Elapsed time on CPU: 0.0h 0.0m 2.1415187190286815s
# Epoch 22/40, Loss: 1.0544, Val Accuracy: 42.76%
# Elapsed time on CPU: 0.0h 0.0m 2.0639513609930873s
# Epoch 23/40, Loss: 1.0543, Val Accuracy: 42.62%
# Elapsed time on CPU: 0.0h 0.0m 2.228556963149458s
# Epoch 24/40, Loss: 1.0543, Val Accuracy: 42.27%
# Elapsed time on CPU: 0.0h 0.0m 2.0834155809134245s
# Epoch 25/40, Loss: 1.0540, Val Accuracy: 42.83%
# Elapsed time on CPU: 0.0h 0.0m 2.133788824081421s
# Epoch 26/40, Loss: 1.0537, Val Accuracy: 42.90%
# Elapsed time on CPU: 0.0h 0.0m 2.093465365935117s
# Epoch 27/40, Loss: 1.0536, Val Accuracy: 42.55%
# Elapsed time on CPU: 0.0h 0.0m 2.155257010832429s
# Epoch 28/40, Loss: 1.0538, Val Accuracy: 42.83%
# Elapsed time on CPU: 0.0h 0.0m 2.086654053069651s
# Epoch 29/40, Loss: 1.0537, Val Accuracy: 42.90%
# Elapsed time on CPU: 0.0h 0.0m 2.1381994849070907s
# Epoch 30/40, Loss: 1.0538, Val Accuracy: 42.62%
# Elapsed time on CPU: 0.0h 0.0m 2.072349077090621s
# Epoch 31/40, Loss: 1.0532, Val Accuracy: 42.76%
# Elapsed time on CPU: 0.0h 0.0m 2.1889162031002343s
# Epoch 32/40, Loss: 1.0534, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 2.101360509172082s
# Epoch 33/40, Loss: 1.0534, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 2.152224086225033s
# Epoch 34/40, Loss: 1.0534, Val Accuracy: 42.76%
# Elapsed time on CPU: 0.0h 0.0m 2.0842687347903848s
# Epoch 35/40, Loss: 1.0536, Val Accuracy: 42.76%
# Elapsed time on CPU: 0.0h 0.0m 2.1477744039148092s
# Epoch 36/40, Loss: 1.0531, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 2.087888462934643s
# Epoch 37/40, Loss: 1.0529, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 2.1597887510433793s
# Epoch 38/40, Loss: 1.0533, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 2.079590091947466s
# Epoch 39/40, Loss: 1.0532, Val Accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 2.177224258892238s
# Epoch 40/40, Loss: 1.0533, Val Accuracy: 42.69%
# Total Train time: 0.0h 11.0m 27s
# Elapsed time on CPU: 0.0h 0.0m 2.1604729760438204s
# Test Accuracy: 42.97%
# Train time: 0.0h 11.0m 29s
# Final Validation Accuracy: 42.97%
# ----------------------------------------------------------
# 실험 6 시작
# Selected Feature: ['Dance', 'Media', 'Style']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2365, np.int64(1): 2363, np.int64(2): 2147})
# train: 5500, valid: 1375
# Elapsed time on CPU: 0.0h 0.0m 2.054247785359621s
# Epoch 1/40, Loss: 1.0928, Val Accuracy: 44.80%
# New best model found at epoch 1 with accuracy: 44.80%
# Elapsed time on CPU: 0.0h 0.0m 2.0318443668074906s
# Epoch 2/40, Loss: 1.0394, Val Accuracy: 42.91%
# Elapsed time on CPU: 0.0h 0.0m 2.0074602528475225s
# Epoch 3/40, Loss: 1.0252, Val Accuracy: 46.40%
# New best model found at epoch 3 with accuracy: 46.40%
# Elapsed time on CPU: 0.0h 0.0m 1.9666199060156941s
# Epoch 4/40, Loss: 1.0355, Val Accuracy: 46.62%
# New best model found at epoch 4 with accuracy: 46.62%
# Elapsed time on CPU: 0.0h 0.0m 1.9335561599582434s
# Epoch 5/40, Loss: 1.0206, Val Accuracy: 45.60%
# Elapsed time on CPU: 0.0h 0.0m 1.9577262829989195s
# Epoch 6/40, Loss: 1.0151, Val Accuracy: 45.67%
# Elapsed time on CPU: 0.0h 0.0m 1.985323770903051s
# Epoch 7/40, Loss: 1.0138, Val Accuracy: 46.91%
# New best model found at epoch 7 with accuracy: 46.91%
# Elapsed time on CPU: 0.0h 0.0m 1.9676930401474237s
# Epoch 8/40, Loss: 1.0120, Val Accuracy: 46.11%
# Elapsed time on CPU: 0.0h 0.0m 1.959013869985938s
# Epoch 9/40, Loss: 1.0118, Val Accuracy: 47.78%
# New best model found at epoch 9 with accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 1.9825937887653708s
# Epoch 10/40, Loss: 1.0107, Val Accuracy: 46.76%
# Elapsed time on CPU: 0.0h 0.0m 1.9788116980344057s
# Epoch 11/40, Loss: 1.0090, Val Accuracy: 47.20%
# Elapsed time on CPU: 0.0h 0.0m 1.9675362640991807s
# Epoch 12/40, Loss: 1.0082, Val Accuracy: 47.35%
# Elapsed time on CPU: 0.0h 0.0m 2.0601803520694375s
# Epoch 13/40, Loss: 1.0078, Val Accuracy: 47.13%
# Elapsed time on CPU: 0.0h 0.0m 1.9827517997473478s
# Epoch 14/40, Loss: 1.0081, Val Accuracy: 46.62%
# Elapsed time on CPU: 0.0h 0.0m 1.9436468570493162s
# Epoch 15/40, Loss: 1.0075, Val Accuracy: 47.49%
# Elapsed time on CPU: 0.0h 0.0m 1.9853361221030354s
# Epoch 16/40, Loss: 1.0061, Val Accuracy: 47.20%
# Elapsed time on CPU: 0.0h 0.0m 1.9589989348314703s
# Epoch 17/40, Loss: 1.0058, Val Accuracy: 47.56%
# Elapsed time on CPU: 0.0h 0.0m 1.9630328849889338s
# Epoch 18/40, Loss: 1.0057, Val Accuracy: 47.20%
# Elapsed time on CPU: 0.0h 0.0m 1.9594568121246994s
# Epoch 19/40, Loss: 1.0059, Val Accuracy: 47.35%
# Elapsed time on CPU: 0.0h 0.0m 1.9439844307489693s
# Epoch 20/40, Loss: 1.0060, Val Accuracy: 47.56%
# Elapsed time on CPU: 0.0h 0.0m 2.0539185497909784s
# Epoch 21/40, Loss: 1.0051, Val Accuracy: 47.49%
# Elapsed time on CPU: 0.0h 0.0m 1.9419348849914968s
# Epoch 22/40, Loss: 1.0050, Val Accuracy: 46.76%
# Elapsed time on CPU: 0.0h 0.0m 1.9376366729848087s
# Epoch 23/40, Loss: 1.0049, Val Accuracy: 47.42%
# Elapsed time on CPU: 0.0h 0.0m 2.0567917646840215s
# Epoch 24/40, Loss: 1.0046, Val Accuracy: 47.64%
# Elapsed time on CPU: 0.0h 0.0m 2.0824735518544912s
# Epoch 25/40, Loss: 1.0049, Val Accuracy: 47.20%
# Elapsed time on CPU: 0.0h 0.0m 1.9500692058354616s
# Epoch 26/40, Loss: 1.0044, Val Accuracy: 47.27%
# Elapsed time on CPU: 0.0h 0.0m 2.0238838219083846s
# Epoch 27/40, Loss: 1.0044, Val Accuracy: 46.84%
# Elapsed time on CPU: 0.0h 0.0m 1.923737262841314s
# Epoch 28/40, Loss: 1.0045, Val Accuracy: 47.20%
# Elapsed time on CPU: 0.0h 0.0m 2.0305848461575806s
# Epoch 29/40, Loss: 1.0042, Val Accuracy: 47.13%
# Elapsed time on CPU: 0.0h 0.0m 1.9644725089892745s
# Epoch 30/40, Loss: 1.0042, Val Accuracy: 47.05%
# Elapsed time on CPU: 0.0h 0.0m 1.9589949883520603s
# Epoch 31/40, Loss: 1.0041, Val Accuracy: 46.98%
# Elapsed time on CPU: 0.0h 0.0m 1.950883616693318s
# Epoch 32/40, Loss: 1.0041, Val Accuracy: 47.05%
# Elapsed time on CPU: 0.0h 0.0m 1.9582963939756155s
# Epoch 33/40, Loss: 1.0041, Val Accuracy: 46.91%
# Elapsed time on CPU: 0.0h 0.0m 1.967915616929531s
# Epoch 34/40, Loss: 1.0040, Val Accuracy: 46.98%
# Elapsed time on CPU: 0.0h 0.0m 1.9701428720727563s
# Epoch 35/40, Loss: 1.0041, Val Accuracy: 46.98%
# Elapsed time on CPU: 0.0h 0.0m 2.003817251417786s
# Epoch 36/40, Loss: 1.0038, Val Accuracy: 46.84%
# Elapsed time on CPU: 0.0h 0.0m 1.971765133086592s
# Epoch 37/40, Loss: 1.0039, Val Accuracy: 46.98%
# Elapsed time on CPU: 0.0h 0.0m 1.9864492160268128s
# Epoch 38/40, Loss: 1.0038, Val Accuracy: 46.98%
# Elapsed time on CPU: 0.0h 0.0m 1.9777218769304454s
# Epoch 39/40, Loss: 1.0039, Val Accuracy: 46.91%
# Elapsed time on CPU: 0.0h 0.0m 1.981719755101949s
# Epoch 40/40, Loss: 1.0038, Val Accuracy: 46.98%
# Total Train time: 0.0h 10.0m 59s
# Elapsed time on CPU: 0.0h 0.0m 2.0224639838561416s
# Test Accuracy: 47.78%
# Train time: 0.0h 11.0m 1s
# Final Validation Accuracy: 47.78%
# ----------------------------------------------------------
