# %% [markdown]
# # Setting

# %%
import os
import glob
import random
import time
import torch
import torch.nn as nn
import torch.optim as optim
import pickle
import copy, math

import torch.nn.functional as F
from torch.nn.modules.utils import _pair
from torch.nn.parameter import Parameter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from collections import Counter
from sklearn.preprocessing import LabelEncoder

from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

import torchvision.transforms as T

from models.shared_perceiver import crop, patchify, get_patch_coords, ImageDataset, PerceiverBlock, Perceiver

# %%
def seed_everything(seed):
    torch.manual_seed(seed) #torch를 거치는 모든 난수들의 생성순서를 고정한다
    torch.cuda.manual_seed(seed) #cuda를 사용하는 메소드들의 난수시드는 따로 고정해줘야한다 
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True #딥러닝에 특화된 CuDNN의 난수시드도 고정 
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed) #numpy를 사용할 경우 고정
    random.seed(seed) #파이썬 자체 모듈 random 모듈의 시드 고정

def seed_worker(worker_id): #데이터로더 난수고정
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

seed_everything(42)
g = torch.Generator()
g.manual_seed(42)
NUM_WORKERS = 4 # 서브프로세스관리자 수. 난수생성과 관련있습니다. 일단은 4로 고정합니다.

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# # Functions

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, epochs, device, scheduler=None):
    best_model = None 
    best_val_score = 0
    model.train()
    train_losses = []
    val_accuracies = []
    start = time.perf_counter()
    
    for epoch in range(epochs):
        total_loss = 0.0
        for images, labels in train_loader:
            # GPU로 옮기기
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        accuracy = evaluate_model(model, valid_loader, device=device, log_results=False)
        val_accuracies.append(accuracy)

        # Scheduler step 추가
        if scheduler:
            scheduler.step()

        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}, Val Accuracy: {accuracy:.2f}%")
        if accuracy > best_val_score:
            best_val_score = accuracy
            best_model_state = model.state_dict()  # 모델 상태 저장
            best_model = copy.deepcopy(model) 
            print(f"New best model found at epoch {epoch+1} with accuracy: {best_val_score:.2f}%")

    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Total Train time: {hour}h {min}m {sec}s")

    return train_losses, val_accuracies, best_model

def evaluate_model(model, data_loader, device, log_results=True):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        start = time.perf_counter()
        for images, labels in data_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        end = time.perf_counter()
        hour = (end-start) // 3600
        min = ((end-start) % 3600) // 60
        sec = (end-start) % 60
        print(f"Elapsed time on CPU: {hour}h {min}m {sec}s")

    accuracy = 100.0 * correct / total
    if log_results:
        print(f"Test Accuracy: {accuracy:.2f}%")
    return accuracy

# %% [markdown]
# # Load Model

# %%
data_dir = '/home/youlee/n24news/n24news/image'
crop_size = 0
patch_size = 16
batch_size = 32
epochs = 40
group_class = 3
LR = 2e-5

# %%
#random.shuffle(target_classes)
target_classes = [ # 임의로 순서지정
    "Opinion", "Art & Design", "Television",
    "Music", "Travel", "Real Estate",
    "Books", "Theater", "Health",
    "Sports", "Science", "Food",
    "Fashion & Style", "Movies", "Technology",
    "Dance", "Media", "Style"
]
target_classes
# Out:
# ['Opinion',
#  'Art & Design',
#  'Television',
#  'Music',
#  'Travel',
#  'Real Estate',
#  'Books',
#  'Theater',
#  'Health',
#  'Sports',
#  'Science',
#  'Food',
#  'Fashion & Style',
#  'Movies',
#  'Technology',
#  'Dance',
#  'Media',
#  'Style']

# %%
output_path = '/home/Minju/Perceiver/shared_layer_model'
loader_path = '/home/Minju/Perceiver/shared_layer_loader'
group_class
# Out:
# 3

# %% [markdown]
# # Train Loop

# %%
for i in range(0, len(target_classes), group_class):  
    print(f"실험 {i//group_class + 1} 시작")
    selected_classes = target_classes[i:i+group_class]
    print(f"Selected Feature: {selected_classes}")

    filtered_dataset = ImageDataset(root_dir=data_dir, 
                                    transform=transform, 
                                    crop_size=crop_size, 
                                    patch_size=patch_size,
                                    selected_classes=selected_classes)
    all_labels = [label_idx for (_, label_idx) in filtered_dataset.data]

    # 1) 유니크 라벨과 개수
    unique_label_ids = np.unique(all_labels)
    print("Unique numeric labels:", unique_label_ids)
    print("Number of unique numeric labels:", len(unique_label_ids))

    # 2) 라벨별 개수 (분포)
    label_counts = Counter(all_labels)
    print("Label distribution (index: count):", label_counts)
    
    train_ratio = 0.8
    train_size = int(len(filtered_dataset) * train_ratio)
    valid_size = len(filtered_dataset) - train_size

    train_dataset, valid_dataset = random_split(filtered_dataset, [train_size, valid_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
                              num_workers=NUM_WORKERS, worker_init_fn=seed_worker, generator=g)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,
                              num_workers=NUM_WORKERS, worker_init_fn=seed_worker, generator=g)

    print(f"train: {train_size}, valid: {valid_size}")
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    NUM_CLASSES = len(filtered_dataset.label_encoder.classes_)
    model = Perceiver(input_dim=(patch_size**2) * 3 + 2,
                        latent_dim=64, 
                        latent_size=64, 
                        num_classes=NUM_CLASSES, 
                        num_blocks=4, 
                        self_attn_layers_per_block=10).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)  # Learning rate decay 추가

    start = time.perf_counter()
    train_losses, val_accuracies, best_model = train_model(
        model, train_loader, valid_loader,
        criterion, optimizer, epochs,
        device=device,
        scheduler=scheduler  
    )
    
    final_acc = evaluate_model(best_model, valid_loader, device=device, log_results=True)
    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Train time: {hour}h {min}m {sec}s")
    print(f"Final Validation Accuracy: {final_acc:.2f}%")
    print("----------------------------------------------------------")
    
    torch.save(best_model, f'{output_path}/image_model_{i//group_class+1}.pkl')

    val_loader_save_path = f"{loader_path}/image_val_loader_{i//group_class+1}.pkl"
    with open(val_loader_save_path, 'wb') as f:
        pickle.dump(valid_dataset, f)
# Out:
# 실험 1 시작
# Selected Feature: ['Opinion', 'Art & Design', 'Television']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(1): 2437, np.int64(0): 2431, np.int64(2): 2419})
# train: 5829, valid: 1458
# Elapsed time on CPU: 0.0h 0.0m 2.10690785292536s
# Epoch 1/40, Loss: 1.0969, Val Accuracy: 43.76%
# New best model found at epoch 1 with accuracy: 43.76%
# Elapsed time on CPU: 0.0h 0.0m 2.0686081619933248s
# Epoch 2/40, Loss: 1.0582, Val Accuracy: 42.94%
# Elapsed time on CPU: 0.0h 0.0m 2.0779803548939526s
# Epoch 3/40, Loss: 1.0484, Val Accuracy: 42.18%
# Elapsed time on CPU: 0.0h 0.0m 2.2319362338166684s
# Epoch 4/40, Loss: 1.0473, Val Accuracy: 42.25%
# Elapsed time on CPU: 0.0h 0.0m 2.2381216201465577s
# Epoch 5/40, Loss: 1.0473, Val Accuracy: 41.98%
# Elapsed time on CPU: 0.0h 0.0m 2.2419274640269578s
# Epoch 6/40, Loss: 1.0459, Val Accuracy: 42.32%
# Elapsed time on CPU: 0.0h 0.0m 2.244501342996955s
# Epoch 7/40, Loss: 1.0454, Val Accuracy: 43.35%
# Elapsed time on CPU: 0.0h 0.0m 2.293200559914112s
# Epoch 8/40, Loss: 1.0439, Val Accuracy: 42.87%
# Elapsed time on CPU: 0.0h 0.0m 2.2667743910569698s
# Epoch 9/40, Loss: 1.0431, Val Accuracy: 41.70%
# Elapsed time on CPU: 0.0h 0.0m 2.238535505020991s
# Epoch 10/40, Loss: 1.0431, Val Accuracy: 42.52%
# Elapsed time on CPU: 0.0h 0.0m 2.269387531094253s
# Epoch 11/40, Loss: 1.0420, Val Accuracy: 42.52%
# Elapsed time on CPU: 0.0h 0.0m 2.2687895908020437s
# Epoch 12/40, Loss: 1.0423, Val Accuracy: 43.35%
# Elapsed time on CPU: 0.0h 0.0m 2.345749015919864s
# Epoch 13/40, Loss: 1.0411, Val Accuracy: 42.66%
# Elapsed time on CPU: 0.0h 0.0m 2.343146341154352s
# Epoch 14/40, Loss: 1.0389, Val Accuracy: 43.55%
# Elapsed time on CPU: 0.0h 0.0m 2.341205158038065s
# Epoch 15/40, Loss: 1.0402, Val Accuracy: 43.55%
# Elapsed time on CPU: 0.0h 0.0m 2.3776353041175753s
# Epoch 16/40, Loss: 1.0380, Val Accuracy: 43.28%
# Elapsed time on CPU: 0.0h 0.0m 2.347172597888857s
# Epoch 17/40, Loss: 1.0356, Val Accuracy: 43.62%
# Elapsed time on CPU: 0.0h 0.0m 2.3885502701159567s
# Epoch 18/40, Loss: 1.0356, Val Accuracy: 44.31%
# New best model found at epoch 18 with accuracy: 44.31%
# Elapsed time on CPU: 0.0h 0.0m 2.411144308047369s
# Epoch 19/40, Loss: 1.0355, Val Accuracy: 44.03%
# Elapsed time on CPU: 0.0h 0.0m 2.354944152990356s
# Epoch 20/40, Loss: 1.0346, Val Accuracy: 44.92%
# New best model found at epoch 20 with accuracy: 44.92%
# Elapsed time on CPU: 0.0h 0.0m 2.3253936108667403s
# Epoch 21/40, Loss: 1.0333, Val Accuracy: 44.38%
# Elapsed time on CPU: 0.0h 0.0m 2.358976843068376s
# Epoch 22/40, Loss: 1.0331, Val Accuracy: 45.06%
# New best model found at epoch 22 with accuracy: 45.06%
# Elapsed time on CPU: 0.0h 0.0m 2.3657875768840313s
# Epoch 23/40, Loss: 1.0327, Val Accuracy: 44.65%
# Elapsed time on CPU: 0.0h 0.0m 2.4322507188189775s
# Epoch 24/40, Loss: 1.0326, Val Accuracy: 44.92%
# Elapsed time on CPU: 0.0h 0.0m 2.3594189069699496s
# Epoch 25/40, Loss: 1.0316, Val Accuracy: 45.34%
# New best model found at epoch 25 with accuracy: 45.34%
# Elapsed time on CPU: 0.0h 0.0m 2.394380731973797s
# Epoch 26/40, Loss: 1.0307, Val Accuracy: 44.92%
# Elapsed time on CPU: 0.0h 0.0m 2.380024803103879s
# Epoch 27/40, Loss: 1.0318, Val Accuracy: 44.99%
# Elapsed time on CPU: 0.0h 0.0m 2.382933982880786s
# Epoch 28/40, Loss: 1.0310, Val Accuracy: 45.75%
# New best model found at epoch 28 with accuracy: 45.75%
# Elapsed time on CPU: 0.0h 0.0m 2.4008692030329257s
# Epoch 29/40, Loss: 1.0312, Val Accuracy: 44.86%
# Elapsed time on CPU: 0.0h 0.0m 2.353703906061128s
# Epoch 30/40, Loss: 1.0316, Val Accuracy: 45.27%
# Elapsed time on CPU: 0.0h 0.0m 2.3352573451120406s
# Epoch 31/40, Loss: 1.0299, Val Accuracy: 44.99%
# Elapsed time on CPU: 0.0h 0.0m 2.3535434510558844s
# Epoch 32/40, Loss: 1.0290, Val Accuracy: 45.34%
# Elapsed time on CPU: 0.0h 0.0m 2.4113825750537217s
# Epoch 33/40, Loss: 1.0292, Val Accuracy: 44.99%
# Elapsed time on CPU: 0.0h 0.0m 2.345918382052332s
# Epoch 34/40, Loss: 1.0298, Val Accuracy: 45.20%
# Elapsed time on CPU: 0.0h 0.0m 2.4146981469821185s
# Epoch 35/40, Loss: 1.0291, Val Accuracy: 45.20%
# Elapsed time on CPU: 0.0h 0.0m 2.332382765831426s
# Epoch 36/40, Loss: 1.0292, Val Accuracy: 45.34%
# Elapsed time on CPU: 0.0h 0.0m 2.4319683688227087s
# Epoch 37/40, Loss: 1.0293, Val Accuracy: 45.40%
# Elapsed time on CPU: 0.0h 0.0m 2.4228060769382864s
# Epoch 38/40, Loss: 1.0284, Val Accuracy: 45.40%
# Elapsed time on CPU: 0.0h 0.0m 2.4076779619790614s
# Epoch 39/40, Loss: 1.0300, Val Accuracy: 45.47%
# Elapsed time on CPU: 0.0h 0.0m 2.418163594091311s
# Epoch 40/40, Loss: 1.0295, Val Accuracy: 45.40%
# Total Train time: 0.0h 11.0m 58s
# Elapsed time on CPU: 0.0h 0.0m 2.418066445970908s
# Test Accuracy: 45.75%
# Train time: 0.0h 12.0m 0s
# Final Validation Accuracy: 45.75%
# ----------------------------------------------------------
# 실험 2 시작
# Selected Feature: ['Music', 'Travel', 'Real Estate']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2416, np.int64(2): 2413, np.int64(1): 2413})
# train: 5793, valid: 1449
# Elapsed time on CPU: 0.0h 0.0m 2.2717031489592046s
# Epoch 1/40, Loss: 1.0839, Val Accuracy: 47.00%
# New best model found at epoch 1 with accuracy: 47.00%
# Elapsed time on CPU: 0.0h 0.0m 2.2674992359243333s
# Epoch 2/40, Loss: 0.9941, Val Accuracy: 47.14%
# New best model found at epoch 2 with accuracy: 47.14%
# Elapsed time on CPU: 0.0h 0.0m 2.3134622068610042s
# Epoch 3/40, Loss: 0.9833, Val Accuracy: 48.17%
# New best model found at epoch 3 with accuracy: 48.17%
# Elapsed time on CPU: 0.0h 0.0m 2.3014303708914667s
# Epoch 4/40, Loss: 0.9773, Val Accuracy: 48.24%
# New best model found at epoch 4 with accuracy: 48.24%
# Elapsed time on CPU: 0.0h 0.0m 2.327617332106456s
# Epoch 5/40, Loss: 0.9805, Val Accuracy: 47.55%
# Elapsed time on CPU: 0.0h 0.0m 2.3093737920280546s
# Epoch 6/40, Loss: 0.9711, Val Accuracy: 48.45%
# New best model found at epoch 6 with accuracy: 48.45%
# Elapsed time on CPU: 0.0h 0.0m 2.236683244118467s
# Epoch 7/40, Loss: 0.9708, Val Accuracy: 48.45%
# Elapsed time on CPU: 0.0h 0.0m 2.309037343133241s
# Epoch 8/40, Loss: 0.9659, Val Accuracy: 48.38%
# Elapsed time on CPU: 0.0h 0.0m 2.2277472661808133s
# Epoch 9/40, Loss: 0.9685, Val Accuracy: 48.59%
# New best model found at epoch 9 with accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.318670003907755s
# Epoch 10/40, Loss: 0.9649, Val Accuracy: 47.55%
# Elapsed time on CPU: 0.0h 0.0m 2.3016310930252075s
# Epoch 11/40, Loss: 0.9654, Val Accuracy: 48.45%
# Elapsed time on CPU: 0.0h 0.0m 2.297719769878313s
# Epoch 12/40, Loss: 0.9613, Val Accuracy: 48.65%
# New best model found at epoch 12 with accuracy: 48.65%
# Elapsed time on CPU: 0.0h 0.0m 2.304410867858678s
# Epoch 13/40, Loss: 0.9630, Val Accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.234848997090012s
# Epoch 14/40, Loss: 0.9603, Val Accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.2196593310218304s
# Epoch 15/40, Loss: 0.9630, Val Accuracy: 48.52%
# Elapsed time on CPU: 0.0h 0.0m 2.244812733028084s
# Epoch 16/40, Loss: 0.9591, Val Accuracy: 48.65%
# Elapsed time on CPU: 0.0h 0.0m 2.2468122360296547s
# Epoch 17/40, Loss: 0.9617, Val Accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.305136030074209s
# Epoch 18/40, Loss: 0.9612, Val Accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.2254702940117568s
# Epoch 19/40, Loss: 0.9607, Val Accuracy: 48.52%
# Elapsed time on CPU: 0.0h 0.0m 2.304929898818955s
# Epoch 20/40, Loss: 0.9603, Val Accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.2315657888539135s
# Epoch 21/40, Loss: 0.9575, Val Accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.2362688269931823s
# Epoch 22/40, Loss: 0.9606, Val Accuracy: 48.65%
# Elapsed time on CPU: 0.0h 0.0m 2.228290688013658s
# Epoch 23/40, Loss: 0.9573, Val Accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.246627864893526s
# Epoch 24/40, Loss: 0.9630, Val Accuracy: 48.59%
# Elapsed time on CPU: 0.0h 0.0m 2.3078291669953614s
# Epoch 25/40, Loss: 0.9607, Val Accuracy: 48.52%
# Elapsed time on CPU: 0.0h 0.0m 2.236577064031735s
# Epoch 26/40, Loss: 0.9605, Val Accuracy: 48.52%
# Elapsed time on CPU: 0.0h 0.0m 2.2363044950179756s
# Epoch 27/40, Loss: 0.9590, Val Accuracy: 48.72%
# New best model found at epoch 27 with accuracy: 48.72%
# Elapsed time on CPU: 0.0h 0.0m 2.2344042509794235s
# Epoch 28/40, Loss: 0.9600, Val Accuracy: 48.86%
# New best model found at epoch 28 with accuracy: 48.86%
# Elapsed time on CPU: 0.0h 0.0m 2.2169939528685063s
# Epoch 29/40, Loss: 0.9655, Val Accuracy: 48.72%
# Elapsed time on CPU: 0.0h 0.0m 2.3067511620465666s
# Epoch 30/40, Loss: 0.9602, Val Accuracy: 48.72%
# Elapsed time on CPU: 0.0h 0.0m 2.31423758296296s
# Epoch 31/40, Loss: 0.9601, Val Accuracy: 48.79%
# Elapsed time on CPU: 0.0h 0.0m 2.326249656965956s
# Epoch 32/40, Loss: 0.9566, Val Accuracy: 48.72%
# Elapsed time on CPU: 0.0h 0.0m 2.237982515944168s
# Epoch 33/40, Loss: 0.9603, Val Accuracy: 48.72%
# Elapsed time on CPU: 0.0h 0.0m 2.219928080914542s
# Epoch 34/40, Loss: 0.9564, Val Accuracy: 48.79%
# Elapsed time on CPU: 0.0h 0.0m 2.2306989731732756s
# Epoch 35/40, Loss: 0.9591, Val Accuracy: 48.79%
# Elapsed time on CPU: 0.0h 0.0m 2.2218437679111958s
# Epoch 36/40, Loss: 0.9563, Val Accuracy: 48.79%
# Elapsed time on CPU: 0.0h 0.0m 2.2377761090174317s
# Epoch 37/40, Loss: 0.9597, Val Accuracy: 48.79%
# Elapsed time on CPU: 0.0h 0.0m 2.2334705530665815s
# Epoch 38/40, Loss: 0.9593, Val Accuracy: 48.79%
# Elapsed time on CPU: 0.0h 0.0m 2.235693546012044s
# Epoch 39/40, Loss: 0.9586, Val Accuracy: 48.93%
# New best model found at epoch 39 with accuracy: 48.93%
# Elapsed time on CPU: 0.0h 0.0m 2.23522890987806s
# Epoch 40/40, Loss: 0.9562, Val Accuracy: 48.72%
# Total Train time: 0.0h 11.0m 58s
# Elapsed time on CPU: 0.0h 0.0m 2.2491902229376137s
# Test Accuracy: 48.93%
# Train time: 0.0h 12.0m 0s
# Final Validation Accuracy: 48.93%
# ----------------------------------------------------------
# 실험 3 시작
# Selected Feature: ['Books', 'Theater', 'Health']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2412, np.int64(1): 2409, np.int64(2): 2409})
# train: 5784, valid: 1446
# Elapsed time on CPU: 0.0h 0.0m 2.153730296995491s
# Epoch 1/40, Loss: 1.0972, Val Accuracy: 45.44%
# New best model found at epoch 1 with accuracy: 45.44%
# Elapsed time on CPU: 0.0h 0.0m 2.171679656021297s
# Epoch 2/40, Loss: 1.0140, Val Accuracy: 50.00%
# New best model found at epoch 2 with accuracy: 50.00%
# Elapsed time on CPU: 0.0h 0.0m 2.1466837010812014s
# Epoch 3/40, Loss: 1.0023, Val Accuracy: 49.45%
# Elapsed time on CPU: 0.0h 0.0m 2.150583819951862s
# Epoch 4/40, Loss: 0.9983, Val Accuracy: 50.48%
# New best model found at epoch 4 with accuracy: 50.48%
# Elapsed time on CPU: 0.0h 0.0m 2.2331030829809606s
# Epoch 5/40, Loss: 0.9967, Val Accuracy: 49.86%
# Elapsed time on CPU: 0.0h 0.0m 2.2356458159629256s
# Epoch 6/40, Loss: 0.9937, Val Accuracy: 50.48%
# Elapsed time on CPU: 0.0h 0.0m 2.2384230790194124s
# Epoch 7/40, Loss: 0.9936, Val Accuracy: 49.45%
# Elapsed time on CPU: 0.0h 0.0m 2.1660825200378895s
# Epoch 8/40, Loss: 0.9917, Val Accuracy: 50.21%
# Elapsed time on CPU: 0.0h 0.0m 2.2458196659572423s
# Epoch 9/40, Loss: 0.9917, Val Accuracy: 49.86%
# Elapsed time on CPU: 0.0h 0.0m 2.2362527949735522s
# Epoch 10/40, Loss: 0.9920, Val Accuracy: 49.52%
# Elapsed time on CPU: 0.0h 0.0m 2.2329435381107032s
# Epoch 11/40, Loss: 0.9896, Val Accuracy: 49.59%
# Elapsed time on CPU: 0.0h 0.0m 2.23423491907306s
# Epoch 12/40, Loss: 0.9902, Val Accuracy: 49.59%
# Elapsed time on CPU: 0.0h 0.0m 2.2502243109047413s
# Epoch 13/40, Loss: 0.9898, Val Accuracy: 50.48%
# Elapsed time on CPU: 0.0h 0.0m 2.2377139378804713s
# Epoch 14/40, Loss: 0.9890, Val Accuracy: 50.55%
# New best model found at epoch 14 with accuracy: 50.55%
# Elapsed time on CPU: 0.0h 0.0m 2.2328442099969834s
# Epoch 15/40, Loss: 0.9889, Val Accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 2.1532362869475037s
# Epoch 16/40, Loss: 0.9883, Val Accuracy: 50.62%
# New best model found at epoch 16 with accuracy: 50.62%
# Elapsed time on CPU: 0.0h 0.0m 2.2444299969356507s
# Epoch 17/40, Loss: 0.9880, Val Accuracy: 50.28%
# Elapsed time on CPU: 0.0h 0.0m 2.1543240449391305s
# Epoch 18/40, Loss: 0.9881, Val Accuracy: 50.83%
# New best model found at epoch 18 with accuracy: 50.83%
# Elapsed time on CPU: 0.0h 0.0m 2.252128280000761s
# Epoch 19/40, Loss: 0.9883, Val Accuracy: 50.55%
# Elapsed time on CPU: 0.0h 0.0m 2.2320506530813873s
# Epoch 20/40, Loss: 0.9881, Val Accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 2.230267307953909s
# Epoch 21/40, Loss: 0.9875, Val Accuracy: 50.55%
# Elapsed time on CPU: 0.0h 0.0m 2.2603392768651247s
# Epoch 22/40, Loss: 0.9874, Val Accuracy: 50.90%
# New best model found at epoch 22 with accuracy: 50.90%
# Elapsed time on CPU: 0.0h 0.0m 2.233397454023361s
# Epoch 23/40, Loss: 0.9877, Val Accuracy: 50.76%
# Elapsed time on CPU: 0.0h 0.0m 2.149496559984982s
# Epoch 24/40, Loss: 0.9875, Val Accuracy: 50.21%
# Elapsed time on CPU: 0.0h 0.0m 2.2082684179767966s
# Epoch 25/40, Loss: 0.9876, Val Accuracy: 50.76%
# Elapsed time on CPU: 0.0h 0.0m 2.2319371518678963s
# Epoch 26/40, Loss: 0.9871, Val Accuracy: 50.35%
# Elapsed time on CPU: 0.0h 0.0m 2.155635453062132s
# Epoch 27/40, Loss: 0.9872, Val Accuracy: 50.90%
# Elapsed time on CPU: 0.0h 0.0m 2.252304557012394s
# Epoch 28/40, Loss: 0.9870, Val Accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 2.2363806541543454s
# Epoch 29/40, Loss: 0.9873, Val Accuracy: 50.83%
# Elapsed time on CPU: 0.0h 0.0m 2.194894172018394s
# Epoch 30/40, Loss: 0.9869, Val Accuracy: 50.28%
# Elapsed time on CPU: 0.0h 0.0m 2.2186929839663208s
# Epoch 31/40, Loss: 0.9869, Val Accuracy: 50.14%
# Elapsed time on CPU: 0.0h 0.0m 2.1658488609828055s
# Epoch 32/40, Loss: 0.9869, Val Accuracy: 50.35%
# Elapsed time on CPU: 0.0h 0.0m 2.2290181070566177s
# Epoch 33/40, Loss: 0.9872, Val Accuracy: 50.48%
# Elapsed time on CPU: 0.0h 0.0m 2.2310221469961107s
# Epoch 34/40, Loss: 0.9869, Val Accuracy: 50.62%
# Elapsed time on CPU: 0.0h 0.0m 2.1492943151388317s
# Epoch 35/40, Loss: 0.9869, Val Accuracy: 50.90%
# Elapsed time on CPU: 0.0h 0.0m 2.155928333988413s
# Epoch 36/40, Loss: 0.9867, Val Accuracy: 50.69%
# Elapsed time on CPU: 0.0h 0.0m 2.2512869050260633s
# Epoch 37/40, Loss: 0.9869, Val Accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 2.233784988988191s
# Epoch 38/40, Loss: 0.9868, Val Accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 2.1481814170256257s
# Epoch 39/40, Loss: 0.9870, Val Accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 2.2336040548980236s
# Epoch 40/40, Loss: 0.9867, Val Accuracy: 50.41%
# Total Train time: 0.0h 11.0m 56s
# Elapsed time on CPU: 0.0h 0.0m 2.239492780994624s
# Test Accuracy: 50.90%
# Train time: 0.0h 11.0m 58s
# Final Validation Accuracy: 50.90%
# ----------------------------------------------------------
# 실험 4 시작
# Selected Feature: ['Sports', 'Science', 'Food']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(2): 2407, np.int64(1): 2387, np.int64(0): 2385})
# train: 5743, valid: 1436
# Elapsed time on CPU: 0.0h 0.0m 2.3292244079057127s
# Epoch 1/40, Loss: 1.1001, Val Accuracy: 33.43%
# New best model found at epoch 1 with accuracy: 33.43%
# Elapsed time on CPU: 0.0h 0.0m 2.3197705051861703s
# Epoch 2/40, Loss: 1.0845, Val Accuracy: 43.66%
# New best model found at epoch 2 with accuracy: 43.66%
# Elapsed time on CPU: 0.0h 0.0m 2.2934972930233926s
# Epoch 3/40, Loss: 1.0633, Val Accuracy: 43.11%
# Elapsed time on CPU: 0.0h 0.0m 2.2343250759877264s
# Epoch 4/40, Loss: 1.0593, Val Accuracy: 41.64%
# Elapsed time on CPU: 0.0h 0.0m 2.237579034175724s
# Epoch 5/40, Loss: 1.0587, Val Accuracy: 43.80%
# New best model found at epoch 5 with accuracy: 43.80%
# Elapsed time on CPU: 0.0h 0.0m 2.3157556680962443s
# Epoch 6/40, Loss: 1.0553, Val Accuracy: 43.38%
# Elapsed time on CPU: 0.0h 0.0m 2.2214993750676513s
# Epoch 7/40, Loss: 1.0546, Val Accuracy: 43.31%
# Elapsed time on CPU: 0.0h 0.0m 2.3150421280879527s
# Epoch 8/40, Loss: 1.0542, Val Accuracy: 43.38%
# Elapsed time on CPU: 0.0h 0.0m 2.325981884961948s
# Epoch 9/40, Loss: 1.0537, Val Accuracy: 43.87%
# New best model found at epoch 9 with accuracy: 43.87%
# Elapsed time on CPU: 0.0h 0.0m 2.344528052955866s
# Epoch 10/40, Loss: 1.0537, Val Accuracy: 43.25%
# Elapsed time on CPU: 0.0h 0.0m 2.3203497529029846s
# Epoch 11/40, Loss: 1.0518, Val Accuracy: 44.64%
# New best model found at epoch 11 with accuracy: 44.64%
# Elapsed time on CPU: 0.0h 0.0m 2.330510603962466s
# Epoch 12/40, Loss: 1.0516, Val Accuracy: 43.59%
# Elapsed time on CPU: 0.0h 0.0m 2.3130472188349813s
# Epoch 13/40, Loss: 1.0516, Val Accuracy: 44.01%
# Elapsed time on CPU: 0.0h 0.0m 2.3394814771600068s
# Epoch 14/40, Loss: 1.0510, Val Accuracy: 44.85%
# New best model found at epoch 14 with accuracy: 44.85%
# Elapsed time on CPU: 0.0h 0.0m 2.223865196108818s
# Epoch 15/40, Loss: 1.0517, Val Accuracy: 44.43%
# Elapsed time on CPU: 0.0h 0.0m 2.2271691411733627s
# Epoch 16/40, Loss: 1.0512, Val Accuracy: 44.85%
# Elapsed time on CPU: 0.0h 0.0m 2.2400039159692824s
# Epoch 17/40, Loss: 1.0502, Val Accuracy: 44.50%
# Elapsed time on CPU: 0.0h 0.0m 2.329474420985207s
# Epoch 18/40, Loss: 1.0506, Val Accuracy: 44.43%
# Elapsed time on CPU: 0.0h 0.0m 2.3041034911293536s
# Epoch 19/40, Loss: 1.0505, Val Accuracy: 44.85%
# Elapsed time on CPU: 0.0h 0.0m 2.3363000680692494s
# Epoch 20/40, Loss: 1.0503, Val Accuracy: 44.08%
# Elapsed time on CPU: 0.0h 0.0m 2.3428638020996004s
# Epoch 21/40, Loss: 1.0503, Val Accuracy: 44.78%
# Elapsed time on CPU: 0.0h 0.0m 2.2388679410796613s
# Epoch 22/40, Loss: 1.0498, Val Accuracy: 44.71%
# Elapsed time on CPU: 0.0h 0.0m 2.2374148110393435s
# Epoch 23/40, Loss: 1.0499, Val Accuracy: 44.36%
# Elapsed time on CPU: 0.0h 0.0m 2.233440024079755s
# Epoch 24/40, Loss: 1.0501, Val Accuracy: 44.57%
# Elapsed time on CPU: 0.0h 0.0m 2.240350855048746s
# Epoch 25/40, Loss: 1.0500, Val Accuracy: 44.43%
# Elapsed time on CPU: 0.0h 0.0m 2.2516344599425793s
# Epoch 26/40, Loss: 1.0495, Val Accuracy: 44.36%
# Elapsed time on CPU: 0.0h 0.0m 2.2431072341278195s
# Epoch 27/40, Loss: 1.0497, Val Accuracy: 44.71%
# Elapsed time on CPU: 0.0h 0.0m 2.2316544430796057s
# Epoch 28/40, Loss: 1.0497, Val Accuracy: 44.64%
# Elapsed time on CPU: 0.0h 0.0m 2.233089419081807s
# Epoch 29/40, Loss: 1.0498, Val Accuracy: 44.71%
# Elapsed time on CPU: 0.0h 0.0m 2.225248344009742s
# Epoch 30/40, Loss: 1.0495, Val Accuracy: 44.85%
# Elapsed time on CPU: 0.0h 0.0m 2.230067600030452s
# Epoch 31/40, Loss: 1.0494, Val Accuracy: 44.78%
# Elapsed time on CPU: 0.0h 0.0m 2.2423690708819777s
# Epoch 32/40, Loss: 1.0499, Val Accuracy: 44.71%
# Elapsed time on CPU: 0.0h 0.0m 2.230287664802745s
# Epoch 33/40, Loss: 1.0497, Val Accuracy: 44.64%
# Elapsed time on CPU: 0.0h 0.0m 2.2323152530007064s
# Epoch 34/40, Loss: 1.0497, Val Accuracy: 44.57%
# Elapsed time on CPU: 0.0h 0.0m 2.233260372886434s
# Epoch 35/40, Loss: 1.0494, Val Accuracy: 44.78%
# Elapsed time on CPU: 0.0h 0.0m 2.332223186036572s
# Epoch 36/40, Loss: 1.0497, Val Accuracy: 44.71%
# Elapsed time on CPU: 0.0h 0.0m 2.311225443845615s
# Epoch 37/40, Loss: 1.0495, Val Accuracy: 44.64%
# Elapsed time on CPU: 0.0h 0.0m 2.231830977834761s
# Epoch 38/40, Loss: 1.0492, Val Accuracy: 44.64%
# Elapsed time on CPU: 0.0h 0.0m 2.236297874012962s
# Epoch 39/40, Loss: 1.0496, Val Accuracy: 44.57%
# Elapsed time on CPU: 0.0h 0.0m 2.239313449943438s
# Epoch 40/40, Loss: 1.0499, Val Accuracy: 44.57%
# Total Train time: 0.0h 11.0m 55s
# Elapsed time on CPU: 0.0h 0.0m 2.247988831019029s
# Test Accuracy: 44.85%
# Train time: 0.0h 11.0m 57s
# Final Validation Accuracy: 44.85%
# ----------------------------------------------------------
# 실험 5 시작
# Selected Feature: ['Fashion & Style', 'Movies', 'Technology']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2385, np.int64(1): 2384, np.int64(2): 2376})
# train: 5716, valid: 1429
# Elapsed time on CPU: 0.0h 0.0m 2.2195476389024407s
# Epoch 1/40, Loss: 1.1000, Val Accuracy: 32.96%
# New best model found at epoch 1 with accuracy: 32.96%
# Elapsed time on CPU: 0.0h 0.0m 2.2161285469774157s
# Epoch 2/40, Loss: 1.0848, Val Accuracy: 40.17%
# New best model found at epoch 2 with accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.2551749588456005s
# Epoch 3/40, Loss: 1.0780, Val Accuracy: 40.80%
# New best model found at epoch 3 with accuracy: 40.80%
# Elapsed time on CPU: 0.0h 0.0m 2.209884334122762s
# Epoch 4/40, Loss: 1.0770, Val Accuracy: 40.73%
# Elapsed time on CPU: 0.0h 0.0m 2.179545958992094s
# Epoch 5/40, Loss: 1.0768, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.1936632078140974s
# Epoch 6/40, Loss: 1.0739, Val Accuracy: 40.45%
# Elapsed time on CPU: 0.0h 0.0m 2.1889871049206704s
# Epoch 7/40, Loss: 1.0728, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.2019472708925605s
# Epoch 8/40, Loss: 1.0723, Val Accuracy: 40.59%
# Elapsed time on CPU: 0.0h 0.0m 2.1837996221147478s
# Epoch 9/40, Loss: 1.0725, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.202189579838887s
# Epoch 10/40, Loss: 1.0718, Val Accuracy: 40.73%
# Elapsed time on CPU: 0.0h 0.0m 2.1915469500236213s
# Epoch 11/40, Loss: 1.0715, Val Accuracy: 39.96%
# Elapsed time on CPU: 0.0h 0.0m 2.184535289881751s
# Epoch 12/40, Loss: 1.0715, Val Accuracy: 39.82%
# Elapsed time on CPU: 0.0h 0.0m 2.2098332319874316s
# Epoch 13/40, Loss: 1.0711, Val Accuracy: 40.31%
# Elapsed time on CPU: 0.0h 0.0m 2.1823536560405046s
# Epoch 14/40, Loss: 1.0707, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.2064154730178416s
# Epoch 15/40, Loss: 1.0707, Val Accuracy: 39.89%
# Elapsed time on CPU: 0.0h 0.0m 2.1820687951985747s
# Epoch 16/40, Loss: 1.0700, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.18010067101568s
# Epoch 17/40, Loss: 1.0699, Val Accuracy: 40.38%
# Elapsed time on CPU: 0.0h 0.0m 2.1882965660188347s
# Epoch 18/40, Loss: 1.0698, Val Accuracy: 40.31%
# Elapsed time on CPU: 0.0h 0.0m 2.1990176080726087s
# Epoch 19/40, Loss: 1.0697, Val Accuracy: 40.10%
# Elapsed time on CPU: 0.0h 0.0m 2.211004550103098s
# Epoch 20/40, Loss: 1.0697, Val Accuracy: 40.31%
# Elapsed time on CPU: 0.0h 0.0m 2.1882201698608696s
# Epoch 21/40, Loss: 1.0693, Val Accuracy: 40.38%
# Elapsed time on CPU: 0.0h 0.0m 2.206430220976472s
# Epoch 22/40, Loss: 1.0694, Val Accuracy: 40.24%
# Elapsed time on CPU: 0.0h 0.0m 2.1989387671928853s
# Epoch 23/40, Loss: 1.0694, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.2082801898941398s
# Epoch 24/40, Loss: 1.0691, Val Accuracy: 40.10%
# Elapsed time on CPU: 0.0h 0.0m 2.2019207319244742s
# Epoch 25/40, Loss: 1.0692, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.1880933090578765s
# Epoch 26/40, Loss: 1.0691, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.182034933939576s
# Epoch 27/40, Loss: 1.0691, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.2016206588596106s
# Epoch 28/40, Loss: 1.0692, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.1983155380003154s
# Epoch 29/40, Loss: 1.0690, Val Accuracy: 40.10%
# Elapsed time on CPU: 0.0h 0.0m 2.1840839909855276s
# Epoch 30/40, Loss: 1.0691, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.194268929073587s
# Epoch 31/40, Loss: 1.0688, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.1862437380477786s
# Epoch 32/40, Loss: 1.0689, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.1973632350564003s
# Epoch 33/40, Loss: 1.0688, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.1921485788188875s
# Epoch 34/40, Loss: 1.0690, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.2111398361157626s
# Epoch 35/40, Loss: 1.0691, Val Accuracy: 40.17%
# Elapsed time on CPU: 0.0h 0.0m 2.209984755842015s
# Epoch 36/40, Loss: 1.0687, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.187285491032526s
# Epoch 37/40, Loss: 1.0687, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.192551092011854s
# Epoch 38/40, Loss: 1.0688, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.198033189866692s
# Epoch 39/40, Loss: 1.0687, Val Accuracy: 40.03%
# Elapsed time on CPU: 0.0h 0.0m 2.1881785630248487s
# Epoch 40/40, Loss: 1.0689, Val Accuracy: 40.03%
# Total Train time: 0.0h 11.0m 49s
# Elapsed time on CPU: 0.0h 0.0m 2.204109680140391s
# Test Accuracy: 40.80%
# Train time: 0.0h 11.0m 51s
# Final Validation Accuracy: 40.80%
# ----------------------------------------------------------
# 실험 6 시작
# Selected Feature: ['Dance', 'Media', 'Style']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2365, np.int64(1): 2363, np.int64(2): 2147})
# train: 5500, valid: 1375
# Elapsed time on CPU: 0.0h 0.0m 2.0824302749242634s
# Epoch 1/40, Loss: 1.0988, Val Accuracy: 43.13%
# New best model found at epoch 1 with accuracy: 43.13%
# Elapsed time on CPU: 0.0h 0.0m 2.041674200911075s
# Epoch 2/40, Loss: 1.0518, Val Accuracy: 45.38%
# New best model found at epoch 2 with accuracy: 45.38%
# Elapsed time on CPU: 0.0h 0.0m 2.0514329909346998s
# Epoch 3/40, Loss: 1.0252, Val Accuracy: 47.64%
# New best model found at epoch 3 with accuracy: 47.64%
# Elapsed time on CPU: 0.0h 0.0m 2.054952638922259s
# Epoch 4/40, Loss: 1.0229, Val Accuracy: 47.27%
# Elapsed time on CPU: 0.0h 0.0m 2.114878125023097s
# Epoch 5/40, Loss: 1.0167, Val Accuracy: 47.42%
# Elapsed time on CPU: 0.0h 0.0m 2.0400234560947865s
# Epoch 6/40, Loss: 1.0134, Val Accuracy: 47.13%
# Elapsed time on CPU: 0.0h 0.0m 2.0629062519874424s
# Epoch 7/40, Loss: 1.0121, Val Accuracy: 47.49%
# Elapsed time on CPU: 0.0h 0.0m 2.0432775570079684s
# Epoch 8/40, Loss: 1.0106, Val Accuracy: 47.49%
# Elapsed time on CPU: 0.0h 0.0m 2.0538277719169855s
# Epoch 9/40, Loss: 1.0111, Val Accuracy: 47.78%
# New best model found at epoch 9 with accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.1271392540074885s
# Epoch 10/40, Loss: 1.0091, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.115108835976571s
# Epoch 11/40, Loss: 1.0081, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.1308826208114624s
# Epoch 12/40, Loss: 1.0072, Val Accuracy: 47.49%
# Elapsed time on CPU: 0.0h 0.0m 2.1397180010098964s
# Epoch 13/40, Loss: 1.0074, Val Accuracy: 47.27%
# Elapsed time on CPU: 0.0h 0.0m 2.11651672818698s
# Epoch 14/40, Loss: 1.0070, Val Accuracy: 46.47%
# Elapsed time on CPU: 0.0h 0.0m 2.1186678169760853s
# Epoch 15/40, Loss: 1.0067, Val Accuracy: 47.85%
# New best model found at epoch 15 with accuracy: 47.85%
# Elapsed time on CPU: 0.0h 0.0m 2.045011153910309s
# Epoch 16/40, Loss: 1.0058, Val Accuracy: 47.27%
# Elapsed time on CPU: 0.0h 0.0m 2.046540878014639s
# Epoch 17/40, Loss: 1.0059, Val Accuracy: 47.56%
# Elapsed time on CPU: 0.0h 0.0m 2.033598503097892s
# Epoch 18/40, Loss: 1.0057, Val Accuracy: 47.71%
# Elapsed time on CPU: 0.0h 0.0m 2.044416496064514s
# Epoch 19/40, Loss: 1.0059, Val Accuracy: 47.64%
# Elapsed time on CPU: 0.0h 0.0m 2.0478166569955647s
# Epoch 20/40, Loss: 1.0057, Val Accuracy: 47.49%
# Elapsed time on CPU: 0.0h 0.0m 2.069548476021737s
# Epoch 21/40, Loss: 1.0052, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.0793300999794155s
# Epoch 22/40, Loss: 1.0052, Val Accuracy: 47.71%
# Elapsed time on CPU: 0.0h 0.0m 2.0403863890096545s
# Epoch 23/40, Loss: 1.0050, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.0472323880530894s
# Epoch 24/40, Loss: 1.0050, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.0594264150131494s
# Epoch 25/40, Loss: 1.0051, Val Accuracy: 47.64%
# Elapsed time on CPU: 0.0h 0.0m 2.052923777140677s
# Epoch 26/40, Loss: 1.0047, Val Accuracy: 47.71%
# Elapsed time on CPU: 0.0h 0.0m 2.050219959113747s
# Epoch 27/40, Loss: 1.0047, Val Accuracy: 47.85%
# Elapsed time on CPU: 0.0h 0.0m 2.0533208169508725s
# Epoch 28/40, Loss: 1.0049, Val Accuracy: 47.71%
# Elapsed time on CPU: 0.0h 0.0m 2.0383651540614665s
# Epoch 29/40, Loss: 1.0046, Val Accuracy: 47.56%
# Elapsed time on CPU: 0.0h 0.0m 2.04493353003636s
# Epoch 30/40, Loss: 1.0046, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.0605980711989105s
# Epoch 31/40, Loss: 1.0046, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.0614606379531324s
# Epoch 32/40, Loss: 1.0046, Val Accuracy: 47.64%
# Elapsed time on CPU: 0.0h 0.0m 2.0627319030463696s
# Epoch 33/40, Loss: 1.0046, Val Accuracy: 47.71%
# Elapsed time on CPU: 0.0h 0.0m 2.050695083104074s
# Epoch 34/40, Loss: 1.0045, Val Accuracy: 47.64%
# Elapsed time on CPU: 0.0h 0.0m 2.047232479089871s
# Epoch 35/40, Loss: 1.0046, Val Accuracy: 47.64%
# Elapsed time on CPU: 0.0h 0.0m 2.067576879868284s
# Epoch 36/40, Loss: 1.0043, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.0625649159774184s
# Epoch 37/40, Loss: 1.0044, Val Accuracy: 47.71%
# Elapsed time on CPU: 0.0h 0.0m 2.0470395679585636s
# Epoch 38/40, Loss: 1.0044, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.046446528052911s
# Epoch 39/40, Loss: 1.0044, Val Accuracy: 47.78%
# Elapsed time on CPU: 0.0h 0.0m 2.044047178933397s
# Epoch 40/40, Loss: 1.0043, Val Accuracy: 47.78%
# Total Train time: 0.0h 11.0m 19s
# Elapsed time on CPU: 0.0h 0.0m 2.0670827149879187s
# Test Accuracy: 47.85%
# Train time: 0.0h 11.0m 21s
# Final Validation Accuracy: 47.85%
# ----------------------------------------------------------
