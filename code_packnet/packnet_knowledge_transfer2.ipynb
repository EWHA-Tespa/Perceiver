# %%
import pandas as pd
import torch
import copy
import numpy as np
import random
import pickle
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
from transformers import BertTokenizer
from sklearn.preprocessing import LabelEncoder
from perceiver import crop, patchify, get_patch_coords, tokenize_data, CustomDataset, PerceiverBlock, Perceiver, CombinedModel, ImageDataset

# Device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.CrossEntropyLoss()

def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) 
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

seed_everything(42)

# 경로 설정
pruned_model_dir = "/home/youlee/perceiver/perceiver/checkpoints_pruned2/"
batch_size = 32

# %%
# 이미지 데이터 전처리 및 로드
image_root_dir = "/home/youlee/n24news/n24news/image"
class_groups = [
    ["Opinion", "Art & Design", "Television"],
    ["Music", "Travel", "Real Estate"],
    ["Books", "Theater", "Health"],
    ["Sports", "Science", "Food"],
    ["Fashion & Style", "Movies", "Technology"],
    ["Dance", "Media", "Style"]
]

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

image_datasets = [ImageDataset(image_root_dir, transform=transform, selected_classes=group) for group in class_groups]
# Train Valid Split 
image_train_loaders, image_valid_loaders = [], []
for dataset in image_datasets:
    train_size = int(len(dataset) * 0.8)
    valid_size = len(dataset) - train_size
    train_set, valid_set = random_split(dataset, [train_size, valid_size])
    image_train_loaders.append(DataLoader(train_set, batch_size=32, shuffle=True))
    image_valid_loaders.append(DataLoader(valid_set, batch_size=32, shuffle=False))

# 텍스트 데이터 전처리 및 로드
text_root_dir = "/home/youlee/n24news/n24news/"
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
label_encoder = LabelEncoder()

def load_text_data(file_path):
    df = pd.read_csv(file_path)
    input_ids, attention_masks = tokenize_data(df, tokenizer=tokenizer, MAX_LENGTH=128)
    
    if df["Label"].dtype == "object":
        df["Label"] = label_encoder.fit_transform(df["Label"])
    labels = torch.tensor(df["Label"].values, dtype=torch.long)
    
    return CustomDataset(input_ids, attention_masks, labels)

text_datasets = [load_text_data(f"{text_root_dir}regroup_{i}.csv") for i in range(1, 7)]

# Train Valid Split 
text_train_loaders, text_valid_loaders = [], []
for dataset in text_datasets:
    train_size = int(len(dataset) * 0.8)
    valid_size = len(dataset) - train_size
    train_set, valid_set = random_split(dataset, [train_size, valid_size])
    text_train_loaders.append(DataLoader(train_set, batch_size=32, shuffle=True))
    text_valid_loaders.append(DataLoader(valid_set, batch_size=32, shuffle=False))

train_loaders = text_train_loaders + image_train_loaders
valid_loaders = text_valid_loaders + image_valid_loaders

# %%
# Pruned 모델 로드 함수
def load_pruned_models(pruned_model_dir, model_dir):
    pruned_text_models, pruned_image_models = [], []
    
    # Text 모델 로드
    for i in range(6):
        file_path = f"{pruned_model_dir}/text_model_{i+1}_pruned.pkl"
        model_path = f"{model_dir}/text_model_{i+1}.pkl"
        
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)
        
        model = torch.load(model_path)
        state_dict = {k.replace("model.", ""): v for k, v in model_data["model_state_dict"].items()}
        model.load_state_dict(state_dict, strict=False)
        pruned_text_models.append(model)

    # Image 모델 로드
    for i in range(6):
        file_path = f"{pruned_model_dir}/image_model_{i+1}_pruned.pkl"
        model_path = f"{model_dir}/image_model_{i+1}.pkl"
        
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)
        
        model = torch.load(model_path)
        state_dict = {k.replace("model.", ""): v for k, v in model_data["model_state_dict"].items()}
        model.load_state_dict(state_dict, strict=False)
        pruned_image_models.append(model)

    return pruned_text_models, pruned_image_models

# %%
# # Validation 데이터 로드 함수
# def load_valid_loaders():
#     valid_loaders = []
#     for i in range(6):
#         with open(f"{loader_dir}text_val_loader_{i+1}.pkl", 'rb') as f:
#             valid_loaders.append(pickle.load(f))
#     for i in range(6):
#         with open(f"{loader_dir}image_val_loader_{i+1}.pkl", 'rb') as f:
#             valid_dataset = pickle.load(f)
#             valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
#             valid_loaders.append(valid_loader)
#     return valid_loaders

# %%
# 키 매핑 함수
def map_keys(state_dict, modality):
    key_map = {}
    for key in state_dict.keys():
        if modality == "Text" and "model.perceiver" in key:
            key_map[key] = key.replace("model.perceiver", "model")
        elif modality == "Image" and "model." in key:
            key_map[key] = key.replace("model.", "model.perceiver")
        else:
            key_map[key] = key
    return key_map

# 가중치 매핑 및 로드 함수
def apply_mapped_state_dict(task_model, backbone_model, modality):
    backbone_state_dict = backbone_model.state_dict()
    key_map = map_keys(backbone_state_dict, modality)
    mapped_state_dict = {key_map[k]: v for k, v in backbone_state_dict.items()}
    task_model.load_state_dict(mapped_state_dict, strict=False)
    print(f"Successfully applied backbone weights for {modality} task.")

# %%
def knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                       task_models, backbone_models, train_loaders, criterion, device, epochs=20):
    if backbone_modality == "Text":
        backbone_model = backbone_models[backbone_id]
    elif backbone_modality == "Image":
        backbone_model = backbone_models[backbone_id]

    task_model = task_models[task_id]
    task_model.to(device)

    apply_mapped_state_dict(task_model, backbone_model, backbone_modality)

    optimizer = optim.SGD(task_model.parameters(), lr=0.0001, momentum=0.9)
    task_model.train()
    
    for epoch in range(epochs):
        total_loss = 0
        correct = 0
        total = 0

        for batch in train_loaders[task_id]:
            optimizer.zero_grad()
            if task_modality == "Text":
                inputs = batch["input_ids"].to(device)
                labels = batch["labels"].to(device)
                outputs = task_model(inputs)
            else:
                inputs, labels = batch
                inputs = inputs.to(device)
                labels = labels.to(device)
                outputs = task_model(inputs)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        print(f"Task {task_id} | Backbone {backbone_id} | Epoch {epoch+1}/{epochs} | Loss: {total_loss:.4f} | Accuracy: {correct/total:.4f}")
    return task_model

# %%
def eval_epoch(model, dataloader, criterion, device, is_text: bool):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0

    correct_samples = []
    incorrect_samples = []

    with torch.no_grad():
        for batch in dataloader:
            if is_text:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)
                outputs = model(input_ids)
            else:
                inputs, labels = batch
                inputs = inputs.to(device)
                labels = labels.to(device)
                outputs = model(inputs)

            loss = criterion(outputs, labels)
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            for i in range(len(labels)):
                if predicted[i] == labels[i] and len(correct_samples) < 4:
                    correct_samples.append((i, labels[i].item(), predicted[i].item()))
                elif predicted[i] != labels[i] and len(incorrect_samples) < 4:
                    incorrect_samples.append((i, labels[i].item(), predicted[i].item()))
            if len(correct_samples) >= 4 and len(incorrect_samples) >= 4:
                break


    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    return avg_loss, accuracy, correct_samples, incorrect_samples

# %%
# 최종 평가 함수
def evaluate_transfer(models, valid_loaders, criterion, device):
    correct_samples_dict = {}  # Task별 정답 샘플 저장
    incorrect_samples_dict = {}  # Task별 오답 샘플 저장

    for i, model in enumerate(models):
        is_text = i < 6

        test_loss, test_acc, correct_samples, incorrect_samples = eval_epoch(model, valid_loaders[i], criterion, device, is_text)
        modality = "Text" if is_text else "Image"
        print(f"Task {i} ({modality}) | Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

        # Task ID별로 샘플 저장
        correct_samples_dict[i] = correct_samples
        incorrect_samples_dict[i] = incorrect_samples

    return correct_samples_dict, incorrect_samples_dict

# %%
# Cosine 및 Euclidean 결과 로드
cosine_results = pd.read_csv("/home/youlee/perceiver/perceiver/code/best_cosine_results.txt", sep='\t')
euclidean_results = pd.read_csv("/home/youlee/perceiver/perceiver/code/best_euclidean_results.txt", sep='\t')
cosine_task_to_backbone = {row["Task_ID"]: row["Best_Target_ID"] for _, row in cosine_results.iterrows()}
euclidean_task_to_backbone = {row["Task_ID"]: row["Best_Target_ID"] for _, row in euclidean_results.iterrows()}

# %%
if __name__ == "__main__":
    print("Loading pruned models and validation loaders...")
    
    pruned_text_models, pruned_image_models = load_pruned_models(pruned_model_dir, "/home/youlee/perceiver/perceiver/model")
    pruned_models = pruned_text_models + pruned_image_models

    cosine_models = [copy.deepcopy(model).to(device) for model in pruned_models]
    euclidean_models = [copy.deepcopy(model).to(device) for model in pruned_models]


    print("Starting Cosine-based Knowledge Transfer...")
    for task_id, backbone_id in cosine_task_to_backbone.items():
        backbone_modality = cosine_results.loc[cosine_results["Task_ID"] == task_id, "Target_Modality"].values[0]
        task_modality = cosine_results.loc[cosine_results["Task_ID"] == task_id, "Task_Modality"].values[0]
        knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                           cosine_models, pruned_models, train_loaders, criterion, device)

    print("Starting Euclidean-based Knowledge Transfer...")
    for task_id, backbone_id in euclidean_task_to_backbone.items():
        backbone_modality = euclidean_results.loc[euclidean_results["Task_ID"] == task_id, "Target_Modality"].values[0]
        task_modality = euclidean_results.loc[euclidean_results["Task_ID"] == task_id, "Task_Modality"].values[0]
        knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                           euclidean_models, pruned_models, train_loaders, criterion, device)

    print("Evaluating Cosine-based Transfer results...")
    cosine_correct_samples, cosine_incorrect_samples = evaluate_transfer(cosine_models, valid_loaders, criterion, device)


    print("Evaluating Euclidean-based Transfer results...")
    euclidean_correct_samples, euclidean_incorrect_samples = evaluate_transfer(euclidean_models, valid_loaders, criterion, device)

    # ✅ Task별 정답/오답 샘플 최종 출력
    print("\n===== Cosine-based Correct & Incorrect Predictions =====")
    for task_id in cosine_correct_samples.keys():
        print(f"✅ Task {task_id} Correct Predictions:")
        for idx, true_label, pred_label in cosine_correct_samples[task_id]:
            print(f"  - Sample {idx}: True Label={true_label}, Predicted Label={pred_label}")

        print(f"❌ Task {task_id} Incorrect Predictions:")
        for idx, true_label, pred_label in cosine_incorrect_samples[task_id]:
            print(f"  - Sample {idx}: True Label={true_label}, Predicted Label={pred_label}")
        print("-" * 60)

    print("\n===== Euclidean-based Correct & Incorrect Predictions =====")
    for task_id in euclidean_correct_samples.keys():
        print(f"✅ Task {task_id} Correct Predictions:")
        for idx, true_label, pred_label in euclidean_correct_samples[task_id]:
            print(f"  - Sample {idx}: True Label={true_label}, Predicted Label={pred_label}")

        print(f"❌ Task {task_id} Incorrect Predictions:")
        for idx, true_label, pred_label in euclidean_incorrect_samples[task_id]:
            print(f"  - Sample {idx}: True Label={true_label}, Predicted Label={pred_label}")
        print("-" * 60)
# Out:
# Loading pruned models and validation loaders...
# /tmp/ipykernel_3282374/3255779742.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)
# /tmp/ipykernel_3282374/3255779742.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)
# Starting Cosine-based Knowledge Transfer...
# Successfully applied backbone weights for Image task.
# Task 0 | Backbone 9 | Epoch 1/20 | Loss: 36.2878 | Accuracy: 0.9480
# Task 0 | Backbone 9 | Epoch 2/20 | Loss: 29.9958 | Accuracy: 0.9587
# Task 0 | Backbone 9 | Epoch 3/20 | Loss: 27.8242 | Accuracy: 0.9616
# Task 0 | Backbone 9 | Epoch 4/20 | Loss: 26.1543 | Accuracy: 0.9653
# Task 0 | Backbone 9 | Epoch 5/20 | Loss: 25.1702 | Accuracy: 0.9664
# Task 0 | Backbone 9 | Epoch 6/20 | Loss: 24.1259 | Accuracy: 0.9674
# Task 0 | Backbone 9 | Epoch 7/20 | Loss: 23.2531 | Accuracy: 0.9700
# Task 0 | Backbone 9 | Epoch 8/20 | Loss: 22.4475 | Accuracy: 0.9710
# Task 0 | Backbone 9 | Epoch 9/20 | Loss: 22.0822 | Accuracy: 0.9720
# Task 0 | Backbone 9 | Epoch 10/20 | Loss: 21.2705 | Accuracy: 0.9731
# Task 0 | Backbone 9 | Epoch 11/20 | Loss: 20.9047 | Accuracy: 0.9738
# Task 0 | Backbone 9 | Epoch 12/20 | Loss: 20.6284 | Accuracy: 0.9748
# Task 0 | Backbone 9 | Epoch 13/20 | Loss: 20.1434 | Accuracy: 0.9758
# Task 0 | Backbone 9 | Epoch 14/20 | Loss: 19.6934 | Accuracy: 0.9767
# Task 0 | Backbone 9 | Epoch 15/20 | Loss: 19.4758 | Accuracy: 0.9767
# Task 0 | Backbone 9 | Epoch 16/20 | Loss: 19.2083 | Accuracy: 0.9775
# Task 0 | Backbone 9 | Epoch 17/20 | Loss: 18.9011 | Accuracy: 0.9784
# Task 0 | Backbone 9 | Epoch 18/20 | Loss: 18.5925 | Accuracy: 0.9782
# Task 0 | Backbone 9 | Epoch 19/20 | Loss: 18.4143 | Accuracy: 0.9787
# Task 0 | Backbone 9 | Epoch 20/20 | Loss: 18.1937 | Accuracy: 0.9792
# Successfully applied backbone weights for Image task.
# Task 1 | Backbone 10 | Epoch 1/20 | Loss: 40.9120 | Accuracy: 0.9379
# Task 1 | Backbone 10 | Epoch 2/20 | Loss: 36.6049 | Accuracy: 0.9442
# Task 1 | Backbone 10 | Epoch 3/20 | Loss: 34.6417 | Accuracy: 0.9484
# Task 1 | Backbone 10 | Epoch 4/20 | Loss: 33.2229 | Accuracy: 0.9517
# Task 1 | Backbone 10 | Epoch 5/20 | Loss: 32.1087 | Accuracy: 0.9539
# Task 1 | Backbone 10 | Epoch 6/20 | Loss: 31.0939 | Accuracy: 0.9558
# Task 1 | Backbone 10 | Epoch 7/20 | Loss: 30.1798 | Accuracy: 0.9584
# Task 1 | Backbone 10 | Epoch 8/20 | Loss: 31.7631 | Accuracy: 0.9596
# Task 1 | Backbone 10 | Epoch 9/20 | Loss: 29.3096 | Accuracy: 0.9600
# Task 9 | Backbone 0 | Epoch 10/20 | Loss: 189.6304 | Accuracy: 0.4285
# Task 9 | Backbone 0 | Epoch 11/20 | Loss: 188.7110 | Accuracy: 0.4358
# Task 9 | Backbone 0 | Epoch 12/20 | Loss: 187.0777 | Accuracy: 0.4461
# Task 9 | Backbone 0 | Epoch 13/20 | Loss: 185.0666 | Accuracy: 0.4548
# Task 9 | Backbone 0 | Epoch 14/20 | Loss: 186.2356 | Accuracy: 0.4491
# Task 9 | Backbone 0 | Epoch 15/20 | Loss: 184.5484 | Accuracy: 0.4625
# Task 9 | Backbone 0 | Epoch 16/20 | Loss: 184.7669 | Accuracy: 0.4670
# Task 9 | Backbone 0 | Epoch 17/20 | Loss: 184.9122 | Accuracy: 0.4573
# Task 9 | Backbone 0 | Epoch 18/20 | Loss: 183.5309 | Accuracy: 0.4616
# Task 9 | Backbone 0 | Epoch 19/20 | Loss: 182.7907 | Accuracy: 0.4708
# Task 9 | Backbone 0 | Epoch 20/20 | Loss: 182.7359 | Accuracy: 0.4714
# Successfully applied backbone weights for Image task.
# Task 10 | Backbone 6 | Epoch 1/20 | Loss: 203.2832 | Accuracy: 0.3464
# Task 10 | Backbone 6 | Epoch 2/20 | Loss: 195.7731 | Accuracy: 0.3702
# Task 10 | Backbone 6 | Epoch 3/20 | Loss: 195.1639 | Accuracy: 0.3723
# Task 10 | Backbone 6 | Epoch 4/20 | Loss: 194.7985 | Accuracy: 0.3802
# Task 10 | Backbone 6 | Epoch 5/20 | Loss: 194.7250 | Accuracy: 0.3793
# Task 10 | Backbone 6 | Epoch 6/20 | Loss: 194.0888 | Accuracy: 0.3856
# Task 10 | Backbone 6 | Epoch 7/20 | Loss: 194.1625 | Accuracy: 0.3845
# Task 10 | Backbone 6 | Epoch 8/20 | Loss: 193.8672 | Accuracy: 0.3905
# Task 10 | Backbone 6 | Epoch 9/20 | Loss: 193.8137 | Accuracy: 0.3891
# Task 10 | Backbone 6 | Epoch 10/20 | Loss: 193.5349 | Accuracy: 0.3872
# Task 10 | Backbone 6 | Epoch 11/20 | Loss: 193.2030 | Accuracy: 0.3973
# Task 10 | Backbone 6 | Epoch 12/20 | Loss: 192.8947 | Accuracy: 0.3935
# Task 10 | Backbone 6 | Epoch 13/20 | Loss: 193.0933 | Accuracy: 0.3970
# Task 10 | Backbone 6 | Epoch 14/20 | Loss: 192.7809 | Accuracy: 0.3910
# Task 10 | Backbone 6 | Epoch 15/20 | Loss: 192.7216 | Accuracy: 0.3971
# Task 10 | Backbone 6 | Epoch 16/20 | Loss: 192.6223 | Accuracy: 0.3886
# Task 10 | Backbone 6 | Epoch 17/20 | Loss: 192.5858 | Accuracy: 0.3959
# Task 10 | Backbone 6 | Epoch 18/20 | Loss: 192.2125 | Accuracy: 0.4043
# Task 10 | Backbone 6 | Epoch 19/20 | Loss: 192.3033 | Accuracy: 0.4003
# Task 10 | Backbone 6 | Epoch 20/20 | Loss: 191.8279 | Accuracy: 0.4064
# Successfully applied backbone weights for Image task.
# Task 11 | Backbone 10 | Epoch 1/20 | Loss: 191.0160 | Accuracy: 0.3560
# Task 11 | Backbone 10 | Epoch 2/20 | Loss: 188.5700 | Accuracy: 0.3713
# Task 11 | Backbone 10 | Epoch 3/20 | Loss: 188.4412 | Accuracy: 0.3644
# Task 11 | Backbone 10 | Epoch 4/20 | Loss: 188.3257 | Accuracy: 0.3758
# Task 11 | Backbone 10 | Epoch 5/20 | Loss: 188.1790 | Accuracy: 0.3775
# Task 11 | Backbone 10 | Epoch 6/20 | Loss: 187.7641 | Accuracy: 0.3855
# Task 11 | Backbone 10 | Epoch 7/20 | Loss: 186.8194 | Accuracy: 0.3871
# Task 11 | Backbone 10 | Epoch 8/20 | Loss: 182.7460 | Accuracy: 0.4149
# Task 11 | Backbone 10 | Epoch 9/20 | Loss: 179.7899 | Accuracy: 0.4309
# Task 11 | Backbone 10 | Epoch 10/20 | Loss: 178.9195 | Accuracy: 0.4475
# Task 11 | Backbone 10 | Epoch 11/20 | Loss: 178.5852 | Accuracy: 0.4509
# Task 11 | Backbone 10 | Epoch 12/20 | Loss: 178.3587 | Accuracy: 0.4493
# Task 11 | Backbone 10 | Epoch 13/20 | Loss: 177.8727 | Accuracy: 0.4507
# Task 11 | Backbone 10 | Epoch 14/20 | Loss: 177.8421 | Accuracy: 0.4513
# Task 11 | Backbone 10 | Epoch 15/20 | Loss: 177.5566 | Accuracy: 0.4520
# Task 11 | Backbone 10 | Epoch 16/20 | Loss: 177.5472 | Accuracy: 0.4471
# Task 11 | Backbone 10 | Epoch 17/20 | Loss: 177.4906 | Accuracy: 0.4531
# Task 11 | Backbone 10 | Epoch 18/20 | Loss: 177.6733 | Accuracy: 0.4509
# Task 11 | Backbone 10 | Epoch 19/20 | Loss: 177.6763 | Accuracy: 0.4535
# Task 11 | Backbone 10 | Epoch 20/20 | Loss: 177.3889 | Accuracy: 0.4525
# Starting Euclidean-based Knowledge Transfer...
# Successfully applied backbone weights for Image task.
# Task 0 | Backbone 7 | Epoch 1/20 | Loss: 36.7274 | Accuracy: 0.9494
# Task 0 | Backbone 7 | Epoch 2/20 | Loss: 30.9975 | Accuracy: 0.9587
# Task 0 | Backbone 7 | Epoch 3/20 | Loss: 28.5176 | Accuracy: 0.9626
# Task 0 | Backbone 7 | Epoch 4/20 | Loss: 27.2088 | Accuracy: 0.9636
# Task 0 | Backbone 7 | Epoch 5/20 | Loss: 25.1427 | Accuracy: 0.9655
# Task 0 | Backbone 7 | Epoch 6/20 | Loss: 24.0669 | Accuracy: 0.9681
# Task 0 | Backbone 7 | Epoch 7/20 | Loss: 24.0821 | Accuracy: 0.9696
# Task 0 | Backbone 7 | Epoch 8/20 | Loss: 22.3675 | Accuracy: 0.9708
# Task 0 | Backbone 7 | Epoch 9/20 | Loss: 21.7900 | Accuracy: 0.9722
# Task 0 | Backbone 7 | Epoch 10/20 | Loss: 21.3242 | Accuracy: 0.9731
# Task 0 | Backbone 7 | Epoch 11/20 | Loss: 20.8868 | Accuracy: 0.9741
# Task 0 | Backbone 7 | Epoch 12/20 | Loss: 20.4912 | Accuracy: 0.9744
# Task 0 | Backbone 7 | Epoch 13/20 | Loss: 20.0581 | Accuracy: 0.9755
# Task 0 | Backbone 7 | Epoch 14/20 | Loss: 19.7842 | Accuracy: 0.9763
# Task 0 | Backbone 7 | Epoch 15/20 | Loss: 19.4809 | Accuracy: 0.9765
# Task 0 | Backbone 7 | Epoch 16/20 | Loss: 19.1620 | Accuracy: 0.9777
# Task 0 | Backbone 7 | Epoch 17/20 | Loss: 18.9257 | Accuracy: 0.9775
# Task 0 | Backbone 7 | Epoch 18/20 | Loss: 18.6481 | Accuracy: 0.9784
# Task 0 | Backbone 7 | Epoch 19/20 | Loss: 18.9043 | Accuracy: 0.9789
# Task 0 | Backbone 7 | Epoch 20/20 | Loss: 18.0885 | Accuracy: 0.9787
# Successfully applied backbone weights for Image task.
# Task 1 | Backbone 10 | Epoch 1/20 | Loss: 40.9812 | Accuracy: 0.9366
# Task 1 | Backbone 10 | Epoch 2/20 | Loss: 36.5983 | Accuracy: 0.9442
# Task 1 | Backbone 10 | Epoch 3/20 | Loss: 36.2988 | Accuracy: 0.9491
# Task 1 | Backbone 10 | Epoch 4/20 | Loss: 33.5778 | Accuracy: 0.9503
# Task 1 | Backbone 10 | Epoch 5/20 | Loss: 32.1312 | Accuracy: 0.9544
# Task 1 | Backbone 10 | Epoch 6/20 | Loss: 31.1179 | Accuracy: 0.9565
# Task 1 | Backbone 10 | Epoch 7/20 | Loss: 30.2340 | Accuracy: 0.9587
# Task 1 | Backbone 10 | Epoch 8/20 | Loss: 29.4984 | Accuracy: 0.9608
# Task 1 | Backbone 10 | Epoch 9/20 | Loss: 28.7264 | Accuracy: 0.9612
# Task 1 | Backbone 10 | Epoch 10/20 | Loss: 27.9745 | Accuracy: 0.9624
# Task 1 | Backbone 10 | Epoch 11/20 | Loss: 27.4697 | Accuracy: 0.9643
# Task 1 | Backbone 10 | Epoch 12/20 | Loss: 27.1317 | Accuracy: 0.9646
# Task 1 | Backbone 10 | Epoch 13/20 | Loss: 26.5348 | Accuracy: 0.9655
# Task 1 | Backbone 10 | Epoch 14/20 | Loss: 26.0658 | Accuracy: 0.9663
# Task 1 | Backbone 10 | Epoch 15/20 | Loss: 25.6857 | Accuracy: 0.9672
# Task 1 | Backbone 10 | Epoch 16/20 | Loss: 25.3490 | Accuracy: 0.9682
# Task 1 | Backbone 10 | Epoch 17/20 | Loss: 25.0031 | Accuracy: 0.9688
# Task 1 | Backbone 10 | Epoch 18/20 | Loss: 24.6910 | Accuracy: 0.9700
# Task 1 | Backbone 10 | Epoch 19/20 | Loss: 24.4174 | Accuracy: 0.9705
# Task 1 | Backbone 10 | Epoch 20/20 | Loss: 24.2019 | Accuracy: 0.9707
# Successfully applied backbone weights for Image task.
# Task 2 | Backbone 8 | Epoch 1/20 | Loss: 34.6032 | Accuracy: 0.9499
# Task 2 | Backbone 8 | Epoch 2/20 | Loss: 29.6813 | Accuracy: 0.9592
# Task 2 | Backbone 8 | Epoch 3/20 | Loss: 28.0441 | Accuracy: 0.9614
# Task 2 | Backbone 8 | Epoch 4/20 | Loss: 26.4239 | Accuracy: 0.9647
# Task 3 | Backbone 10 | Epoch 17/20 | Loss: 15.5675 | Accuracy: 0.9842
# Task 3 | Backbone 10 | Epoch 18/20 | Loss: 15.3508 | Accuracy: 0.9843
# Task 3 | Backbone 10 | Epoch 19/20 | Loss: 15.1264 | Accuracy: 0.9849
# Task 3 | Backbone 10 | Epoch 20/20 | Loss: 15.0600 | Accuracy: 0.9849
# Successfully applied backbone weights for Image task.
# Task 4 | Backbone 10 | Epoch 1/20 | Loss: 33.7225 | Accuracy: 0.9535
# Task 4 | Backbone 10 | Epoch 2/20 | Loss: 30.5870 | Accuracy: 0.9589
# Task 4 | Backbone 10 | Epoch 3/20 | Loss: 28.7398 | Accuracy: 0.9627
# Task 4 | Backbone 10 | Epoch 4/20 | Loss: 27.2574 | Accuracy: 0.9652
# Task 4 | Backbone 10 | Epoch 5/20 | Loss: 25.7239 | Accuracy: 0.9666
# Task 4 | Backbone 10 | Epoch 6/20 | Loss: 24.7866 | Accuracy: 0.9671
# Task 4 | Backbone 10 | Epoch 7/20 | Loss: 23.7678 | Accuracy: 0.9689
# Task 4 | Backbone 10 | Epoch 8/20 | Loss: 23.1192 | Accuracy: 0.9706
# Task 4 | Backbone 10 | Epoch 9/20 | Loss: 22.4176 | Accuracy: 0.9717
# Task 4 | Backbone 10 | Epoch 10/20 | Loss: 21.9043 | Accuracy: 0.9727
# Task 4 | Backbone 10 | Epoch 11/20 | Loss: 21.4436 | Accuracy: 0.9738
# Task 4 | Backbone 10 | Epoch 12/20 | Loss: 20.8434 | Accuracy: 0.9753
# Task 4 | Backbone 10 | Epoch 13/20 | Loss: 20.4635 | Accuracy: 0.9759
# Task 4 | Backbone 10 | Epoch 14/20 | Loss: 20.1309 | Accuracy: 0.9762
# Task 4 | Backbone 10 | Epoch 15/20 | Loss: 20.0380 | Accuracy: 0.9771
# Task 4 | Backbone 10 | Epoch 16/20 | Loss: 19.6567 | Accuracy: 0.9776
# Task 4 | Backbone 10 | Epoch 17/20 | Loss: 19.3013 | Accuracy: 0.9776
# Task 4 | Backbone 10 | Epoch 18/20 | Loss: 19.1082 | Accuracy: 0.9778
# Task 4 | Backbone 10 | Epoch 19/20 | Loss: 18.8901 | Accuracy: 0.9783
# Task 4 | Backbone 10 | Epoch 20/20 | Loss: 18.6679 | Accuracy: 0.9781
# Successfully applied backbone weights for Text task.
# Task 5 | Backbone 4 | Epoch 1/20 | Loss: 433.3898 | Accuracy: 0.3071
# Task 5 | Backbone 4 | Epoch 2/20 | Loss: 213.7902 | Accuracy: 0.3862
# Task 5 | Backbone 4 | Epoch 3/20 | Loss: 189.9255 | Accuracy: 0.4680
# Task 5 | Backbone 4 | Epoch 4/20 | Loss: 184.5793 | Accuracy: 0.4691
# Task 5 | Backbone 4 | Epoch 5/20 | Loss: 182.0094 | Accuracy: 0.4645
# Task 5 | Backbone 4 | Epoch 6/20 | Loss: 179.8547 | Accuracy: 0.4722
# Task 5 | Backbone 4 | Epoch 7/20 | Loss: 177.7299 | Accuracy: 0.4787
# Task 5 | Backbone 4 | Epoch 8/20 | Loss: 175.5518 | Accuracy: 0.4842
# Task 5 | Backbone 4 | Epoch 9/20 | Loss: 173.4378 | Accuracy: 0.4893
# Task 5 | Backbone 4 | Epoch 10/20 | Loss: 171.4261 | Accuracy: 0.4953
# Task 5 | Backbone 4 | Epoch 11/20 | Loss: 169.5282 | Accuracy: 0.5007
# Task 5 | Backbone 4 | Epoch 12/20 | Loss: 167.8789 | Accuracy: 0.5107
# Task 5 | Backbone 4 | Epoch 13/20 | Loss: 166.3399 | Accuracy: 0.5209
# Task 5 | Backbone 4 | Epoch 14/20 | Loss: 164.8339 | Accuracy: 0.5327
# Task 5 | Backbone 4 | Epoch 15/20 | Loss: 163.2899 | Accuracy: 0.5424
# Task 5 | Backbone 4 | Epoch 16/20 | Loss: 161.8137 | Accuracy: 0.5518
# Task 5 | Backbone 4 | Epoch 17/20 | Loss: 160.3361 | Accuracy: 0.5636
# Task 5 | Backbone 4 | Epoch 18/20 | Loss: 158.9181 | Accuracy: 0.5716
# Task 5 | Backbone 4 | Epoch 19/20 | Loss: 157.4850 | Accuracy: 0.5767
# Task 5 | Backbone 4 | Epoch 20/20 | Loss: 156.1831 | Accuracy: 0.5842
# Successfully applied backbone weights for Image task.
# Task 6 | Backbone 10 | Epoch 1/20 | Loss: 204.4363 | Accuracy: 0.3196
# Task 6 | Backbone 10 | Epoch 2/20 | Loss: 201.3820 | Accuracy: 0.3122
# Task 6 | Backbone 10 | Epoch 3/20 | Loss: 201.3581 | Accuracy: 0.3239
# Task 6 | Backbone 10 | Epoch 4/20 | Loss: 201.3099 | Accuracy: 0.3294
# Task 6 | Backbone 10 | Epoch 5/20 | Loss: 201.2609 | Accuracy: 0.3105
# Task 6 | Backbone 10 | Epoch 6/20 | Loss: 201.2439 | Accuracy: 0.3242
# Task 6 | Backbone 10 | Epoch 7/20 | Loss: 201.2242 | Accuracy: 0.3176
# Task 6 | Backbone 10 | Epoch 8/20 | Loss: 201.1208 | Accuracy: 0.3332
# Task 6 | Backbone 10 | Epoch 9/20 | Loss: 201.0920 | Accuracy: 0.3385
# Task 6 | Backbone 10 | Epoch 10/20 | Loss: 201.0945 | Accuracy: 0.3397
# Task 6 | Backbone 10 | Epoch 11/20 | Loss: 201.0508 | Accuracy: 0.3417
# Task 6 | Backbone 10 | Epoch 12/20 | Loss: 200.8122 | Accuracy: 0.3647
# Task 6 | Backbone 10 | Epoch 13/20 | Loss: 199.5899 | Accuracy: 0.3761
# Task 6 | Backbone 10 | Epoch 14/20 | Loss: 195.2210 | Accuracy: 0.4064
# Task 6 | Backbone 10 | Epoch 15/20 | Loss: 194.1296 | Accuracy: 0.4080
# Task 6 | Backbone 10 | Epoch 16/20 | Loss: 193.7113 | Accuracy: 0.4069
# Task 6 | Backbone 10 | Epoch 17/20 | Loss: 193.1813 | Accuracy: 0.4117
# Task 6 | Backbone 10 | Epoch 18/20 | Loss: 192.7270 | Accuracy: 0.4273
# Task 6 | Backbone 10 | Epoch 19/20 | Loss: 192.3363 | Accuracy: 0.4340
# Task 6 | Backbone 10 | Epoch 20/20 | Loss: 191.8262 | Accuracy: 0.4299
# Task 8 | Backbone 6 | Epoch 13/20 | Loss: 184.4713 | Accuracy: 0.4621
# Task 8 | Backbone 6 | Epoch 14/20 | Loss: 184.4655 | Accuracy: 0.4630
# Task 8 | Backbone 6 | Epoch 15/20 | Loss: 184.2730 | Accuracy: 0.4675
# Task 8 | Backbone 6 | Epoch 16/20 | Loss: 184.0864 | Accuracy: 0.4675
# Task 8 | Backbone 6 | Epoch 17/20 | Loss: 184.3789 | Accuracy: 0.4633
# Task 8 | Backbone 6 | Epoch 18/20 | Loss: 184.1229 | Accuracy: 0.4760
# Task 8 | Backbone 6 | Epoch 19/20 | Loss: 184.2191 | Accuracy: 0.4699
# Task 8 | Backbone 6 | Epoch 20/20 | Loss: 184.1296 | Accuracy: 0.4623
# Successfully applied backbone weights for Image task.
# Task 9 | Backbone 10 | Epoch 1/20 | Loss: 200.8372 | Accuracy: 0.3213
# Task 9 | Backbone 10 | Epoch 2/20 | Loss: 197.9242 | Accuracy: 0.3275
# Task 9 | Backbone 10 | Epoch 3/20 | Loss: 198.0146 | Accuracy: 0.3152
# Task 9 | Backbone 10 | Epoch 4/20 | Loss: 197.9598 | Accuracy: 0.3293
# Task 9 | Backbone 10 | Epoch 5/20 | Loss: 197.9296 | Accuracy: 0.3261
# Task 9 | Backbone 10 | Epoch 6/20 | Loss: 197.9459 | Accuracy: 0.3301
# Task 9 | Backbone 10 | Epoch 7/20 | Loss: 197.9678 | Accuracy: 0.3275
# Task 9 | Backbone 10 | Epoch 8/20 | Loss: 197.8638 | Accuracy: 0.3376
# Task 9 | Backbone 10 | Epoch 9/20 | Loss: 197.9339 | Accuracy: 0.3221
# Task 9 | Backbone 10 | Epoch 10/20 | Loss: 197.8343 | Accuracy: 0.3206
# Task 9 | Backbone 10 | Epoch 11/20 | Loss: 197.8915 | Accuracy: 0.3368
# Task 9 | Backbone 10 | Epoch 12/20 | Loss: 197.8295 | Accuracy: 0.3239
# Task 9 | Backbone 10 | Epoch 13/20 | Loss: 197.7823 | Accuracy: 0.3319
# Task 9 | Backbone 10 | Epoch 14/20 | Loss: 197.7721 | Accuracy: 0.3420
# Task 9 | Backbone 10 | Epoch 15/20 | Loss: 197.8125 | Accuracy: 0.3336
# Task 9 | Backbone 10 | Epoch 16/20 | Loss: 197.7550 | Accuracy: 0.3429
# Task 9 | Backbone 10 | Epoch 17/20 | Loss: 197.7291 | Accuracy: 0.3435
# Task 9 | Backbone 10 | Epoch 18/20 | Loss: 197.7199 | Accuracy: 0.3375
# Task 9 | Backbone 10 | Epoch 19/20 | Loss: 197.5857 | Accuracy: 0.3545
# Task 9 | Backbone 10 | Epoch 20/20 | Loss: 197.4174 | Accuracy: 0.3550
# Successfully applied backbone weights for Image task.
# Task 10 | Backbone 6 | Epoch 1/20 | Loss: 202.8266 | Accuracy: 0.3544
# Task 10 | Backbone 6 | Epoch 2/20 | Loss: 195.8280 | Accuracy: 0.3651
# Task 10 | Backbone 6 | Epoch 3/20 | Loss: 195.3938 | Accuracy: 0.3670
# Task 10 | Backbone 6 | Epoch 4/20 | Loss: 194.8075 | Accuracy: 0.3744
# Task 10 | Backbone 6 | Epoch 5/20 | Loss: 194.3626 | Accuracy: 0.3786
# Task 10 | Backbone 6 | Epoch 6/20 | Loss: 194.4241 | Accuracy: 0.3833
# Task 10 | Backbone 6 | Epoch 7/20 | Loss: 194.0092 | Accuracy: 0.3844
# Task 10 | Backbone 6 | Epoch 8/20 | Loss: 193.5479 | Accuracy: 0.3887
# Task 10 | Backbone 6 | Epoch 9/20 | Loss: 193.9057 | Accuracy: 0.3866
# Task 10 | Backbone 6 | Epoch 10/20 | Loss: 193.5533 | Accuracy: 0.3924
# Task 10 | Backbone 6 | Epoch 11/20 | Loss: 193.1108 | Accuracy: 0.3975
# Task 10 | Backbone 6 | Epoch 12/20 | Loss: 193.1138 | Accuracy: 0.3901
# Task 10 | Backbone 6 | Epoch 13/20 | Loss: 192.8011 | Accuracy: 0.3889
# Task 10 | Backbone 6 | Epoch 14/20 | Loss: 192.8591 | Accuracy: 0.3842
# Task 10 | Backbone 6 | Epoch 15/20 | Loss: 192.7485 | Accuracy: 0.3926
# Task 10 | Backbone 6 | Epoch 16/20 | Loss: 192.6489 | Accuracy: 0.3887
# Task 10 | Backbone 6 | Epoch 17/20 | Loss: 192.7036 | Accuracy: 0.3922
# Task 10 | Backbone 6 | Epoch 18/20 | Loss: 192.3595 | Accuracy: 0.3994
# Task 10 | Backbone 6 | Epoch 19/20 | Loss: 192.0794 | Accuracy: 0.3982
# Task 10 | Backbone 6 | Epoch 20/20 | Loss: 191.8742 | Accuracy: 0.4026
# Successfully applied backbone weights for Image task.
# Task 11 | Backbone 10 | Epoch 1/20 | Loss: 191.2781 | Accuracy: 0.3536
# Task 11 | Backbone 10 | Epoch 2/20 | Loss: 188.6491 | Accuracy: 0.3744
# Task 11 | Backbone 10 | Epoch 3/20 | Loss: 188.4842 | Accuracy: 0.3707
# Task 11 | Backbone 10 | Epoch 4/20 | Loss: 188.3577 | Accuracy: 0.3735
# Task 11 | Backbone 10 | Epoch 5/20 | Loss: 188.1044 | Accuracy: 0.3673
# Task 11 | Backbone 10 | Epoch 6/20 | Loss: 187.8011 | Accuracy: 0.3931
# Task 11 | Backbone 10 | Epoch 7/20 | Loss: 186.8920 | Accuracy: 0.3940
# Task 11 | Backbone 10 | Epoch 8/20 | Loss: 182.8280 | Accuracy: 0.4096
# Task 11 | Backbone 10 | Epoch 9/20 | Loss: 179.9312 | Accuracy: 0.4356
# Task 11 | Backbone 10 | Epoch 10/20 | Loss: 179.2168 | Accuracy: 0.4427
# Task 11 | Backbone 10 | Epoch 11/20 | Loss: 178.5001 | Accuracy: 0.4489
# Task 11 | Backbone 10 | Epoch 12/20 | Loss: 179.2273 | Accuracy: 0.4456
# Task 11 | Backbone 10 | Epoch 13/20 | Loss: 178.1102 | Accuracy: 0.4500
# Task 11 | Backbone 10 | Epoch 14/20 | Loss: 177.9139 | Accuracy: 0.4547
# Task 11 | Backbone 10 | Epoch 15/20 | Loss: 177.7280 | Accuracy: 0.4495
# Task 11 | Backbone 10 | Epoch 16/20 | Loss: 177.6033 | Accuracy: 0.4425
# Task 11 | Backbone 10 | Epoch 17/20 | Loss: 177.4236 | Accuracy: 0.4515
# Task 11 | Backbone 10 | Epoch 18/20 | Loss: 177.2486 | Accuracy: 0.4527
# Task 11 | Backbone 10 | Epoch 19/20 | Loss: 177.4746 | Accuracy: 0.4476
# Task 11 | Backbone 10 | Epoch 20/20 | Loss: 177.4129 | Accuracy: 0.4476
# Evaluating Cosine-based Transfer results...
# Task 0 (Text) | Test Loss: 0.0113, Test Accuracy: 0.9479
# Task 1 (Text) | Test Loss: 0.0098, Test Accuracy: 0.9583
# Task 2 (Text) | Test Loss: 0.0161, Test Accuracy: 0.9688
# Task 3 (Text) | Test Loss: 0.0071, Test Accuracy: 0.9688
# Task 4 (Text) | Test Loss: 0.0083, Test Accuracy: 0.9688
# Task 5 (Text) | Test Loss: 0.0173, Test Accuracy: 0.6562
# Task 6 (Image) | Test Loss: 0.0227, Test Accuracy: 0.6250
# Task 7 (Image) | Test Loss: 0.0210, Test Accuracy: 0.5938
# Task 8 (Image) | Test Loss: 0.0224, Test Accuracy: 0.4375
# Task 9 (Image) | Test Loss: 0.0214, Test Accuracy: 0.4375
# Task 10 (Image) | Test Loss: 0.0218, Test Accuracy: 0.6562
# Task 11 (Image) | Test Loss: 0.0243, Test Accuracy: 0.3750
# Evaluating Euclidean-based Transfer results...
# Task 0 (Text) | Test Loss: 0.0116, Test Accuracy: 0.9479
# Task 1 (Text) | Test Loss: 0.0105, Test Accuracy: 0.9583
# Task 2 (Text) | Test Loss: 0.0163, Test Accuracy: 0.9688
# Task 3 (Text) | Test Loss: 0.0074, Test Accuracy: 0.9688
# Task 4 (Text) | Test Loss: 0.0082, Test Accuracy: 0.9688
# Task 5 (Text) | Test Loss: 0.0181, Test Accuracy: 0.6250
# Task 6 (Image) | Test Loss: 0.0224, Test Accuracy: 0.4375
# Task 7 (Image) | Test Loss: 0.0211, Test Accuracy: 0.5625
# Task 8 (Image) | Test Loss: 0.0222, Test Accuracy: 0.4688
# Task 9 (Image) | Test Loss: 0.0243, Test Accuracy: 0.3438
# Task 10 (Image) | Test Loss: 0.0220, Test Accuracy: 0.6875
# Task 11 (Image) | Test Loss: 0.0242, Test Accuracy: 0.3125
#
# ===== Cosine-based Correct & Incorrect Predictions =====
# ✅ Task 0 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 2: True Label=0, Predicted Label=0
#   - Sample 3: True Label=1, Predicted Label=1
# ❌ Task 0 Incorrect Predictions:
#   - Sample 25: True Label=2, Predicted Label=1
#   - Sample 11: True Label=2, Predicted Label=1
#   - Sample 19: True Label=0, Predicted Label=1
#   - Sample 29: True Label=1, Predicted Label=0
# ------------------------------------------------------------
# ✅ Task 1 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 2: True Label=1, Predicted Label=1
#   - Sample 3: True Label=1, Predicted Label=1
# ❌ Task 1 Incorrect Predictions:
#   - Sample 19: True Label=0, Predicted Label=2
#   - Sample 7: True Label=1, Predicted Label=0
#   - Sample 14: True Label=0, Predicted Label=1
#   - Sample 22: True Label=2, Predicted Label=1
# ------------------------------------------------------------
# ✅ Task 2 Correct Predictions:
#   - Sample 0: True Label=1, Predicted Label=1
#   - Sample 1: True Label=0, Predicted Label=0
#   - Sample 2: True Label=2, Predicted Label=2
#   - Sample 3: True Label=2, Predicted Label=2
# ❌ Task 2 Incorrect Predictions:
#   - Sample 18: True Label=2, Predicted Label=0
#   - Sample 28: True Label=2, Predicted Label=0
#   - Sample 10: True Label=1, Predicted Label=0
#   - Sample 8: True Label=0, Predicted Label=1
# ------------------------------------------------------------
# ✅ Task 3 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=0, Predicted Label=0
#   - Sample 2: True Label=0, Predicted Label=0
#   - Sample 3: True Label=1, Predicted Label=1
# ❌ Task 3 Incorrect Predictions:
#   - Sample 17: True Label=1, Predicted Label=0
#   - Sample 22: True Label=0, Predicted Label=2
#   - Sample 23: True Label=0, Predicted Label=1
#   - Sample 0: True Label=1, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 4 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=2, Predicted Label=2
#   - Sample 2: True Label=2, Predicted Label=2
#   - Sample 3: True Label=2, Predicted Label=2
# ❌ Task 4 Incorrect Predictions:
#   - Sample 22: True Label=0, Predicted Label=1
#   - Sample 20: True Label=0, Predicted Label=2
#   - Sample 23: True Label=2, Predicted Label=0
#   - Sample 21: True Label=0, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 5 Correct Predictions:
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 2: True Label=1, Predicted Label=1
#   - Sample 3: True Label=1, Predicted Label=1
#   - Sample 5: True Label=2, Predicted Label=2
# ❌ Task 5 Incorrect Predictions:
#   - Sample 0: True Label=2, Predicted Label=1
#   - Sample 4: True Label=1, Predicted Label=2
#   - Sample 7: True Label=0, Predicted Label=2
#   - Sample 10: True Label=1, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 6 Correct Predictions:
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 2: True Label=2, Predicted Label=2
#   - Sample 5: True Label=2, Predicted Label=2
#   - Sample 6: True Label=2, Predicted Label=2
# ❌ Task 6 Incorrect Predictions:
#   - Sample 0: True Label=2, Predicted Label=0
#   - Sample 3: True Label=0, Predicted Label=2
#   - Sample 4: True Label=1, Predicted Label=2
#   - Sample 9: True Label=2, Predicted Label=0
# ------------------------------------------------------------
# ✅ Task 7 Correct Predictions:
#   - Sample 0: True Label=1, Predicted Label=1
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 3: True Label=0, Predicted Label=0
#   - Sample 4: True Label=1, Predicted Label=1
# ❌ Task 7 Incorrect Predictions:
#   - Sample 2: True Label=2, Predicted Label=1
#   - Sample 6: True Label=2, Predicted Label=1
#   - Sample 7: True Label=0, Predicted Label=1
#   - Sample 9: True Label=2, Predicted Label=1
# ------------------------------------------------------------
# ✅ Task 8 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=2, Predicted Label=2
#   - Sample 2: True Label=0, Predicted Label=0
#   - Sample 4: True Label=2, Predicted Label=2
# ❌ Task 8 Incorrect Predictions:
#   - Sample 3: True Label=1, Predicted Label=0
#   - Sample 6: True Label=1, Predicted Label=2
#   - Sample 7: True Label=1, Predicted Label=2
#   - Sample 9: True Label=0, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 9 Correct Predictions:
#   - Sample 0: True Label=0, Predicted Label=0
#   - Sample 2: True Label=0, Predicted Label=0
#   - Sample 3: True Label=0, Predicted Label=0
#   - Sample 7: True Label=1, Predicted Label=1
# ❌ Task 9 Incorrect Predictions:
#   - Sample 1: True Label=2, Predicted Label=1
#   - Sample 4: True Label=1, Predicted Label=2
#   - Sample 5: True Label=2, Predicted Label=1
#   - Sample 6: True Label=0, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 10 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=0, Predicted Label=0
#   - Sample 3: True Label=1, Predicted Label=1
#   - Sample 10: True Label=0, Predicted Label=0
# ❌ Task 10 Incorrect Predictions:
#   - Sample 2: True Label=2, Predicted Label=1
#   - Sample 4: True Label=2, Predicted Label=1
#   - Sample 5: True Label=2, Predicted Label=1
#   - Sample 6: True Label=1, Predicted Label=0
# ------------------------------------------------------------
# ✅ Task 11 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 3: True Label=0, Predicted Label=0
#   - Sample 5: True Label=0, Predicted Label=0
#   - Sample 7: True Label=2, Predicted Label=2
# ❌ Task 11 Incorrect Predictions:
#   - Sample 1: True Label=1, Predicted Label=0
#   - Sample 2: True Label=0, Predicted Label=2
#   - Sample 4: True Label=1, Predicted Label=2
#   - Sample 6: True Label=1, Predicted Label=2
# ------------------------------------------------------------
#
# ===== Euclidean-based Correct & Incorrect Predictions =====
# ✅ Task 0 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 2: True Label=0, Predicted Label=0
#   - Sample 3: True Label=1, Predicted Label=1
# ❌ Task 0 Incorrect Predictions:
#   - Sample 25: True Label=2, Predicted Label=1
#   - Sample 11: True Label=2, Predicted Label=1
#   - Sample 19: True Label=0, Predicted Label=1
#   - Sample 29: True Label=1, Predicted Label=0
# ------------------------------------------------------------
# ✅ Task 1 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 2: True Label=1, Predicted Label=1
#   - Sample 3: True Label=1, Predicted Label=1
# ❌ Task 1 Incorrect Predictions:
#   - Sample 19: True Label=0, Predicted Label=2
#   - Sample 7: True Label=1, Predicted Label=0
#   - Sample 14: True Label=0, Predicted Label=1
#   - Sample 22: True Label=2, Predicted Label=1
# ------------------------------------------------------------
# ✅ Task 2 Correct Predictions:
#   - Sample 0: True Label=1, Predicted Label=1
#   - Sample 1: True Label=0, Predicted Label=0
#   - Sample 2: True Label=2, Predicted Label=2
#   - Sample 3: True Label=2, Predicted Label=2
# ❌ Task 2 Incorrect Predictions:
#   - Sample 18: True Label=2, Predicted Label=0
#   - Sample 28: True Label=2, Predicted Label=0
#   - Sample 10: True Label=1, Predicted Label=0
#   - Sample 8: True Label=0, Predicted Label=1
# ------------------------------------------------------------
# ✅ Task 3 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=0, Predicted Label=0
#   - Sample 2: True Label=0, Predicted Label=0
#   - Sample 3: True Label=1, Predicted Label=1
# ❌ Task 3 Incorrect Predictions:
#   - Sample 17: True Label=1, Predicted Label=0
#   - Sample 22: True Label=0, Predicted Label=2
#   - Sample 23: True Label=0, Predicted Label=1
#   - Sample 0: True Label=1, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 4 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=2, Predicted Label=2
#   - Sample 2: True Label=2, Predicted Label=2
#   - Sample 3: True Label=2, Predicted Label=2
# ❌ Task 4 Incorrect Predictions:
#   - Sample 22: True Label=0, Predicted Label=1
#   - Sample 20: True Label=0, Predicted Label=2
#   - Sample 23: True Label=2, Predicted Label=0
#   - Sample 21: True Label=0, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 5 Correct Predictions:
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 2: True Label=1, Predicted Label=1
#   - Sample 3: True Label=1, Predicted Label=1
#   - Sample 5: True Label=2, Predicted Label=2
# ❌ Task 5 Incorrect Predictions:
#   - Sample 0: True Label=2, Predicted Label=1
#   - Sample 4: True Label=1, Predicted Label=2
#   - Sample 7: True Label=0, Predicted Label=2
#   - Sample 10: True Label=1, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 6 Correct Predictions:
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 4: True Label=1, Predicted Label=1
#   - Sample 7: True Label=1, Predicted Label=1
#   - Sample 12: True Label=1, Predicted Label=1
# ❌ Task 6 Incorrect Predictions:
#   - Sample 0: True Label=2, Predicted Label=0
#   - Sample 2: True Label=2, Predicted Label=1
#   - Sample 3: True Label=0, Predicted Label=2
#   - Sample 5: True Label=2, Predicted Label=1
# ------------------------------------------------------------
# ✅ Task 7 Correct Predictions:
#   - Sample 1: True Label=1, Predicted Label=1
#   - Sample 3: True Label=0, Predicted Label=0
#   - Sample 4: True Label=1, Predicted Label=1
#   - Sample 6: True Label=2, Predicted Label=2
# ❌ Task 7 Incorrect Predictions:
#   - Sample 0: True Label=1, Predicted Label=2
#   - Sample 2: True Label=2, Predicted Label=1
#   - Sample 5: True Label=1, Predicted Label=2
#   - Sample 7: True Label=0, Predicted Label=1
# ------------------------------------------------------------
# ✅ Task 8 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=2, Predicted Label=2
#   - Sample 2: True Label=0, Predicted Label=0
#   - Sample 4: True Label=2, Predicted Label=2
# ❌ Task 8 Incorrect Predictions:
#   - Sample 3: True Label=1, Predicted Label=0
#   - Sample 6: True Label=1, Predicted Label=2
#   - Sample 7: True Label=1, Predicted Label=2
#   - Sample 9: True Label=0, Predicted Label=2
# ------------------------------------------------------------
# ✅ Task 9 Correct Predictions:
#   - Sample 0: True Label=0, Predicted Label=0
#   - Sample 3: True Label=0, Predicted Label=0
#   - Sample 8: True Label=1, Predicted Label=1
#   - Sample 10: True Label=1, Predicted Label=1
# ❌ Task 9 Incorrect Predictions:
#   - Sample 1: True Label=2, Predicted Label=0
#   - Sample 2: True Label=0, Predicted Label=1
#   - Sample 4: True Label=1, Predicted Label=0
#   - Sample 5: True Label=2, Predicted Label=0
# ------------------------------------------------------------
# ✅ Task 10 Correct Predictions:
#   - Sample 0: True Label=2, Predicted Label=2
#   - Sample 1: True Label=0, Predicted Label=0
#   - Sample 3: True Label=1, Predicted Label=1
#   - Sample 6: True Label=1, Predicted Label=1
# ❌ Task 10 Incorrect Predictions:
#   - Sample 2: True Label=2, Predicted Label=1
#   - Sample 4: True Label=2, Predicted Label=1
#   - Sample 5: True Label=2, Predicted Label=1
#   - Sample 7: True Label=2, Predicted Label=1
# ------------------------------------------------------------
# ✅ Task 11 Correct Predictions:
#   - Sample 3: True Label=0, Predicted Label=0
#   - Sample 5: True Label=0, Predicted Label=0
#   - Sample 9: True Label=2, Predicted Label=2
#   - Sample 12: True Label=1, Predicted Label=1
# ❌ Task 11 Incorrect Predictions:
#   - Sample 0: True Label=2, Predicted Label=1
#   - Sample 1: True Label=1, Predicted Label=0
#   - Sample 2: True Label=0, Predicted Label=1
#   - Sample 4: True Label=1, Predicted Label=2
# ------------------------------------------------------------

# %%
import pickle

file_path = "/home/youlee/perceiver/perceiver/checkpoints_pruned/text_model_1_pruned.pkl"

try:
    with open(file_path, 'rb') as f:
        model_data = pickle.load(f)
    print("Successfully loaded the file. Keys in the file:")
    print(model_data.keys())
except Exception as e:
    print(f"Error while opening the file: {e}")


# model_state_dict 내부 키 확인
state_dict = model_data["model_state_dict"]
print("Keys in model_state_dict:")
print(list(state_dict.keys())[:10])  # 첫 10개의 키

# masks 내부 키 확인
masks = model_data["masks"]
print("Keys in masks:")
print(list(masks.keys())[:10])  # 첫 10개의 키
# Out:
# Successfully loaded the file. Keys in the file:
# dict_keys(['model_state_dict', 'masks'])
# Keys in model_state_dict:
# ['model.embedding.weight', 'model.perceiver.latents', 'model.perceiver.input_projection.weight', 'model.perceiver.input_projection.bias', 'model.perceiver.blocks.0.cross_attn.in_proj_weight', 'model.perceiver.blocks.0.cross_attn.in_proj_bias', 'model.perceiver.blocks.0.cross_attn.out_proj.weight', 'model.perceiver.blocks.0.cross_attn.out_proj.bias', 'model.perceiver.blocks.0.cross_ln.weight', 'model.perceiver.blocks.0.cross_ln.bias']
# Keys in masks:
# ['text_task_1']

# %%
import pickle

file_path = "/home/youlee/perceiver/perceiver/checkpoints_pruned/image_model_1_pruned.pkl"

try:
    with open(file_path, 'rb') as f:
        model_data = pickle.load(f)
    print("Successfully loaded the file. Keys in the file:")
    print(model_data.keys())
except Exception as e:
    print(f"Error while opening the file: {e}")


# model_state_dict 내부 키 확인
state_dict = model_data["model_state_dict"]
print("Keys in model_state_dict:")
print(list(state_dict.keys())[:10])  # 첫 10개의 키

# masks 내부 키 확인
masks = model_data["masks"]
print("Keys in masks:")
print(list(masks.keys())[:10])  # 첫 10개의 키
# Out:
# Successfully loaded the file. Keys in the file:
# dict_keys(['model_state_dict', 'masks'])
# Keys in model_state_dict:
# ['model.latents', 'model.input_projection.weight', 'model.input_projection.bias', 'model.blocks.0.cross_attn.in_proj_weight', 'model.blocks.0.cross_attn.in_proj_bias', 'model.blocks.0.cross_attn.out_proj.weight', 'model.blocks.0.cross_attn.out_proj.bias', 'model.blocks.0.cross_ln.weight', 'model.blocks.0.cross_ln.bias', 'model.blocks.0.self_attn_layers.0.self_attn.in_proj_weight']
# Keys in masks:
# ['image_task_1']
