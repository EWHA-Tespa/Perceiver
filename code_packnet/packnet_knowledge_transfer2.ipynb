# %%
import pandas as pd
import torch
import pickle
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from perceiver import tokenize_data, CustomDataset, PerceiverBlock, Perceiver, CombinedModel

# Device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.CrossEntropyLoss()

# 경로 설정
pruned_model_dir = "/home/youlee/perceiver/perceiver/checkpoints_pruned2/"
loader_dir = "/home/youlee/perceiver/perceiver/loader/"
batch_size = 32

# %%
# Pruned 모델 로드 함수
def load_pruned_models(pruned_model_dir, model_dir):
    pruned_text_models, pruned_image_models = [], []
    
    # Text 모델 로드
    for i in range(6):
        file_path = f"{pruned_model_dir}/text_model_{i+1}_pruned.pkl"
        model_path = f"{model_dir}/text_model_{i+1}.pkl"
        
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)
        
        model = torch.load(model_path)
        state_dict = {k.replace("model.", ""): v for k, v in model_data["model_state_dict"].items()}
        model.load_state_dict(state_dict, strict=False)
        pruned_text_models.append(model)

    # Image 모델 로드
    for i in range(6):
        file_path = f"{pruned_model_dir}/image_model_{i+1}_pruned.pkl"
        model_path = f"{model_dir}/image_model_{i+1}.pkl"
        
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)
        
        model = torch.load(model_path)
        state_dict = {k.replace("model.", ""): v for k, v in model_data["model_state_dict"].items()}
        model.load_state_dict(state_dict, strict=False)
        pruned_image_models.append(model)

    return pruned_text_models, pruned_image_models

# %%
# Validation 데이터 로드 함수
def load_valid_loaders():
    valid_loaders = []
    for i in range(6):
        with open(f"{loader_dir}text_val_loader_{i+1}.pkl", 'rb') as f:
            valid_loaders.append(pickle.load(f))
    for i in range(6):
        with open(f"{loader_dir}image_val_loader_{i+1}.pkl", 'rb') as f:
            valid_dataset = pickle.load(f)
            valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
            valid_loaders.append(valid_loader)
    return valid_loaders

# %%
# 키 매핑 함수
def map_keys(state_dict, modality):
    key_map = {}
    for key in state_dict.keys():
        if modality == "Text" and "model.perceiver" in key:
            key_map[key] = key.replace("model.perceiver", "model")
        elif modality == "Image" and "model." in key:
            key_map[key] = key.replace("model.", "model.perceiver")
        else:
            key_map[key] = key
    return key_map

# 가중치 매핑 및 로드 함수
def apply_mapped_state_dict(task_model, backbone_model, modality):
    backbone_state_dict = backbone_model.state_dict()
    key_map = map_keys(backbone_state_dict, modality)
    mapped_state_dict = {key_map[k]: v for k, v in backbone_state_dict.items()}
    task_model.load_state_dict(mapped_state_dict, strict=False)
    print(f"Successfully applied backbone weights for {modality} task.")

# %%
def knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                       task_models, backbone_models, valid_loaders, criterion, device, epochs=20):
    if backbone_modality == "Text":
        backbone_model = backbone_models[backbone_id]
    else:
        backbone_model = backbone_models[backbone_id - 6]

    task_model = task_models[task_id]
    task_model.to(device)

    apply_mapped_state_dict(task_model, backbone_model, backbone_modality)

    optimizer = optim.SGD(task_model.parameters(), lr=0.001, momentum=0.9)
    task_model.train()
    
    for epoch in range(epochs):
        total_loss = 0
        correct = 0
        total = 0

        for batch in valid_loaders[task_id]:
            optimizer.zero_grad()
            if task_modality == "Text":
                inputs = batch["input_ids"].to(device)
                labels = batch["labels"].to(device)
                outputs = task_model(inputs)
            else:
                inputs, labels = batch
                inputs = inputs.to(device)
                labels = labels.to(device)
                outputs = task_model(inputs)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        print(f"Task {task_id} | Backbone {backbone_id} | Epoch {epoch+1}/{epochs} | Loss: {total_loss:.4f} | Accuracy: {correct/total:.4f}")
    return task_model

# %%
def eval_epoch(model, dataloader, criterion, device, is_text: bool):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch in dataloader:
            if is_text:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)
                outputs = model(input_ids)
            else:
                inputs, labels = batch
                inputs = inputs.to(device)
                labels = labels.to(device)
                outputs = model(inputs)

            loss = criterion(outputs, labels)
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    return avg_loss, accuracy

# %%
# 최종 평가 함수
def evaluate_transfer(models, valid_loaders, criterion, device):
    for i, model in enumerate(models):
        is_text = i < 6
        test_loss, test_acc = eval_epoch(model, valid_loaders[i], criterion, device, is_text)
        modality = "Text" if is_text else "Image"
        print(f"Task {i} ({modality}) | Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

# %%
# Cosine 및 Euclidean 결과 로드
cosine_results = pd.read_csv("/home/youlee/perceiver/perceiver/code/best_cosine_results.txt", sep='\t')
euclidean_results = pd.read_csv("/home/youlee/perceiver/perceiver/code/best_euclidean_results.txt", sep='\t')
cosine_task_to_backbone = {row["Task_ID"]: row["Best_Target_ID"] for _, row in cosine_results.iterrows()}
euclidean_task_to_backbone = {row["Task_ID"]: row["Best_Target_ID"] for _, row in euclidean_results.iterrows()}

# %%
if __name__ == "__main__":
    print("Loading pruned models and validation loaders...")
    
    pruned_text_models, pruned_image_models = load_pruned_models(pruned_model_dir, "/home/youlee/perceiver/perceiver/model")
    valid_loaders = load_valid_loaders()
    pruned_models = pruned_text_models + pruned_image_models

    print("Starting Cosine-based Knowledge Transfer...")
    for task_id, backbone_id in cosine_task_to_backbone.items():
        backbone_modality = cosine_results.loc[cosine_results["Task_ID"] == task_id, "Target_Modality"].values[0]
        task_modality = cosine_results.loc[cosine_results["Task_ID"] == task_id, "Task_Modality"].values[0]
        knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                           pruned_models, pruned_models, valid_loaders, criterion, device)

    print("Starting Euclidean-based Knowledge Transfer...")
    for task_id, backbone_id in euclidean_task_to_backbone.items():
        backbone_modality = euclidean_results.loc[euclidean_results["Task_ID"] == task_id, "Target_Modality"].values[0]
        task_modality = euclidean_results.loc[euclidean_results["Task_ID"] == task_id, "Task_Modality"].values[0]
        knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                           pruned_models, pruned_models, valid_loaders, criterion, device)

    print("Evaluating final results...")
    evaluate_transfer(pruned_models, valid_loaders, criterion, device)
# Out:
# Loading pruned models and validation loaders...
# /tmp/ipykernel_2176991/631762024.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)
# /tmp/ipykernel_2176991/631762024.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)
# Starting Cosine-based Knowledge Transfer...
# Successfully applied backbone weights for Image task.
# Task 0 | Backbone 9 | Epoch 1/20 | Loss: 96.4009 | Accuracy: 0.4259
# Task 0 | Backbone 9 | Epoch 2/20 | Loss: 45.1834 | Accuracy: 0.5171
# Task 0 | Backbone 9 | Epoch 3/20 | Loss: 43.1964 | Accuracy: 0.5535
# Task 0 | Backbone 9 | Epoch 4/20 | Loss: 41.7833 | Accuracy: 0.5809
# Task 0 | Backbone 9 | Epoch 5/20 | Loss: 40.2946 | Accuracy: 0.6049
# Task 0 | Backbone 9 | Epoch 6/20 | Loss: 38.6543 | Accuracy: 0.6331
# Task 0 | Backbone 9 | Epoch 7/20 | Loss: 37.1833 | Accuracy: 0.6605
# Task 0 | Backbone 9 | Epoch 8/20 | Loss: 35.7304 | Accuracy: 0.6831
# Task 0 | Backbone 9 | Epoch 9/20 | Loss: 34.4477 | Accuracy: 0.6989
# Task 0 | Backbone 9 | Epoch 10/20 | Loss: 33.1995 | Accuracy: 0.7099
# Task 0 | Backbone 9 | Epoch 11/20 | Loss: 32.0741 | Accuracy: 0.7257
# Task 0 | Backbone 9 | Epoch 12/20 | Loss: 30.9605 | Accuracy: 0.7366
# Task 0 | Backbone 9 | Epoch 13/20 | Loss: 29.6148 | Accuracy: 0.7524
# Task 0 | Backbone 9 | Epoch 14/20 | Loss: 28.2834 | Accuracy: 0.7627
# Task 0 | Backbone 9 | Epoch 15/20 | Loss: 26.8770 | Accuracy: 0.7730
# Task 0 | Backbone 9 | Epoch 16/20 | Loss: 25.4466 | Accuracy: 0.7922
# Task 0 | Backbone 9 | Epoch 17/20 | Loss: 24.0629 | Accuracy: 0.8073
# Task 0 | Backbone 9 | Epoch 18/20 | Loss: 22.8026 | Accuracy: 0.8210
# Task 0 | Backbone 9 | Epoch 19/20 | Loss: 21.3139 | Accuracy: 0.8374
# Task 0 | Backbone 9 | Epoch 20/20 | Loss: 19.8173 | Accuracy: 0.8594
# Successfully applied backbone weights for Image task.
# Task 1 | Backbone 10 | Epoch 1/20 | Loss: 90.5129 | Accuracy: 0.3271
# Task 1 | Backbone 10 | Epoch 2/20 | Loss: 49.6919 | Accuracy: 0.4065
# Task 1 | Backbone 10 | Epoch 3/20 | Loss: 48.8202 | Accuracy: 0.4182
# Task 1 | Backbone 10 | Epoch 4/20 | Loss: 48.1997 | Accuracy: 0.4300
# Task 1 | Backbone 10 | Epoch 5/20 | Loss: 47.4531 | Accuracy: 0.4534
# Task 1 | Backbone 10 | Epoch 6/20 | Loss: 46.4571 | Accuracy: 0.4755
# Task 1 | Backbone 10 | Epoch 7/20 | Loss: 45.1407 | Accuracy: 0.5355
# Task 1 | Backbone 10 | Epoch 8/20 | Loss: 43.9598 | Accuracy: 0.5390
# Task 1 | Backbone 10 | Epoch 9/20 | Loss: 42.9823 | Accuracy: 0.5535
# Task 1 | Backbone 10 | Epoch 10/20 | Loss: 42.0584 | Accuracy: 0.5638
# Task 1 | Backbone 10 | Epoch 11/20 | Loss: 41.1387 | Accuracy: 0.5707
# Task 1 | Backbone 10 | Epoch 12/20 | Loss: 40.2121 | Accuracy: 0.5811
# Task 1 | Backbone 10 | Epoch 13/20 | Loss: 39.1377 | Accuracy: 0.5894
# Task 1 | Backbone 10 | Epoch 14/20 | Loss: 38.0201 | Accuracy: 0.6046
# Task 1 | Backbone 10 | Epoch 15/20 | Loss: 36.7958 | Accuracy: 0.6225
# Task 1 | Backbone 10 | Epoch 16/20 | Loss: 35.7010 | Accuracy: 0.6349
# Task 1 | Backbone 10 | Epoch 17/20 | Loss: 34.6160 | Accuracy: 0.6487
# Task 1 | Backbone 10 | Epoch 18/20 | Loss: 33.5508 | Accuracy: 0.6591
# Task 1 | Backbone 10 | Epoch 19/20 | Loss: 32.5613 | Accuracy: 0.6660
# Task 1 | Backbone 10 | Epoch 20/20 | Loss: 31.6578 | Accuracy: 0.6784
# Successfully applied backbone weights for Image task.
# Task 2 | Backbone 8 | Epoch 1/20 | Loss: 27.2586 | Accuracy: 0.8409
# Task 2 | Backbone 8 | Epoch 2/20 | Loss: 18.2087 | Accuracy: 0.8741
# Task 2 | Backbone 8 | Epoch 3/20 | Loss: 16.1611 | Accuracy: 0.8817
# Task 2 | Backbone 8 | Epoch 4/20 | Loss: 14.9377 | Accuracy: 0.8963
# Task 2 | Backbone 8 | Epoch 5/20 | Loss: 14.0299 | Accuracy: 0.9039
# Task 2 | Backbone 8 | Epoch 6/20 | Loss: 13.2934 | Accuracy: 0.9122
# Task 2 | Backbone 8 | Epoch 7/20 | Loss: 12.7123 | Accuracy: 0.9149
# Task 2 | Backbone 8 | Epoch 8/20 | Loss: 12.0773 | Accuracy: 0.9225
# Task 2 | Backbone 8 | Epoch 9/20 | Loss: 11.6973 | Accuracy: 0.9253
# Task 2 | Backbone 8 | Epoch 10/20 | Loss: 11.2585 | Accuracy: 0.9315
# Task 2 | Backbone 8 | Epoch 11/20 | Loss: 10.8317 | Accuracy: 0.9336
# Task 2 | Backbone 8 | Epoch 12/20 | Loss: 10.4579 | Accuracy: 0.9336
# Task 2 | Backbone 8 | Epoch 13/20 | Loss: 10.0986 | Accuracy: 0.9405
# Task 2 | Backbone 8 | Epoch 14/20 | Loss: 9.6343 | Accuracy: 0.9454
# Task 2 | Backbone 8 | Epoch 15/20 | Loss: 9.3124 | Accuracy: 0.9474
# Task 2 | Backbone 8 | Epoch 16/20 | Loss: 8.9721 | Accuracy: 0.9502
# Task 2 | Backbone 8 | Epoch 17/20 | Loss: 8.7303 | Accuracy: 0.9530
# Task 2 | Backbone 8 | Epoch 18/20 | Loss: 8.5552 | Accuracy: 0.9571
# Task 2 | Backbone 8 | Epoch 19/20 | Loss: 8.3853 | Accuracy: 0.9564
# Task 2 | Backbone 8 | Epoch 20/20 | Loss: 8.1531 | Accuracy: 0.9585
# Successfully applied backbone weights for Image task.
# Task 3 | Backbone 10 | Epoch 1/20 | Loss: 90.5750 | Accuracy: 0.3496
# Task 3 | Backbone 10 | Epoch 2/20 | Loss: 49.3923 | Accuracy: 0.3565
# Task 3 | Backbone 10 | Epoch 3/20 | Loss: 49.2106 | Accuracy: 0.3531
# Task 3 | Backbone 10 | Epoch 4/20 | Loss: 49.1051 | Accuracy: 0.3565
# Task 3 | Backbone 10 | Epoch 5/20 | Loss: 48.9754 | Accuracy: 0.3663
# Task 3 | Backbone 10 | Epoch 6/20 | Loss: 48.8432 | Accuracy: 0.3760
# Task 3 | Backbone 10 | Epoch 7/20 | Loss: 48.6590 | Accuracy: 0.3781
# Task 3 | Backbone 10 | Epoch 8/20 | Loss: 48.4439 | Accuracy: 0.3865
# Task 3 | Backbone 10 | Epoch 9/20 | Loss: 48.1872 | Accuracy: 0.3983
# Task 3 | Backbone 10 | Epoch 10/20 | Loss: 47.8079 | Accuracy: 0.4011
# Task 3 | Backbone 10 | Epoch 11/20 | Loss: 47.3752 | Accuracy: 0.4178
# Task 3 | Backbone 10 | Epoch 12/20 | Loss: 46.8680 | Accuracy: 0.4297
# Task 3 | Backbone 10 | Epoch 13/20 | Loss: 46.2939 | Accuracy: 0.4422
# Task 3 | Backbone 10 | Epoch 14/20 | Loss: 45.5552 | Accuracy: 0.4701
# Task 3 | Backbone 10 | Epoch 15/20 | Loss: 44.8403 | Accuracy: 0.4791
# Task 3 | Backbone 10 | Epoch 16/20 | Loss: 44.0258 | Accuracy: 0.5056
# Task 3 | Backbone 10 | Epoch 17/20 | Loss: 43.1681 | Accuracy: 0.5299
# Task 3 | Backbone 10 | Epoch 18/20 | Loss: 42.2848 | Accuracy: 0.5508
# Task 3 | Backbone 10 | Epoch 19/20 | Loss: 41.3270 | Accuracy: 0.5655
# Task 3 | Backbone 10 | Epoch 20/20 | Loss: 40.3643 | Accuracy: 0.5836
# Successfully applied backbone weights for Image task.
# Task 4 | Backbone 10 | Epoch 1/20 | Loss: 28.3895 | Accuracy: 0.8376
# Task 4 | Backbone 10 | Epoch 2/20 | Loss: 17.7173 | Accuracy: 0.8803
# Task 4 | Backbone 10 | Epoch 3/20 | Loss: 15.6614 | Accuracy: 0.8887
# Task 4 | Backbone 10 | Epoch 4/20 | Loss: 14.0046 | Accuracy: 0.9076
# Task 4 | Backbone 10 | Epoch 5/20 | Loss: 12.8217 | Accuracy: 0.9202
# Task 4 | Backbone 10 | Epoch 6/20 | Loss: 11.9443 | Accuracy: 0.9286
# Task 4 | Backbone 10 | Epoch 7/20 | Loss: 11.2266 | Accuracy: 0.9356
# Task 4 | Backbone 10 | Epoch 8/20 | Loss: 10.6007 | Accuracy: 0.9405
# Task 4 | Backbone 10 | Epoch 9/20 | Loss: 10.0464 | Accuracy: 0.9447
# Task 4 | Backbone 10 | Epoch 10/20 | Loss: 9.6673 | Accuracy: 0.9489
# Task 4 | Backbone 10 | Epoch 11/20 | Loss: 8.9830 | Accuracy: 0.9559
# Task 4 | Backbone 10 | Epoch 12/20 | Loss: 8.5560 | Accuracy: 0.9580
# Task 4 | Backbone 10 | Epoch 13/20 | Loss: 8.2148 | Accuracy: 0.9615
# Task 4 | Backbone 10 | Epoch 14/20 | Loss: 7.9892 | Accuracy: 0.9622
# Task 4 | Backbone 10 | Epoch 15/20 | Loss: 7.7565 | Accuracy: 0.9629
# Task 4 | Backbone 10 | Epoch 16/20 | Loss: 7.4437 | Accuracy: 0.9643
# Task 4 | Backbone 10 | Epoch 17/20 | Loss: 7.1566 | Accuracy: 0.9671
# Task 4 | Backbone 10 | Epoch 18/20 | Loss: 6.9780 | Accuracy: 0.9664
# Task 4 | Backbone 10 | Epoch 19/20 | Loss: 6.6817 | Accuracy: 0.9685
# Task 4 | Backbone 10 | Epoch 20/20 | Loss: 6.5323 | Accuracy: 0.9706
# Successfully applied backbone weights for Text task.
# Task 5 | Backbone 4 | Epoch 1/20 | Loss: 72.2128 | Accuracy: 0.3593
# Task 5 | Backbone 4 | Epoch 2/20 | Loss: 46.0414 | Accuracy: 0.4036
# Task 5 | Backbone 4 | Epoch 3/20 | Loss: 43.7994 | Accuracy: 0.5098
# Task 5 | Backbone 4 | Epoch 4/20 | Loss: 41.4714 | Accuracy: 0.5491
# Task 5 | Backbone 4 | Epoch 5/20 | Loss: 39.7891 | Accuracy: 0.5833
# Task 5 | Backbone 4 | Epoch 6/20 | Loss: 38.2687 | Accuracy: 0.6058
# Task 5 | Backbone 4 | Epoch 7/20 | Loss: 36.6983 | Accuracy: 0.6298
# Task 5 | Backbone 4 | Epoch 8/20 | Loss: 35.3405 | Accuracy: 0.6480
# Task 5 | Backbone 4 | Epoch 9/20 | Loss: 34.1972 | Accuracy: 0.6713
# Task 5 | Backbone 4 | Epoch 10/20 | Loss: 33.2536 | Accuracy: 0.6865
# Task 5 | Backbone 4 | Epoch 11/20 | Loss: 32.3256 | Accuracy: 0.6960
# Task 5 | Backbone 4 | Epoch 12/20 | Loss: 31.4033 | Accuracy: 0.7120
# Task 5 | Backbone 4 | Epoch 13/20 | Loss: 30.4610 | Accuracy: 0.7244
# Task 5 | Backbone 4 | Epoch 14/20 | Loss: 29.5303 | Accuracy: 0.7360
# Task 5 | Backbone 4 | Epoch 15/20 | Loss: 28.5805 | Accuracy: 0.7476
# Task 5 | Backbone 4 | Epoch 16/20 | Loss: 27.5231 | Accuracy: 0.7658
# Task 5 | Backbone 4 | Epoch 17/20 | Loss: 26.6866 | Accuracy: 0.7702
# Task 5 | Backbone 4 | Epoch 18/20 | Loss: 25.9989 | Accuracy: 0.7855
# Task 5 | Backbone 4 | Epoch 19/20 | Loss: 25.3064 | Accuracy: 0.7927
# Task 5 | Backbone 4 | Epoch 20/20 | Loss: 24.5339 | Accuracy: 0.8029
# Successfully applied backbone weights for Image task.
# Task 6 | Backbone 10 | Epoch 1/20 | Loss: 36.6311 | Accuracy: 0.6337
# Task 6 | Backbone 10 | Epoch 2/20 | Loss: 32.6377 | Accuracy: 0.6866
# Task 6 | Backbone 10 | Epoch 3/20 | Loss: 31.9069 | Accuracy: 0.6886
# Task 6 | Backbone 10 | Epoch 4/20 | Loss: 31.4151 | Accuracy: 0.6920
# Task 6 | Backbone 10 | Epoch 5/20 | Loss: 30.9129 | Accuracy: 0.6996
# Task 6 | Backbone 10 | Epoch 6/20 | Loss: 30.8159 | Accuracy: 0.6996
# Task 6 | Backbone 10 | Epoch 7/20 | Loss: 30.3108 | Accuracy: 0.7085
# Task 6 | Backbone 10 | Epoch 8/20 | Loss: 30.1329 | Accuracy: 0.7160
# Task 6 | Backbone 10 | Epoch 9/20 | Loss: 29.6773 | Accuracy: 0.7174
# Task 6 | Backbone 10 | Epoch 10/20 | Loss: 29.6914 | Accuracy: 0.7209
# Task 6 | Backbone 10 | Epoch 11/20 | Loss: 30.0249 | Accuracy: 0.7106
# Task 6 | Backbone 10 | Epoch 12/20 | Loss: 29.9265 | Accuracy: 0.7154
# Task 6 | Backbone 10 | Epoch 13/20 | Loss: 30.1373 | Accuracy: 0.7188
# Task 6 | Backbone 10 | Epoch 14/20 | Loss: 30.4212 | Accuracy: 0.7147
# Task 6 | Backbone 10 | Epoch 15/20 | Loss: 29.7727 | Accuracy: 0.7222
# Task 6 | Backbone 10 | Epoch 16/20 | Loss: 29.4725 | Accuracy: 0.7215
# Task 6 | Backbone 10 | Epoch 17/20 | Loss: 28.9879 | Accuracy: 0.7332
# Task 6 | Backbone 10 | Epoch 18/20 | Loss: 28.3538 | Accuracy: 0.7421
# Task 6 | Backbone 10 | Epoch 19/20 | Loss: 28.3700 | Accuracy: 0.7407
# Task 6 | Backbone 10 | Epoch 20/20 | Loss: 27.4181 | Accuracy: 0.7558
# Successfully applied backbone weights for Text task.
# Task 7 | Backbone 0 | Epoch 1/20 | Loss: 40.1256 | Accuracy: 0.5742
# Task 7 | Backbone 0 | Epoch 2/20 | Loss: 37.3036 | Accuracy: 0.6066
# Task 7 | Backbone 0 | Epoch 3/20 | Loss: 36.5971 | Accuracy: 0.6108
# Task 7 | Backbone 0 | Epoch 4/20 | Loss: 36.5323 | Accuracy: 0.6170
# Task 7 | Backbone 0 | Epoch 5/20 | Loss: 36.1462 | Accuracy: 0.6108
# Task 7 | Backbone 0 | Epoch 6/20 | Loss: 35.5109 | Accuracy: 0.6301
# Task 7 | Backbone 0 | Epoch 7/20 | Loss: 35.1957 | Accuracy: 0.6287
# Task 7 | Backbone 0 | Epoch 8/20 | Loss: 34.7997 | Accuracy: 0.6329
# Task 7 | Backbone 0 | Epoch 9/20 | Loss: 34.2301 | Accuracy: 0.6432
# Task 7 | Backbone 0 | Epoch 10/20 | Loss: 33.8797 | Accuracy: 0.6453
# Task 7 | Backbone 0 | Epoch 11/20 | Loss: 33.3010 | Accuracy: 0.6529
# Task 7 | Backbone 0 | Epoch 12/20 | Loss: 32.5536 | Accuracy: 0.6549
# Task 7 | Backbone 0 | Epoch 13/20 | Loss: 31.8278 | Accuracy: 0.6632
# Task 7 | Backbone 0 | Epoch 14/20 | Loss: 31.2629 | Accuracy: 0.6777
# Task 7 | Backbone 0 | Epoch 15/20 | Loss: 30.7018 | Accuracy: 0.6908
# Task 7 | Backbone 0 | Epoch 16/20 | Loss: 30.5699 | Accuracy: 0.6950
# Task 7 | Backbone 0 | Epoch 17/20 | Loss: 30.3465 | Accuracy: 0.6963
# Task 7 | Backbone 0 | Epoch 18/20 | Loss: 30.5160 | Accuracy: 0.6901
# Task 7 | Backbone 0 | Epoch 19/20 | Loss: 29.9644 | Accuracy: 0.6936
# Task 7 | Backbone 0 | Epoch 20/20 | Loss: 29.0301 | Accuracy: 0.7074
# Successfully applied backbone weights for Image task.
# Task 8 | Backbone 6 | Epoch 1/20 | Loss: 44.8571 | Accuracy: 0.5166
# Task 8 | Backbone 6 | Epoch 2/20 | Loss: 43.1244 | Accuracy: 0.5429
# Task 8 | Backbone 6 | Epoch 3/20 | Loss: 43.0903 | Accuracy: 0.5456
# Task 8 | Backbone 6 | Epoch 4/20 | Loss: 42.6234 | Accuracy: 0.5567
# Task 8 | Backbone 6 | Epoch 5/20 | Loss: 42.1575 | Accuracy: 0.5615
# Task 8 | Backbone 6 | Epoch 6/20 | Loss: 42.0150 | Accuracy: 0.5685
# Task 8 | Backbone 6 | Epoch 7/20 | Loss: 41.7686 | Accuracy: 0.5712
# Task 8 | Backbone 6 | Epoch 8/20 | Loss: 41.3962 | Accuracy: 0.5816
# Task 8 | Backbone 6 | Epoch 9/20 | Loss: 40.8981 | Accuracy: 0.5885
# Task 8 | Backbone 6 | Epoch 10/20 | Loss: 40.7255 | Accuracy: 0.5947
# Task 8 | Backbone 6 | Epoch 11/20 | Loss: 40.3723 | Accuracy: 0.6086
# Task 8 | Backbone 6 | Epoch 12/20 | Loss: 40.0614 | Accuracy: 0.6162
# Task 8 | Backbone 6 | Epoch 13/20 | Loss: 39.6993 | Accuracy: 0.6189
# Task 8 | Backbone 6 | Epoch 14/20 | Loss: 39.1567 | Accuracy: 0.6245
# Task 8 | Backbone 6 | Epoch 15/20 | Loss: 38.7527 | Accuracy: 0.6314
# Task 8 | Backbone 6 | Epoch 16/20 | Loss: 38.3744 | Accuracy: 0.6314
# Task 8 | Backbone 6 | Epoch 17/20 | Loss: 37.8716 | Accuracy: 0.6418
# Task 8 | Backbone 6 | Epoch 18/20 | Loss: 38.4804 | Accuracy: 0.6300
# Task 8 | Backbone 6 | Epoch 19/20 | Loss: 37.6392 | Accuracy: 0.6508
# Task 8 | Backbone 6 | Epoch 20/20 | Loss: 37.8270 | Accuracy: 0.6418
# Successfully applied backbone weights for Text task.
# Task 9 | Backbone 0 | Epoch 1/20 | Loss: 42.5351 | Accuracy: 0.5675
# Task 9 | Backbone 0 | Epoch 2/20 | Loss: 40.5980 | Accuracy: 0.6024
# Task 9 | Backbone 0 | Epoch 3/20 | Loss: 40.0221 | Accuracy: 0.6086
# Task 9 | Backbone 0 | Epoch 4/20 | Loss: 39.0244 | Accuracy: 0.6302
# Task 9 | Backbone 0 | Epoch 5/20 | Loss: 38.0616 | Accuracy: 0.6400
# Task 9 | Backbone 0 | Epoch 6/20 | Loss: 37.3610 | Accuracy: 0.6560
# Task 9 | Backbone 0 | Epoch 7/20 | Loss: 37.1363 | Accuracy: 0.6595
# Task 9 | Backbone 0 | Epoch 8/20 | Loss: 36.0080 | Accuracy: 0.6852
# Task 9 | Backbone 0 | Epoch 9/20 | Loss: 35.3744 | Accuracy: 0.6943
# Task 9 | Backbone 0 | Epoch 10/20 | Loss: 35.0662 | Accuracy: 0.6915
# Task 9 | Backbone 0 | Epoch 11/20 | Loss: 35.3059 | Accuracy: 0.6950
# Task 9 | Backbone 0 | Epoch 12/20 | Loss: 34.8319 | Accuracy: 0.6971
# Task 9 | Backbone 0 | Epoch 13/20 | Loss: 33.6806 | Accuracy: 0.7089
# Task 9 | Backbone 0 | Epoch 14/20 | Loss: 32.4328 | Accuracy: 0.7277
# Task 9 | Backbone 0 | Epoch 15/20 | Loss: 31.6659 | Accuracy: 0.7368
# Task 9 | Backbone 0 | Epoch 16/20 | Loss: 30.6217 | Accuracy: 0.7486
# Task 9 | Backbone 0 | Epoch 17/20 | Loss: 30.5251 | Accuracy: 0.7465
# Task 9 | Backbone 0 | Epoch 18/20 | Loss: 30.8583 | Accuracy: 0.7403
# Task 9 | Backbone 0 | Epoch 19/20 | Loss: 29.7318 | Accuracy: 0.7584
# Task 9 | Backbone 0 | Epoch 20/20 | Loss: 29.4853 | Accuracy: 0.7444
# Successfully applied backbone weights for Image task.
# Task 10 | Backbone 6 | Epoch 1/20 | Loss: 45.3469 | Accuracy: 0.4990
# Task 10 | Backbone 6 | Epoch 2/20 | Loss: 40.5112 | Accuracy: 0.5682
# Task 10 | Backbone 6 | Epoch 3/20 | Loss: 40.1972 | Accuracy: 0.5710
# Task 10 | Backbone 6 | Epoch 4/20 | Loss: 39.9048 | Accuracy: 0.5717
# Task 10 | Backbone 6 | Epoch 5/20 | Loss: 37.8430 | Accuracy: 0.6046
# Task 10 | Backbone 6 | Epoch 6/20 | Loss: 37.6171 | Accuracy: 0.6053
# Task 10 | Backbone 6 | Epoch 7/20 | Loss: 37.4912 | Accuracy: 0.6060
# Task 10 | Backbone 6 | Epoch 8/20 | Loss: 36.9257 | Accuracy: 0.6067
# Task 10 | Backbone 6 | Epoch 9/20 | Loss: 36.4734 | Accuracy: 0.6158
# Task 10 | Backbone 6 | Epoch 10/20 | Loss: 36.0551 | Accuracy: 0.6326
# Task 10 | Backbone 6 | Epoch 11/20 | Loss: 36.0552 | Accuracy: 0.6284
# Task 10 | Backbone 6 | Epoch 12/20 | Loss: 35.7387 | Accuracy: 0.6312
# Task 10 | Backbone 6 | Epoch 13/20 | Loss: 35.3085 | Accuracy: 0.6396
# Task 10 | Backbone 6 | Epoch 14/20 | Loss: 34.9319 | Accuracy: 0.6410
# Task 10 | Backbone 6 | Epoch 15/20 | Loss: 34.5462 | Accuracy: 0.6389
# Task 10 | Backbone 6 | Epoch 16/20 | Loss: 34.3905 | Accuracy: 0.6445
# Task 10 | Backbone 6 | Epoch 17/20 | Loss: 34.9254 | Accuracy: 0.6361
# Task 10 | Backbone 6 | Epoch 18/20 | Loss: 34.2984 | Accuracy: 0.6424
# Task 10 | Backbone 6 | Epoch 19/20 | Loss: 33.9939 | Accuracy: 0.6396
# Task 10 | Backbone 6 | Epoch 20/20 | Loss: 34.5009 | Accuracy: 0.6403
# Successfully applied backbone weights for Image task.
# Task 11 | Backbone 10 | Epoch 1/20 | Loss: 42.2436 | Accuracy: 0.5047
# Task 11 | Backbone 10 | Epoch 2/20 | Loss: 41.2508 | Accuracy: 0.5236
# Task 11 | Backbone 10 | Epoch 3/20 | Loss: 40.9282 | Accuracy: 0.5324
# Task 11 | Backbone 10 | Epoch 4/20 | Loss: 40.6544 | Accuracy: 0.5375
# Task 11 | Backbone 10 | Epoch 5/20 | Loss: 40.4202 | Accuracy: 0.5382
# Task 11 | Backbone 10 | Epoch 6/20 | Loss: 40.2889 | Accuracy: 0.5440
# Task 11 | Backbone 10 | Epoch 7/20 | Loss: 39.9419 | Accuracy: 0.5469
# Task 11 | Backbone 10 | Epoch 8/20 | Loss: 39.6745 | Accuracy: 0.5593
# Task 11 | Backbone 10 | Epoch 9/20 | Loss: 39.2784 | Accuracy: 0.5695
# Task 11 | Backbone 10 | Epoch 10/20 | Loss: 38.7355 | Accuracy: 0.5738
# Task 11 | Backbone 10 | Epoch 11/20 | Loss: 38.5672 | Accuracy: 0.5804
# Task 11 | Backbone 10 | Epoch 12/20 | Loss: 38.1148 | Accuracy: 0.5760
# Task 11 | Backbone 10 | Epoch 13/20 | Loss: 38.2277 | Accuracy: 0.5702
# Task 11 | Backbone 10 | Epoch 14/20 | Loss: 37.4265 | Accuracy: 0.5891
# Task 11 | Backbone 10 | Epoch 15/20 | Loss: 37.6056 | Accuracy: 0.5898
# Task 11 | Backbone 10 | Epoch 16/20 | Loss: 38.0737 | Accuracy: 0.5775
# Task 11 | Backbone 10 | Epoch 17/20 | Loss: 37.5295 | Accuracy: 0.5956
# Task 11 | Backbone 10 | Epoch 18/20 | Loss: 37.2006 | Accuracy: 0.6051
# Task 11 | Backbone 10 | Epoch 19/20 | Loss: 37.4925 | Accuracy: 0.6015
# Task 11 | Backbone 10 | Epoch 20/20 | Loss: 37.6723 | Accuracy: 0.6044
# Starting Euclidean-based Knowledge Transfer...
# Successfully applied backbone weights for Image task.
# Task 0 | Backbone 7 | Epoch 1/20 | Loss: 58.5516 | Accuracy: 0.3875
# Task 0 | Backbone 7 | Epoch 2/20 | Loss: 42.7647 | Accuracy: 0.5000
# Task 0 | Backbone 7 | Epoch 3/20 | Loss: 39.8625 | Accuracy: 0.5302
# Task 0 | Backbone 7 | Epoch 4/20 | Loss: 37.7728 | Accuracy: 0.5665
# Task 0 | Backbone 7 | Epoch 5/20 | Loss: 36.3806 | Accuracy: 0.5768
# Task 0 | Backbone 7 | Epoch 6/20 | Loss: 35.3360 | Accuracy: 0.5953
# Task 0 | Backbone 7 | Epoch 7/20 | Loss: 34.4891 | Accuracy: 0.6228
# Task 0 | Backbone 7 | Epoch 8/20 | Loss: 33.8068 | Accuracy: 0.6358
# Task 0 | Backbone 7 | Epoch 9/20 | Loss: 33.1867 | Accuracy: 0.6536
# Task 0 | Backbone 7 | Epoch 10/20 | Loss: 32.5653 | Accuracy: 0.6578
# Task 0 | Backbone 7 | Epoch 11/20 | Loss: 31.9921 | Accuracy: 0.6591
# Task 0 | Backbone 7 | Epoch 12/20 | Loss: 31.4057 | Accuracy: 0.6639
# Task 0 | Backbone 7 | Epoch 13/20 | Loss: 30.7750 | Accuracy: 0.6680
# Task 0 | Backbone 7 | Epoch 14/20 | Loss: 30.1321 | Accuracy: 0.6763
# Task 0 | Backbone 7 | Epoch 15/20 | Loss: 29.4332 | Accuracy: 0.6920
# Task 0 | Backbone 7 | Epoch 16/20 | Loss: 28.7266 | Accuracy: 0.7154
# Task 0 | Backbone 7 | Epoch 17/20 | Loss: 27.9179 | Accuracy: 0.7332
# Task 0 | Backbone 7 | Epoch 18/20 | Loss: 27.0565 | Accuracy: 0.7517
# Task 0 | Backbone 7 | Epoch 19/20 | Loss: 26.0935 | Accuracy: 0.7689
# Task 0 | Backbone 7 | Epoch 20/20 | Loss: 25.1988 | Accuracy: 0.7798
# Successfully applied backbone weights for Image task.
# Task 1 | Backbone 10 | Epoch 1/20 | Loss: 74.6309 | Accuracy: 0.2974
# Task 1 | Backbone 10 | Epoch 2/20 | Loss: 47.1642 | Accuracy: 0.4465
# Task 1 | Backbone 10 | Epoch 3/20 | Loss: 45.7693 | Accuracy: 0.4617
# Task 1 | Backbone 10 | Epoch 4/20 | Loss: 44.6894 | Accuracy: 0.4796
# Task 1 | Backbone 10 | Epoch 5/20 | Loss: 43.5538 | Accuracy: 0.4990
# Task 1 | Backbone 10 | Epoch 6/20 | Loss: 42.5613 | Accuracy: 0.5107
# Task 1 | Backbone 10 | Epoch 7/20 | Loss: 41.5951 | Accuracy: 0.5231
# Task 1 | Backbone 10 | Epoch 8/20 | Loss: 40.6284 | Accuracy: 0.5376
# Task 1 | Backbone 10 | Epoch 9/20 | Loss: 39.5702 | Accuracy: 0.5611
# Task 1 | Backbone 10 | Epoch 10/20 | Loss: 38.4740 | Accuracy: 0.5673
# Task 1 | Backbone 10 | Epoch 11/20 | Loss: 37.4164 | Accuracy: 0.5887
# Task 1 | Backbone 10 | Epoch 12/20 | Loss: 36.4024 | Accuracy: 0.6025
# Task 1 | Backbone 10 | Epoch 13/20 | Loss: 35.4460 | Accuracy: 0.6177
# Task 1 | Backbone 10 | Epoch 14/20 | Loss: 34.5173 | Accuracy: 0.6384
# Task 1 | Backbone 10 | Epoch 15/20 | Loss: 33.7398 | Accuracy: 0.6404
# Task 1 | Backbone 10 | Epoch 16/20 | Loss: 32.9896 | Accuracy: 0.6494
# Task 1 | Backbone 10 | Epoch 17/20 | Loss: 32.3120 | Accuracy: 0.6598
# Task 1 | Backbone 10 | Epoch 18/20 | Loss: 31.6775 | Accuracy: 0.6715
# Task 1 | Backbone 10 | Epoch 19/20 | Loss: 31.1222 | Accuracy: 0.6812
# Task 1 | Backbone 10 | Epoch 20/20 | Loss: 30.5795 | Accuracy: 0.6860
# Successfully applied backbone weights for Image task.
# Task 2 | Backbone 8 | Epoch 1/20 | Loss: 8.0007 | Accuracy: 0.9571
# Task 2 | Backbone 8 | Epoch 2/20 | Loss: 7.6516 | Accuracy: 0.9613
# Task 2 | Backbone 8 | Epoch 3/20 | Loss: 7.7340 | Accuracy: 0.9571
# Task 2 | Backbone 8 | Epoch 4/20 | Loss: 7.6225 | Accuracy: 0.9550
# Task 2 | Backbone 8 | Epoch 5/20 | Loss: 7.3378 | Accuracy: 0.9564
# Task 2 | Backbone 8 | Epoch 6/20 | Loss: 6.8363 | Accuracy: 0.9633
# Task 2 | Backbone 8 | Epoch 7/20 | Loss: 7.7140 | Accuracy: 0.9516
# Task 2 | Backbone 8 | Epoch 8/20 | Loss: 7.1534 | Accuracy: 0.9578
# Task 2 | Backbone 8 | Epoch 9/20 | Loss: 6.5138 | Accuracy: 0.9620
# Task 2 | Backbone 8 | Epoch 10/20 | Loss: 6.5444 | Accuracy: 0.9627
# Task 2 | Backbone 8 | Epoch 11/20 | Loss: 6.4947 | Accuracy: 0.9599
# Task 2 | Backbone 8 | Epoch 12/20 | Loss: 5.7752 | Accuracy: 0.9661
# Task 2 | Backbone 8 | Epoch 13/20 | Loss: 5.3316 | Accuracy: 0.9710
# Task 2 | Backbone 8 | Epoch 14/20 | Loss: 5.0929 | Accuracy: 0.9751
# Task 2 | Backbone 8 | Epoch 15/20 | Loss: 4.7753 | Accuracy: 0.9779
# Task 2 | Backbone 8 | Epoch 16/20 | Loss: 4.5231 | Accuracy: 0.9793
# Task 2 | Backbone 8 | Epoch 17/20 | Loss: 4.4066 | Accuracy: 0.9793
# Task 2 | Backbone 8 | Epoch 18/20 | Loss: 4.3235 | Accuracy: 0.9799
# Task 2 | Backbone 8 | Epoch 19/20 | Loss: 4.2547 | Accuracy: 0.9806
# Task 2 | Backbone 8 | Epoch 20/20 | Loss: 4.1688 | Accuracy: 0.9806
# Successfully applied backbone weights for Image task.
# Task 3 | Backbone 10 | Epoch 1/20 | Loss: 74.1956 | Accuracy: 0.3572
# Task 3 | Backbone 10 | Epoch 2/20 | Loss: 48.9539 | Accuracy: 0.3886
# Task 3 | Backbone 10 | Epoch 3/20 | Loss: 47.9480 | Accuracy: 0.4373
# Task 3 | Backbone 10 | Epoch 4/20 | Loss: 47.0460 | Accuracy: 0.4673
# Task 3 | Backbone 10 | Epoch 5/20 | Loss: 46.0121 | Accuracy: 0.4972
# Task 3 | Backbone 10 | Epoch 6/20 | Loss: 44.8707 | Accuracy: 0.5174
# Task 3 | Backbone 10 | Epoch 7/20 | Loss: 43.6964 | Accuracy: 0.5355
# Task 3 | Backbone 10 | Epoch 8/20 | Loss: 42.6249 | Accuracy: 0.5585
# Task 3 | Backbone 10 | Epoch 9/20 | Loss: 41.7046 | Accuracy: 0.5766
# Task 3 | Backbone 10 | Epoch 10/20 | Loss: 40.8199 | Accuracy: 0.5933
# Task 3 | Backbone 10 | Epoch 11/20 | Loss: 40.0450 | Accuracy: 0.6065
# Task 3 | Backbone 10 | Epoch 12/20 | Loss: 39.2858 | Accuracy: 0.6128
# Task 3 | Backbone 10 | Epoch 13/20 | Loss: 38.5680 | Accuracy: 0.6184
# Task 3 | Backbone 10 | Epoch 14/20 | Loss: 37.7785 | Accuracy: 0.6288
# Task 3 | Backbone 10 | Epoch 15/20 | Loss: 37.0583 | Accuracy: 0.6400
# Task 3 | Backbone 10 | Epoch 16/20 | Loss: 36.3844 | Accuracy: 0.6490
# Task 3 | Backbone 10 | Epoch 17/20 | Loss: 35.6831 | Accuracy: 0.6616
# Task 3 | Backbone 10 | Epoch 18/20 | Loss: 34.9811 | Accuracy: 0.6797
# Task 3 | Backbone 10 | Epoch 19/20 | Loss: 34.3183 | Accuracy: 0.6915
# Task 3 | Backbone 10 | Epoch 20/20 | Loss: 33.6160 | Accuracy: 0.7047
# Successfully applied backbone weights for Image task.
# Task 4 | Backbone 10 | Epoch 1/20 | Loss: 6.4455 | Accuracy: 0.9720
# Task 4 | Backbone 10 | Epoch 2/20 | Loss: 6.3496 | Accuracy: 0.9727
# Task 4 | Backbone 10 | Epoch 3/20 | Loss: 6.2667 | Accuracy: 0.9727
# Task 4 | Backbone 10 | Epoch 4/20 | Loss: 6.1870 | Accuracy: 0.9734
# Task 4 | Backbone 10 | Epoch 5/20 | Loss: 6.0746 | Accuracy: 0.9734
# Task 4 | Backbone 10 | Epoch 6/20 | Loss: 5.9445 | Accuracy: 0.9741
# Task 4 | Backbone 10 | Epoch 7/20 | Loss: 5.7118 | Accuracy: 0.9755
# Task 4 | Backbone 10 | Epoch 8/20 | Loss: 5.6210 | Accuracy: 0.9755
# Task 4 | Backbone 10 | Epoch 9/20 | Loss: 5.4646 | Accuracy: 0.9769
# Task 4 | Backbone 10 | Epoch 10/20 | Loss: 5.3501 | Accuracy: 0.9769
# Task 4 | Backbone 10 | Epoch 11/20 | Loss: 5.2174 | Accuracy: 0.9776
# Task 4 | Backbone 10 | Epoch 12/20 | Loss: 5.0854 | Accuracy: 0.9790
# Task 4 | Backbone 10 | Epoch 13/20 | Loss: 5.0109 | Accuracy: 0.9790
# Task 4 | Backbone 10 | Epoch 14/20 | Loss: 4.9674 | Accuracy: 0.9790
# Task 4 | Backbone 10 | Epoch 15/20 | Loss: 4.8773 | Accuracy: 0.9804
# Task 4 | Backbone 10 | Epoch 16/20 | Loss: 4.7348 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 17/20 | Loss: 4.7001 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 18/20 | Loss: 4.6570 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 19/20 | Loss: 4.5315 | Accuracy: 0.9818
# Task 4 | Backbone 10 | Epoch 20/20 | Loss: 4.4938 | Accuracy: 0.9818
# Successfully applied backbone weights for Text task.
# Task 5 | Backbone 4 | Epoch 1/20 | Loss: 75.5242 | Accuracy: 0.3418
# Task 5 | Backbone 4 | Epoch 2/20 | Loss: 47.9007 | Accuracy: 0.3491
# Task 5 | Backbone 4 | Epoch 3/20 | Loss: 46.6497 | Accuracy: 0.3731
# Task 5 | Backbone 4 | Epoch 4/20 | Loss: 45.8468 | Accuracy: 0.4262
# Task 5 | Backbone 4 | Epoch 5/20 | Loss: 44.7880 | Accuracy: 0.4538
# Task 5 | Backbone 4 | Epoch 6/20 | Loss: 43.6593 | Accuracy: 0.4880
# Task 5 | Backbone 4 | Epoch 7/20 | Loss: 42.7622 | Accuracy: 0.4989
# Task 5 | Backbone 4 | Epoch 8/20 | Loss: 42.0601 | Accuracy: 0.5120
# Task 5 | Backbone 4 | Epoch 9/20 | Loss: 41.4684 | Accuracy: 0.5200
# Task 5 | Backbone 4 | Epoch 10/20 | Loss: 40.8885 | Accuracy: 0.5324
# Task 5 | Backbone 4 | Epoch 11/20 | Loss: 40.2650 | Accuracy: 0.5433
# Task 5 | Backbone 4 | Epoch 12/20 | Loss: 39.5800 | Accuracy: 0.5476
# Task 5 | Backbone 4 | Epoch 13/20 | Loss: 38.8877 | Accuracy: 0.5549
# Task 5 | Backbone 4 | Epoch 14/20 | Loss: 38.1389 | Accuracy: 0.5651
# Task 5 | Backbone 4 | Epoch 15/20 | Loss: 37.3908 | Accuracy: 0.5775
# Task 5 | Backbone 4 | Epoch 16/20 | Loss: 36.6139 | Accuracy: 0.5847
# Task 5 | Backbone 4 | Epoch 17/20 | Loss: 35.8563 | Accuracy: 0.5956
# Task 5 | Backbone 4 | Epoch 18/20 | Loss: 34.9628 | Accuracy: 0.6109
# Task 5 | Backbone 4 | Epoch 19/20 | Loss: 33.9194 | Accuracy: 0.6211
# Task 5 | Backbone 4 | Epoch 20/20 | Loss: 32.7644 | Accuracy: 0.6342
# Successfully applied backbone weights for Image task.
# Task 6 | Backbone 10 | Epoch 1/20 | Loss: 29.5210 | Accuracy: 0.7298
# Task 6 | Backbone 10 | Epoch 2/20 | Loss: 27.6508 | Accuracy: 0.7524
# Task 6 | Backbone 10 | Epoch 3/20 | Loss: 26.4652 | Accuracy: 0.7695
# Task 6 | Backbone 10 | Epoch 4/20 | Loss: 26.8441 | Accuracy: 0.7551
# Task 6 | Backbone 10 | Epoch 5/20 | Loss: 25.4740 | Accuracy: 0.7785
# Task 6 | Backbone 10 | Epoch 6/20 | Loss: 24.2249 | Accuracy: 0.7990
# Task 6 | Backbone 10 | Epoch 7/20 | Loss: 25.2376 | Accuracy: 0.7778
# Task 6 | Backbone 10 | Epoch 8/20 | Loss: 23.6377 | Accuracy: 0.8073
# Task 6 | Backbone 10 | Epoch 9/20 | Loss: 23.6596 | Accuracy: 0.8018
# Task 6 | Backbone 10 | Epoch 10/20 | Loss: 23.6427 | Accuracy: 0.8080
# Task 6 | Backbone 10 | Epoch 11/20 | Loss: 24.5537 | Accuracy: 0.7963
# Task 6 | Backbone 10 | Epoch 12/20 | Loss: 22.8984 | Accuracy: 0.8107
# Task 6 | Backbone 10 | Epoch 13/20 | Loss: 23.3736 | Accuracy: 0.7997
# Task 6 | Backbone 10 | Epoch 14/20 | Loss: 22.8100 | Accuracy: 0.8114
# Task 6 | Backbone 10 | Epoch 15/20 | Loss: 21.4547 | Accuracy: 0.8278
# Task 6 | Backbone 10 | Epoch 16/20 | Loss: 21.9651 | Accuracy: 0.8196
# Task 6 | Backbone 10 | Epoch 17/20 | Loss: 22.2750 | Accuracy: 0.8121
# Task 6 | Backbone 10 | Epoch 18/20 | Loss: 22.7890 | Accuracy: 0.8128
# Task 6 | Backbone 10 | Epoch 19/20 | Loss: 23.3177 | Accuracy: 0.8162
# Task 6 | Backbone 10 | Epoch 20/20 | Loss: 24.1491 | Accuracy: 0.7929
# Successfully applied backbone weights for Image task.
# Task 7 | Backbone 11 | Epoch 1/20 | Loss: 28.9938 | Accuracy: 0.6970
# Task 7 | Backbone 11 | Epoch 2/20 | Loss: 28.0637 | Accuracy: 0.7170
# Task 7 | Backbone 11 | Epoch 3/20 | Loss: 27.1643 | Accuracy: 0.7288
# Task 7 | Backbone 11 | Epoch 4/20 | Loss: 29.7295 | Accuracy: 0.7012
# Task 7 | Backbone 11 | Epoch 5/20 | Loss: 31.2566 | Accuracy: 0.6929
# Task 7 | Backbone 11 | Epoch 6/20 | Loss: 30.7902 | Accuracy: 0.6798
# Task 7 | Backbone 11 | Epoch 7/20 | Loss: 27.9791 | Accuracy: 0.7177
# Task 7 | Backbone 11 | Epoch 8/20 | Loss: 26.3060 | Accuracy: 0.7433
# Task 7 | Backbone 11 | Epoch 9/20 | Loss: 26.4823 | Accuracy: 0.7364
# Task 7 | Backbone 11 | Epoch 10/20 | Loss: 25.9955 | Accuracy: 0.7495
# Task 7 | Backbone 11 | Epoch 11/20 | Loss: 27.3970 | Accuracy: 0.7226
# Task 7 | Backbone 11 | Epoch 12/20 | Loss: 26.8422 | Accuracy: 0.7329
# Task 7 | Backbone 11 | Epoch 13/20 | Loss: 27.1623 | Accuracy: 0.7253
# Task 7 | Backbone 11 | Epoch 14/20 | Loss: 27.6935 | Accuracy: 0.7219
# Task 7 | Backbone 11 | Epoch 15/20 | Loss: 27.1382 | Accuracy: 0.7253
# Task 7 | Backbone 11 | Epoch 16/20 | Loss: 28.5251 | Accuracy: 0.7005
# Task 7 | Backbone 11 | Epoch 17/20 | Loss: 25.9920 | Accuracy: 0.7419
# Task 7 | Backbone 11 | Epoch 18/20 | Loss: 25.2547 | Accuracy: 0.7543
# Task 7 | Backbone 11 | Epoch 19/20 | Loss: 26.2017 | Accuracy: 0.7391
# Task 7 | Backbone 11 | Epoch 20/20 | Loss: 23.9763 | Accuracy: 0.7702
# Successfully applied backbone weights for Image task.
# Task 8 | Backbone 6 | Epoch 1/20 | Loss: 36.5747 | Accuracy: 0.6556
# Task 8 | Backbone 6 | Epoch 2/20 | Loss: 36.9830 | Accuracy: 0.6542
# Task 8 | Backbone 6 | Epoch 3/20 | Loss: 36.2488 | Accuracy: 0.6653
# Task 8 | Backbone 6 | Epoch 4/20 | Loss: 40.9301 | Accuracy: 0.6252
# Task 8 | Backbone 6 | Epoch 5/20 | Loss: 36.6112 | Accuracy: 0.6577
# Task 8 | Backbone 6 | Epoch 6/20 | Loss: 37.1352 | Accuracy: 0.6591
# Task 8 | Backbone 6 | Epoch 7/20 | Loss: 35.5935 | Accuracy: 0.6722
# Task 8 | Backbone 6 | Epoch 8/20 | Loss: 35.7716 | Accuracy: 0.6715
# Task 8 | Backbone 6 | Epoch 9/20 | Loss: 35.6089 | Accuracy: 0.6743
# Task 8 | Backbone 6 | Epoch 10/20 | Loss: 34.6915 | Accuracy: 0.6826
# Task 8 | Backbone 6 | Epoch 11/20 | Loss: 39.6255 | Accuracy: 0.6217
# Task 8 | Backbone 6 | Epoch 12/20 | Loss: 37.0467 | Accuracy: 0.6653
# Task 8 | Backbone 6 | Epoch 13/20 | Loss: 37.0879 | Accuracy: 0.6680
# Task 8 | Backbone 6 | Epoch 14/20 | Loss: 34.2193 | Accuracy: 0.6909
# Task 8 | Backbone 6 | Epoch 15/20 | Loss: 33.8663 | Accuracy: 0.7054
# Task 8 | Backbone 6 | Epoch 16/20 | Loss: 35.1491 | Accuracy: 0.6770
# Task 8 | Backbone 6 | Epoch 17/20 | Loss: 32.9418 | Accuracy: 0.7095
# Task 8 | Backbone 6 | Epoch 18/20 | Loss: 33.7529 | Accuracy: 0.6971
# Task 8 | Backbone 6 | Epoch 19/20 | Loss: 32.7249 | Accuracy: 0.7089
# Task 8 | Backbone 6 | Epoch 20/20 | Loss: 33.4745 | Accuracy: 0.6964
# Successfully applied backbone weights for Image task.
# Task 9 | Backbone 10 | Epoch 1/20 | Loss: 28.5355 | Accuracy: 0.7549
# Task 9 | Backbone 10 | Epoch 2/20 | Loss: 27.7701 | Accuracy: 0.7625
# Task 9 | Backbone 10 | Epoch 3/20 | Loss: 26.9309 | Accuracy: 0.7779
# Task 9 | Backbone 10 | Epoch 4/20 | Loss: 27.6679 | Accuracy: 0.7639
# Task 9 | Backbone 10 | Epoch 5/20 | Loss: 28.1913 | Accuracy: 0.7604
# Task 9 | Backbone 10 | Epoch 6/20 | Loss: 26.0098 | Accuracy: 0.7876
# Task 9 | Backbone 10 | Epoch 7/20 | Loss: 25.5524 | Accuracy: 0.7876
# Task 9 | Backbone 10 | Epoch 8/20 | Loss: 24.8639 | Accuracy: 0.7987
# Task 9 | Backbone 10 | Epoch 9/20 | Loss: 23.0806 | Accuracy: 0.8182
# Task 9 | Backbone 10 | Epoch 10/20 | Loss: 24.8026 | Accuracy: 0.7960
# Task 9 | Backbone 10 | Epoch 11/20 | Loss: 23.2119 | Accuracy: 0.8078
# Task 9 | Backbone 10 | Epoch 12/20 | Loss: 23.5990 | Accuracy: 0.8085
# Task 9 | Backbone 10 | Epoch 13/20 | Loss: 23.1994 | Accuracy: 0.8162
# Task 9 | Backbone 10 | Epoch 14/20 | Loss: 24.6150 | Accuracy: 0.7974
# Task 9 | Backbone 10 | Epoch 15/20 | Loss: 24.1097 | Accuracy: 0.8106
# Task 9 | Backbone 10 | Epoch 16/20 | Loss: 21.5387 | Accuracy: 0.8245
# Task 9 | Backbone 10 | Epoch 17/20 | Loss: 20.3754 | Accuracy: 0.8433
# Task 9 | Backbone 10 | Epoch 18/20 | Loss: 19.5439 | Accuracy: 0.8489
# Task 9 | Backbone 10 | Epoch 19/20 | Loss: 22.6296 | Accuracy: 0.8064
# Task 9 | Backbone 10 | Epoch 20/20 | Loss: 23.3974 | Accuracy: 0.8029
# Successfully applied backbone weights for Image task.
# Task 10 | Backbone 6 | Epoch 1/20 | Loss: 36.0770 | Accuracy: 0.6340
# Task 10 | Backbone 6 | Epoch 2/20 | Loss: 34.0840 | Accuracy: 0.6543
# Task 10 | Backbone 6 | Epoch 3/20 | Loss: 35.0924 | Accuracy: 0.6396
# Task 10 | Backbone 6 | Epoch 4/20 | Loss: 37.1794 | Accuracy: 0.6074
# Task 10 | Backbone 6 | Epoch 5/20 | Loss: 35.4283 | Accuracy: 0.6270
# Task 10 | Backbone 6 | Epoch 6/20 | Loss: 34.1827 | Accuracy: 0.6319
# Task 10 | Backbone 6 | Epoch 7/20 | Loss: 33.7865 | Accuracy: 0.6417
# Task 10 | Backbone 6 | Epoch 8/20 | Loss: 33.7459 | Accuracy: 0.6410
# Task 10 | Backbone 6 | Epoch 9/20 | Loss: 34.3979 | Accuracy: 0.6389
# Task 10 | Backbone 6 | Epoch 10/20 | Loss: 33.9933 | Accuracy: 0.6466
# Task 10 | Backbone 6 | Epoch 11/20 | Loss: 33.4785 | Accuracy: 0.6585
# Task 10 | Backbone 6 | Epoch 12/20 | Loss: 32.9106 | Accuracy: 0.6690
# Task 10 | Backbone 6 | Epoch 13/20 | Loss: 33.2896 | Accuracy: 0.6732
# Task 10 | Backbone 6 | Epoch 14/20 | Loss: 32.8276 | Accuracy: 0.6690
# Task 10 | Backbone 6 | Epoch 15/20 | Loss: 32.7243 | Accuracy: 0.6718
# Task 10 | Backbone 6 | Epoch 16/20 | Loss: 32.9990 | Accuracy: 0.6697
# Task 10 | Backbone 6 | Epoch 17/20 | Loss: 32.4339 | Accuracy: 0.6837
# Task 10 | Backbone 6 | Epoch 18/20 | Loss: 33.5450 | Accuracy: 0.6634
# Task 10 | Backbone 6 | Epoch 19/20 | Loss: 32.2231 | Accuracy: 0.6704
# Task 10 | Backbone 6 | Epoch 20/20 | Loss: 30.3034 | Accuracy: 0.6991
# Successfully applied backbone weights for Image task.
# Task 11 | Backbone 10 | Epoch 1/20 | Loss: 37.0705 | Accuracy: 0.6073
# Task 11 | Backbone 10 | Epoch 2/20 | Loss: 36.1100 | Accuracy: 0.6145
# Task 11 | Backbone 10 | Epoch 3/20 | Loss: 35.8247 | Accuracy: 0.6298
# Task 11 | Backbone 10 | Epoch 4/20 | Loss: 35.0520 | Accuracy: 0.6429
# Task 11 | Backbone 10 | Epoch 5/20 | Loss: 34.3732 | Accuracy: 0.6487
# Task 11 | Backbone 10 | Epoch 6/20 | Loss: 35.0364 | Accuracy: 0.6291
# Task 11 | Backbone 10 | Epoch 7/20 | Loss: 33.6669 | Accuracy: 0.6575
# Task 11 | Backbone 10 | Epoch 8/20 | Loss: 33.4489 | Accuracy: 0.6589
# Task 11 | Backbone 10 | Epoch 9/20 | Loss: 32.9041 | Accuracy: 0.6647
# Task 11 | Backbone 10 | Epoch 10/20 | Loss: 33.0559 | Accuracy: 0.6669
# Task 11 | Backbone 10 | Epoch 11/20 | Loss: 32.4639 | Accuracy: 0.6800
# Task 11 | Backbone 10 | Epoch 12/20 | Loss: 31.8142 | Accuracy: 0.6844
# Task 11 | Backbone 10 | Epoch 13/20 | Loss: 34.0254 | Accuracy: 0.6524
# Task 11 | Backbone 10 | Epoch 14/20 | Loss: 34.4966 | Accuracy: 0.6407
# Task 11 | Backbone 10 | Epoch 15/20 | Loss: 31.4570 | Accuracy: 0.6887
# Task 11 | Backbone 10 | Epoch 16/20 | Loss: 31.7915 | Accuracy: 0.6756
# Task 11 | Backbone 10 | Epoch 17/20 | Loss: 30.6379 | Accuracy: 0.6909
# Task 11 | Backbone 10 | Epoch 18/20 | Loss: 30.6986 | Accuracy: 0.6975
# Task 11 | Backbone 10 | Epoch 19/20 | Loss: 30.2700 | Accuracy: 0.7076
# Task 11 | Backbone 10 | Epoch 20/20 | Loss: 29.4934 | Accuracy: 0.7164
# Evaluating final results...
# Task 0 (Text) | Test Loss: 0.5378, Test Accuracy: 0.7874
# Task 1 (Text) | Test Loss: 0.6519, Test Accuracy: 0.6950
# Task 2 (Text) | Test Loss: 0.0865, Test Accuracy: 0.9820
# Task 3 (Text) | Test Loss: 0.7295, Test Accuracy: 0.7138
# Task 4 (Text) | Test Loss: 0.0981, Test Accuracy: 0.9818
# Task 5 (Text) | Test Loss: 0.7355, Test Accuracy: 0.6662
# Task 6 (Image) | Test Loss: 0.5237, Test Accuracy: 0.7867
# Task 7 (Image) | Test Loss: 0.5604, Test Accuracy: 0.7336
# Task 8 (Image) | Test Loss: 0.7113, Test Accuracy: 0.7192
# Task 9 (Image) | Test Loss: 0.5946, Test Accuracy: 0.7660
# Task 10 (Image) | Test Loss: 0.6336, Test Accuracy: 0.7334
# Task 11 (Image) | Test Loss: 0.6374, Test Accuracy: 0.7433

# %%
import pickle

file_path = "/home/youlee/perceiver/perceiver/checkpoints_pruned/text_model_1_pruned.pkl"

try:
    with open(file_path, 'rb') as f:
        model_data = pickle.load(f)
    print("Successfully loaded the file. Keys in the file:")
    print(model_data.keys())
except Exception as e:
    print(f"Error while opening the file: {e}")


# model_state_dict 내부 키 확인
state_dict = model_data["model_state_dict"]
print("Keys in model_state_dict:")
print(list(state_dict.keys())[:10])  # 첫 10개의 키

# masks 내부 키 확인
masks = model_data["masks"]
print("Keys in masks:")
print(list(masks.keys())[:10])  # 첫 10개의 키
# Out:
# Successfully loaded the file. Keys in the file:
# dict_keys(['model_state_dict', 'masks'])
# Keys in model_state_dict:
# ['model.embedding.weight', 'model.perceiver.latents', 'model.perceiver.input_projection.weight', 'model.perceiver.input_projection.bias', 'model.perceiver.blocks.0.cross_attn.in_proj_weight', 'model.perceiver.blocks.0.cross_attn.in_proj_bias', 'model.perceiver.blocks.0.cross_attn.out_proj.weight', 'model.perceiver.blocks.0.cross_attn.out_proj.bias', 'model.perceiver.blocks.0.cross_ln.weight', 'model.perceiver.blocks.0.cross_ln.bias']
# Keys in masks:
# ['text_task_1']

# %%
import pickle

file_path = "/home/youlee/perceiver/perceiver/checkpoints_pruned/image_model_1_pruned.pkl"

try:
    with open(file_path, 'rb') as f:
        model_data = pickle.load(f)
    print("Successfully loaded the file. Keys in the file:")
    print(model_data.keys())
except Exception as e:
    print(f"Error while opening the file: {e}")


# model_state_dict 내부 키 확인
state_dict = model_data["model_state_dict"]
print("Keys in model_state_dict:")
print(list(state_dict.keys())[:10])  # 첫 10개의 키

# masks 내부 키 확인
masks = model_data["masks"]
print("Keys in masks:")
print(list(masks.keys())[:10])  # 첫 10개의 키
# Out:
# Successfully loaded the file. Keys in the file:
# dict_keys(['model_state_dict', 'masks'])
# Keys in model_state_dict:
# ['model.latents', 'model.input_projection.weight', 'model.input_projection.bias', 'model.blocks.0.cross_attn.in_proj_weight', 'model.blocks.0.cross_attn.in_proj_bias', 'model.blocks.0.cross_attn.out_proj.weight', 'model.blocks.0.cross_attn.out_proj.bias', 'model.blocks.0.cross_ln.weight', 'model.blocks.0.cross_ln.bias', 'model.blocks.0.self_attn_layers.0.self_attn.in_proj_weight']
# Keys in masks:
# ['image_task_1']
