# %%
import pandas as pd
import torch
import pickle
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from perceiver import tokenize_data, CustomDataset, PerceiverBlock, Perceiver, CombinedModel

# Device 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.CrossEntropyLoss()

# 경로 설정
pruned_model_dir = "/home/youlee/perceiver/perceiver/checkpoints_pruned/"
loader_dir = "/home/youlee/perceiver/perceiver/loader/"
batch_size = 32

# %%
# Pruned 모델 로드 함수
def load_pruned_models(pruned_model_dir, model_dir):
    pruned_text_models, pruned_image_models = [], []
    
    # Text 모델 로드
    for i in range(6):
        file_path = f"{pruned_model_dir}/text_model_{i+1}_pruned.pkl"
        model_path = f"{model_dir}/text_model_{i+1}.pkl"
        
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)
        
        model = torch.load(model_path)
        state_dict = {k.replace("model.", ""): v for k, v in model_data["model_state_dict"].items()}
        model.load_state_dict(state_dict, strict=False)
        pruned_text_models.append(model)

    # Image 모델 로드
    for i in range(6):
        file_path = f"{pruned_model_dir}/image_model_{i+1}_pruned.pkl"
        model_path = f"{model_dir}/image_model_{i+1}.pkl"
        
        with open(file_path, 'rb') as f:
            model_data = pickle.load(f)
        
        model = torch.load(model_path)
        state_dict = {k.replace("model.", ""): v for k, v in model_data["model_state_dict"].items()}
        model.load_state_dict(state_dict, strict=False)
        pruned_image_models.append(model)

    return pruned_text_models, pruned_image_models

# %%
# Validation 데이터 로드 함수
def load_valid_loaders():
    valid_loaders = []
    for i in range(6):
        with open(f"{loader_dir}text_val_loader_{i+1}.pkl", 'rb') as f:
            valid_loaders.append(pickle.load(f))
    for i in range(6):
        with open(f"{loader_dir}image_val_loader_{i+1}.pkl", 'rb') as f:
            valid_dataset = pickle.load(f)
            valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
            valid_loaders.append(valid_loader)
    return valid_loaders

# %%
# 키 매핑 함수
def map_keys(state_dict, modality):
    key_map = {}
    for key in state_dict.keys():
        if modality == "Text" and "model.perceiver" in key:
            key_map[key] = key.replace("model.perceiver", "model")
        elif modality == "Image" and "model." in key:
            key_map[key] = key.replace("model.", "model.perceiver")
        else:
            key_map[key] = key
    return key_map

# 가중치 매핑 및 로드 함수
def apply_mapped_state_dict(task_model, backbone_model, modality):
    backbone_state_dict = backbone_model.state_dict()
    key_map = map_keys(backbone_state_dict, modality)
    mapped_state_dict = {key_map[k]: v for k, v in backbone_state_dict.items()}
    task_model.load_state_dict(mapped_state_dict, strict=False)
    print(f"Successfully applied backbone weights for {modality} task.")

# %%
def knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                       task_models, backbone_models, valid_loaders, criterion, device, epochs=20):
    if backbone_modality == "Text":
        backbone_model = backbone_models[backbone_id]
    else:
        backbone_model = backbone_models[backbone_id - 6]

    task_model = task_models[task_id]
    task_model.to(device)

    apply_mapped_state_dict(task_model, backbone_model, backbone_modality)

    optimizer = optim.SGD(task_model.parameters(), lr=0.001, momentum=0.9)
    task_model.train()
    
    for epoch in range(epochs):
        total_loss = 0
        correct = 0
        total = 0

        for batch in valid_loaders[task_id]:
            optimizer.zero_grad()
            if task_modality == "Text":
                inputs = batch["input_ids"].to(device)
                labels = batch["labels"].to(device)
                outputs = task_model(inputs)
            else:
                inputs, labels = batch
                inputs = inputs.to(device)
                labels = labels.to(device)
                outputs = task_model(inputs)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        print(f"Task {task_id} | Backbone {backbone_id} | Epoch {epoch+1}/{epochs} | Loss: {total_loss:.4f} | Accuracy: {correct/total:.4f}")
    return task_model

# %%
def eval_epoch(model, dataloader, criterion, device, is_text: bool):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch in dataloader:
            if is_text:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)
                outputs = model(input_ids)
            else:
                inputs, labels = batch
                inputs = inputs.to(device)
                labels = labels.to(device)
                outputs = model(inputs)

            loss = criterion(outputs, labels)
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    return avg_loss, accuracy

# %%
# 최종 평가 함수
def evaluate_transfer(models, valid_loaders, criterion, device):
    for i, model in enumerate(models):
        is_text = i < 6
        test_loss, test_acc = eval_epoch(model, valid_loaders[i], criterion, device, is_text)
        modality = "Text" if is_text else "Image"
        print(f"Task {i} ({modality}) | Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

# %%
# Cosine 및 Euclidean 결과 로드
cosine_results = pd.read_csv("/home/youlee/perceiver/perceiver/code/best_cosine_results.txt", sep='\t')
euclidean_results = pd.read_csv("/home/youlee/perceiver/perceiver/code/best_euclidean_results.txt", sep='\t')
cosine_task_to_backbone = {row["Task_ID"]: row["Best_Target_ID"] for _, row in cosine_results.iterrows()}
euclidean_task_to_backbone = {row["Task_ID"]: row["Best_Target_ID"] for _, row in euclidean_results.iterrows()}

# %%
if __name__ == "__main__":
    print("Loading pruned models and validation loaders...")
    
    pruned_text_models, pruned_image_models = load_pruned_models(pruned_model_dir, "/home/youlee/perceiver/perceiver/model")
    valid_loaders = load_valid_loaders()
    pruned_models = pruned_text_models + pruned_image_models

    print("Starting Cosine-based Knowledge Transfer...")
    for task_id, backbone_id in cosine_task_to_backbone.items():
        backbone_modality = cosine_results.loc[cosine_results["Task_ID"] == task_id, "Target_Modality"].values[0]
        task_modality = cosine_results.loc[cosine_results["Task_ID"] == task_id, "Task_Modality"].values[0]
        knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                           pruned_models, pruned_models, valid_loaders, criterion, device)

    print("Starting Euclidean-based Knowledge Transfer...")
    for task_id, backbone_id in euclidean_task_to_backbone.items():
        backbone_modality = euclidean_results.loc[euclidean_results["Task_ID"] == task_id, "Target_Modality"].values[0]
        task_modality = euclidean_results.loc[euclidean_results["Task_ID"] == task_id, "Task_Modality"].values[0]
        knowledge_transfer(task_id, backbone_id, backbone_modality, task_modality, 
                           pruned_models, pruned_models, valid_loaders, criterion, device)

    print("Evaluating final results...")
    evaluate_transfer(pruned_models, valid_loaders, criterion, device)
# Out:
# Loading pruned models and validation loaders...
# /tmp/ipykernel_1403272/631762024.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)
# /tmp/ipykernel_1403272/631762024.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)
# Starting Cosine-based Knowledge Transfer...
# Successfully applied backbone weights for Image task.
# Task 0 | Backbone 9 | Epoch 1/20 | Loss: 103.9075 | Accuracy: 0.4417
# Task 0 | Backbone 9 | Epoch 2/20 | Loss: 44.6477 | Accuracy: 0.5336
# Task 0 | Backbone 9 | Epoch 3/20 | Loss: 42.2105 | Accuracy: 0.5727
# Task 0 | Backbone 9 | Epoch 4/20 | Loss: 40.4263 | Accuracy: 0.5988
# Task 0 | Backbone 9 | Epoch 5/20 | Loss: 38.8032 | Accuracy: 0.6159
# Task 0 | Backbone 9 | Epoch 6/20 | Loss: 37.1759 | Accuracy: 0.6440
# Task 0 | Backbone 9 | Epoch 7/20 | Loss: 35.4552 | Accuracy: 0.6708
# Task 0 | Backbone 9 | Epoch 8/20 | Loss: 33.6654 | Accuracy: 0.7003
# Task 0 | Backbone 9 | Epoch 9/20 | Loss: 32.0442 | Accuracy: 0.7188
# Task 0 | Backbone 9 | Epoch 10/20 | Loss: 30.7255 | Accuracy: 0.7366
# Task 0 | Backbone 9 | Epoch 11/20 | Loss: 29.6251 | Accuracy: 0.7483
# Task 0 | Backbone 9 | Epoch 12/20 | Loss: 28.4551 | Accuracy: 0.7558
# Task 0 | Backbone 9 | Epoch 13/20 | Loss: 27.3229 | Accuracy: 0.7709
# Task 0 | Backbone 9 | Epoch 14/20 | Loss: 26.0048 | Accuracy: 0.7874
# Task 0 | Backbone 9 | Epoch 15/20 | Loss: 24.1319 | Accuracy: 0.8100
# Task 0 | Backbone 9 | Epoch 16/20 | Loss: 22.2914 | Accuracy: 0.8299
# Task 0 | Backbone 9 | Epoch 17/20 | Loss: 20.9852 | Accuracy: 0.8402
# Task 0 | Backbone 9 | Epoch 18/20 | Loss: 19.8378 | Accuracy: 0.8560
# Task 0 | Backbone 9 | Epoch 19/20 | Loss: 18.7940 | Accuracy: 0.8690
# Task 0 | Backbone 9 | Epoch 20/20 | Loss: 17.7470 | Accuracy: 0.8772
# Successfully applied backbone weights for Image task.
# Task 1 | Backbone 10 | Epoch 1/20 | Loss: 108.9254 | Accuracy: 0.3244
# Task 1 | Backbone 10 | Epoch 2/20 | Loss: 49.1427 | Accuracy: 0.4300
# Task 1 | Backbone 10 | Epoch 3/20 | Loss: 47.5094 | Accuracy: 0.4658
# Task 1 | Backbone 10 | Epoch 4/20 | Loss: 46.2592 | Accuracy: 0.5003
# Task 1 | Backbone 10 | Epoch 5/20 | Loss: 44.9795 | Accuracy: 0.5148
# Task 1 | Backbone 10 | Epoch 6/20 | Loss: 43.8317 | Accuracy: 0.5280
# Task 1 | Backbone 10 | Epoch 7/20 | Loss: 42.7891 | Accuracy: 0.5452
# Task 1 | Backbone 10 | Epoch 8/20 | Loss: 41.6704 | Accuracy: 0.5500
# Task 1 | Backbone 10 | Epoch 9/20 | Loss: 40.5961 | Accuracy: 0.5707
# Task 1 | Backbone 10 | Epoch 10/20 | Loss: 39.5817 | Accuracy: 0.5852
# Task 1 | Backbone 10 | Epoch 11/20 | Loss: 38.5737 | Accuracy: 0.5990
# Task 1 | Backbone 10 | Epoch 12/20 | Loss: 37.4715 | Accuracy: 0.6128
# Task 1 | Backbone 10 | Epoch 13/20 | Loss: 36.3474 | Accuracy: 0.6225
# Task 1 | Backbone 10 | Epoch 14/20 | Loss: 35.2694 | Accuracy: 0.6432
# Task 1 | Backbone 10 | Epoch 15/20 | Loss: 34.1991 | Accuracy: 0.6536
# Task 1 | Backbone 10 | Epoch 16/20 | Loss: 33.2164 | Accuracy: 0.6687
# Task 6 | Backbone 10 | Epoch 12/20 | Loss: 29.4174 | Accuracy: 0.7209
# Task 6 | Backbone 10 | Epoch 13/20 | Loss: 29.8051 | Accuracy: 0.7119
# Task 6 | Backbone 10 | Epoch 14/20 | Loss: 28.7588 | Accuracy: 0.7250
# Task 6 | Backbone 10 | Epoch 15/20 | Loss: 28.4253 | Accuracy: 0.7305
# Task 6 | Backbone 10 | Epoch 16/20 | Loss: 27.7630 | Accuracy: 0.7387
# Task 6 | Backbone 10 | Epoch 17/20 | Loss: 27.3354 | Accuracy: 0.7442
# Task 6 | Backbone 10 | Epoch 18/20 | Loss: 27.4610 | Accuracy: 0.7428
# Task 6 | Backbone 10 | Epoch 19/20 | Loss: 27.1139 | Accuracy: 0.7503
# Task 6 | Backbone 10 | Epoch 20/20 | Loss: 27.0256 | Accuracy: 0.7545
# Successfully applied backbone weights for Text task.
# Task 7 | Backbone 0 | Epoch 1/20 | Loss: 36.2357 | Accuracy: 0.6108
# Task 7 | Backbone 0 | Epoch 2/20 | Loss: 35.8397 | Accuracy: 0.6204
# Task 7 | Backbone 0 | Epoch 3/20 | Loss: 35.1728 | Accuracy: 0.6108
# Task 7 | Backbone 0 | Epoch 4/20 | Loss: 34.8718 | Accuracy: 0.6259
# Task 7 | Backbone 0 | Epoch 5/20 | Loss: 34.5143 | Accuracy: 0.6239
# Task 7 | Backbone 0 | Epoch 6/20 | Loss: 34.2313 | Accuracy: 0.6259
# Task 7 | Backbone 0 | Epoch 7/20 | Loss: 33.5129 | Accuracy: 0.6460
# Task 7 | Backbone 0 | Epoch 8/20 | Loss: 32.9898 | Accuracy: 0.6515
# Task 7 | Backbone 0 | Epoch 9/20 | Loss: 32.5731 | Accuracy: 0.6598
# Task 7 | Backbone 0 | Epoch 10/20 | Loss: 32.3206 | Accuracy: 0.6653
# Task 7 | Backbone 0 | Epoch 11/20 | Loss: 32.0276 | Accuracy: 0.6646
# Task 7 | Backbone 0 | Epoch 12/20 | Loss: 31.8215 | Accuracy: 0.6680
# Task 7 | Backbone 0 | Epoch 13/20 | Loss: 31.5675 | Accuracy: 0.6646
# Task 7 | Backbone 0 | Epoch 14/20 | Loss: 31.2208 | Accuracy: 0.6777
# Task 7 | Backbone 0 | Epoch 15/20 | Loss: 31.2032 | Accuracy: 0.6715
# Task 7 | Backbone 0 | Epoch 16/20 | Loss: 30.8282 | Accuracy: 0.6756
# Task 7 | Backbone 0 | Epoch 17/20 | Loss: 30.8169 | Accuracy: 0.6770
# Task 7 | Backbone 0 | Epoch 18/20 | Loss: 30.3199 | Accuracy: 0.6957
# Task 7 | Backbone 0 | Epoch 19/20 | Loss: 29.7526 | Accuracy: 0.6901
# Task 7 | Backbone 0 | Epoch 20/20 | Loss: 30.2229 | Accuracy: 0.6798
# Successfully applied backbone weights for Image task.
# Task 8 | Backbone 6 | Epoch 1/20 | Loss: 43.4015 | Accuracy: 0.5394
# Task 8 | Backbone 6 | Epoch 2/20 | Loss: 42.3699 | Accuracy: 0.5636
# Task 9 | Backbone 0 | Epoch 15/20 | Loss: 28.5829 | Accuracy: 0.7451
# Task 9 | Backbone 0 | Epoch 16/20 | Loss: 27.7684 | Accuracy: 0.7486
# Task 9 | Backbone 0 | Epoch 17/20 | Loss: 27.7063 | Accuracy: 0.7500
# Task 9 | Backbone 0 | Epoch 18/20 | Loss: 28.0531 | Accuracy: 0.7556
# Task 9 | Backbone 0 | Epoch 19/20 | Loss: 26.4053 | Accuracy: 0.7653
# Task 9 | Backbone 0 | Epoch 20/20 | Loss: 25.9009 | Accuracy: 0.7639
# Successfully applied backbone weights for Image task.
# Task 10 | Backbone 6 | Epoch 1/20 | Loss: 44.8903 | Accuracy: 0.5101
# Task 10 | Backbone 6 | Epoch 2/20 | Loss: 39.4684 | Accuracy: 0.5822
# Task 10 | Backbone 6 | Epoch 3/20 | Loss: 37.0933 | Accuracy: 0.6109
# Task 10 | Backbone 6 | Epoch 4/20 | Loss: 36.7709 | Accuracy: 0.6158
# Task 10 | Backbone 6 | Epoch 5/20 | Loss: 36.1805 | Accuracy: 0.6235
# Task 10 | Backbone 6 | Epoch 6/20 | Loss: 35.6896 | Accuracy: 0.6242
# Task 10 | Backbone 6 | Epoch 7/20 | Loss: 35.3025 | Accuracy: 0.6298
# Task 10 | Backbone 6 | Epoch 8/20 | Loss: 35.1551 | Accuracy: 0.6291
# Task 10 | Backbone 6 | Epoch 9/20 | Loss: 34.8243 | Accuracy: 0.6445
# Task 10 | Backbone 6 | Epoch 10/20 | Loss: 34.2980 | Accuracy: 0.6480
# Task 10 | Backbone 6 | Epoch 11/20 | Loss: 34.3166 | Accuracy: 0.6368
# Task 10 | Backbone 6 | Epoch 12/20 | Loss: 35.0570 | Accuracy: 0.6382
# Task 10 | Backbone 6 | Epoch 13/20 | Loss: 34.0183 | Accuracy: 0.6522
# Task 10 | Backbone 6 | Epoch 14/20 | Loss: 34.8839 | Accuracy: 0.6312
# Task 10 | Backbone 6 | Epoch 15/20 | Loss: 34.2798 | Accuracy: 0.6347
# Task 10 | Backbone 6 | Epoch 16/20 | Loss: 35.2008 | Accuracy: 0.6193
# Task 10 | Backbone 6 | Epoch 17/20 | Loss: 38.0665 | Accuracy: 0.5962
# Task 10 | Backbone 6 | Epoch 18/20 | Loss: 34.7241 | Accuracy: 0.6263
# Task 10 | Backbone 6 | Epoch 19/20 | Loss: 34.0632 | Accuracy: 0.6389
# Task 10 | Backbone 6 | Epoch 20/20 | Loss: 33.2962 | Accuracy: 0.6382
# Successfully applied backbone weights for Image task.
# Task 11 | Backbone 10 | Epoch 1/20 | Loss: 40.8071 | Accuracy: 0.5316
# Task 11 | Backbone 10 | Epoch 2/20 | Loss: 40.0861 | Accuracy: 0.5375
# Task 11 | Backbone 10 | Epoch 3/20 | Loss: 39.6957 | Accuracy: 0.5418
# Task 11 | Backbone 10 | Epoch 4/20 | Loss: 39.4089 | Accuracy: 0.5491
# Task 11 | Backbone 10 | Epoch 5/20 | Loss: 38.9949 | Accuracy: 0.5491
# Task 11 | Backbone 10 | Epoch 6/20 | Loss: 38.6981 | Accuracy: 0.5585
# Task 11 | Backbone 10 | Epoch 7/20 | Loss: 38.4298 | Accuracy: 0.5702
# Task 11 | Backbone 10 | Epoch 8/20 | Loss: 37.9711 | Accuracy: 0.5767
# Task 11 | Backbone 10 | Epoch 9/20 | Loss: 37.5592 | Accuracy: 0.5942
# Task 11 | Backbone 10 | Epoch 10/20 | Loss: 37.1893 | Accuracy: 0.5993
# Task 11 | Backbone 10 | Epoch 11/20 | Loss: 36.8821 | Accuracy: 0.5993
# Task 11 | Backbone 10 | Epoch 12/20 | Loss: 37.1727 | Accuracy: 0.6044
# Task 11 | Backbone 10 | Epoch 13/20 | Loss: 36.4636 | Accuracy: 0.6080
# Task 11 | Backbone 10 | Epoch 14/20 | Loss: 35.8157 | Accuracy: 0.6262
# Task 11 | Backbone 10 | Epoch 15/20 | Loss: 35.0402 | Accuracy: 0.6298
# Task 11 | Backbone 10 | Epoch 16/20 | Loss: 35.1224 | Accuracy: 0.6342
# Task 11 | Backbone 10 | Epoch 17/20 | Loss: 35.5603 | Accuracy: 0.6342
# Task 11 | Backbone 10 | Epoch 18/20 | Loss: 35.7980 | Accuracy: 0.6160
# Task 11 | Backbone 10 | Epoch 19/20 | Loss: 34.9283 | Accuracy: 0.6305
# Task 11 | Backbone 10 | Epoch 20/20 | Loss: 34.0634 | Accuracy: 0.6509
# Starting Euclidean-based Knowledge Transfer...
# Successfully applied backbone weights for Image task.
# Task 0 | Backbone 7 | Epoch 1/20 | Loss: 56.7881 | Accuracy: 0.4842
# Task 0 | Backbone 7 | Epoch 2/20 | Loss: 38.9309 | Accuracy: 0.5898
# Task 0 | Backbone 7 | Epoch 3/20 | Loss: 36.0026 | Accuracy: 0.6358
# Task 0 | Backbone 7 | Epoch 4/20 | Loss: 34.3069 | Accuracy: 0.6502
# Task 0 | Backbone 7 | Epoch 5/20 | Loss: 33.2252 | Accuracy: 0.6708
# Task 0 | Backbone 7 | Epoch 6/20 | Loss: 32.3379 | Accuracy: 0.6852
# Task 0 | Backbone 7 | Epoch 7/20 | Loss: 31.4357 | Accuracy: 0.6982
# Task 0 | Backbone 7 | Epoch 8/20 | Loss: 30.4533 | Accuracy: 0.7202
# Task 0 | Backbone 7 | Epoch 9/20 | Loss: 29.4397 | Accuracy: 0.7394
# Task 0 | Backbone 7 | Epoch 10/20 | Loss: 28.4405 | Accuracy: 0.7579
# Task 0 | Backbone 7 | Epoch 11/20 | Loss: 27.4350 | Accuracy: 0.7737
# Task 0 | Backbone 7 | Epoch 12/20 | Loss: 26.4831 | Accuracy: 0.7901
# Task 0 | Backbone 7 | Epoch 13/20 | Loss: 25.5531 | Accuracy: 0.8004
# Task 0 | Backbone 7 | Epoch 14/20 | Loss: 24.6424 | Accuracy: 0.8121
# Task 0 | Backbone 7 | Epoch 15/20 | Loss: 23.7415 | Accuracy: 0.8251
# Task 0 | Backbone 7 | Epoch 16/20 | Loss: 22.8943 | Accuracy: 0.8326
# Task 0 | Backbone 7 | Epoch 17/20 | Loss: 22.1355 | Accuracy: 0.8388
# Task 0 | Backbone 7 | Epoch 18/20 | Loss: 21.3249 | Accuracy: 0.8450
# Task 0 | Backbone 7 | Epoch 19/20 | Loss: 20.5788 | Accuracy: 0.8532
# Task 0 | Backbone 7 | Epoch 20/20 | Loss: 19.8889 | Accuracy: 0.8628
# Successfully applied backbone weights for Image task.
# Task 1 | Backbone 10 | Epoch 1/20 | Loss: 75.6196 | Accuracy: 0.3175
# Task 1 | Backbone 10 | Epoch 2/20 | Loss: 48.0274 | Accuracy: 0.4569
# Task 1 | Backbone 10 | Epoch 3/20 | Loss: 46.3806 | Accuracy: 0.4859
# Task 1 | Backbone 10 | Epoch 4/20 | Loss: 44.8913 | Accuracy: 0.5100
# Task 1 | Backbone 10 | Epoch 5/20 | Loss: 43.6391 | Accuracy: 0.5369
# Task 1 | Backbone 10 | Epoch 6/20 | Loss: 42.4855 | Accuracy: 0.5521
# Task 1 | Backbone 10 | Epoch 7/20 | Loss: 41.4348 | Accuracy: 0.5576
# Task 1 | Backbone 10 | Epoch 8/20 | Loss: 40.4809 | Accuracy: 0.5707
# Task 1 | Backbone 10 | Epoch 9/20 | Loss: 39.4927 | Accuracy: 0.5825
# Task 1 | Backbone 10 | Epoch 10/20 | Loss: 38.5195 | Accuracy: 0.5914
# Task 1 | Backbone 10 | Epoch 11/20 | Loss: 37.6151 | Accuracy: 0.6039
# Task 1 | Backbone 10 | Epoch 12/20 | Loss: 36.7282 | Accuracy: 0.6163
# Task 1 | Backbone 10 | Epoch 13/20 | Loss: 35.7780 | Accuracy: 0.6301
# Task 1 | Backbone 10 | Epoch 14/20 | Loss: 34.8074 | Accuracy: 0.6446
# Task 1 | Backbone 10 | Epoch 15/20 | Loss: 33.9849 | Accuracy: 0.6563
# Task 1 | Backbone 10 | Epoch 16/20 | Loss: 33.1588 | Accuracy: 0.6715
# Task 1 | Backbone 10 | Epoch 17/20 | Loss: 32.4145 | Accuracy: 0.6805
# Task 1 | Backbone 10 | Epoch 18/20 | Loss: 31.6597 | Accuracy: 0.6867
# Task 1 | Backbone 10 | Epoch 19/20 | Loss: 30.9390 | Accuracy: 0.6950
# Task 1 | Backbone 10 | Epoch 20/20 | Loss: 30.1618 | Accuracy: 0.7060
# Successfully applied backbone weights for Image task.
# Task 2 | Backbone 8 | Epoch 1/20 | Loss: 6.5051 | Accuracy: 0.9654
# Task 2 | Backbone 8 | Epoch 2/20 | Loss: 6.3606 | Accuracy: 0.9675
# Task 2 | Backbone 8 | Epoch 3/20 | Loss: 6.2313 | Accuracy: 0.9675
# Task 2 | Backbone 8 | Epoch 4/20 | Loss: 6.0564 | Accuracy: 0.9689
# Task 2 | Backbone 8 | Epoch 5/20 | Loss: 5.8989 | Accuracy: 0.9703
# Task 2 | Backbone 8 | Epoch 6/20 | Loss: 5.7196 | Accuracy: 0.9723
# Task 2 | Backbone 8 | Epoch 7/20 | Loss: 5.5834 | Accuracy: 0.9730
# Task 2 | Backbone 8 | Epoch 8/20 | Loss: 5.4438 | Accuracy: 0.9744
# Task 2 | Backbone 8 | Epoch 9/20 | Loss: 5.3327 | Accuracy: 0.9751
# Task 2 | Backbone 8 | Epoch 10/20 | Loss: 5.2443 | Accuracy: 0.9758
# Task 2 | Backbone 8 | Epoch 11/20 | Loss: 5.1425 | Accuracy: 0.9758
# Task 2 | Backbone 8 | Epoch 12/20 | Loss: 5.0417 | Accuracy: 0.9772
# Task 2 | Backbone 8 | Epoch 13/20 | Loss: 4.9615 | Accuracy: 0.9765
# Task 2 | Backbone 8 | Epoch 14/20 | Loss: 4.8615 | Accuracy: 0.9772
# Task 2 | Backbone 8 | Epoch 15/20 | Loss: 4.7819 | Accuracy: 0.9765
# Task 2 | Backbone 8 | Epoch 16/20 | Loss: 4.6644 | Accuracy: 0.9765
# Task 2 | Backbone 8 | Epoch 17/20 | Loss: 4.5515 | Accuracy: 0.9765
# Task 2 | Backbone 8 | Epoch 18/20 | Loss: 4.4071 | Accuracy: 0.9779
# Task 2 | Backbone 8 | Epoch 19/20 | Loss: 4.2976 | Accuracy: 0.9806
# Task 2 | Backbone 8 | Epoch 20/20 | Loss: 4.1776 | Accuracy: 0.9813
# Successfully applied backbone weights for Image task.
# Task 3 | Backbone 10 | Epoch 1/20 | Loss: 71.3724 | Accuracy: 0.3684
# Task 3 | Backbone 10 | Epoch 2/20 | Loss: 47.0252 | Accuracy: 0.4610
# Task 3 | Backbone 10 | Epoch 3/20 | Loss: 46.1196 | Accuracy: 0.4854
# Task 3 | Backbone 10 | Epoch 4/20 | Loss: 45.3746 | Accuracy: 0.5000
# Task 3 | Backbone 10 | Epoch 5/20 | Loss: 44.6397 | Accuracy: 0.5118
# Task 3 | Backbone 10 | Epoch 6/20 | Loss: 43.8600 | Accuracy: 0.5286
# Task 3 | Backbone 10 | Epoch 7/20 | Loss: 43.0505 | Accuracy: 0.5467
# Task 3 | Backbone 10 | Epoch 8/20 | Loss: 42.1856 | Accuracy: 0.5641
# Task 3 | Backbone 10 | Epoch 9/20 | Loss: 41.2293 | Accuracy: 0.5766
# Task 3 | Backbone 10 | Epoch 10/20 | Loss: 40.3247 | Accuracy: 0.5912
# Task 3 | Backbone 10 | Epoch 11/20 | Loss: 39.4737 | Accuracy: 0.6024
# Task 3 | Backbone 10 | Epoch 12/20 | Loss: 38.6091 | Accuracy: 0.6274
# Task 3 | Backbone 10 | Epoch 13/20 | Loss: 37.7684 | Accuracy: 0.6421
# Task 3 | Backbone 10 | Epoch 14/20 | Loss: 36.8534 | Accuracy: 0.6546
# Task 3 | Backbone 10 | Epoch 15/20 | Loss: 35.9443 | Accuracy: 0.6699
# Task 3 | Backbone 10 | Epoch 16/20 | Loss: 34.9612 | Accuracy: 0.6859
# Task 3 | Backbone 10 | Epoch 17/20 | Loss: 33.9468 | Accuracy: 0.6985
# Task 3 | Backbone 10 | Epoch 18/20 | Loss: 33.0082 | Accuracy: 0.7103
# Task 3 | Backbone 10 | Epoch 19/20 | Loss: 32.0728 | Accuracy: 0.7256
# Task 3 | Backbone 10 | Epoch 20/20 | Loss: 31.2700 | Accuracy: 0.7333
# Successfully applied backbone weights for Image task.
# Task 4 | Backbone 10 | Epoch 1/20 | Loss: 5.8181 | Accuracy: 0.9755
# Task 4 | Backbone 10 | Epoch 2/20 | Loss: 5.6796 | Accuracy: 0.9762
# Task 4 | Backbone 10 | Epoch 3/20 | Loss: 5.5723 | Accuracy: 0.9769
# Task 4 | Backbone 10 | Epoch 4/20 | Loss: 5.4688 | Accuracy: 0.9769
# Task 4 | Backbone 10 | Epoch 5/20 | Loss: 5.3404 | Accuracy: 0.9776
# Task 4 | Backbone 10 | Epoch 6/20 | Loss: 5.2392 | Accuracy: 0.9776
# Task 4 | Backbone 10 | Epoch 7/20 | Loss: 5.1163 | Accuracy: 0.9790
# Task 4 | Backbone 10 | Epoch 8/20 | Loss: 4.9721 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 9/20 | Loss: 4.9185 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 10/20 | Loss: 4.8709 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 11/20 | Loss: 4.8213 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 12/20 | Loss: 4.7666 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 13/20 | Loss: 4.7267 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 14/20 | Loss: 4.6409 | Accuracy: 0.9811
# Task 4 | Backbone 10 | Epoch 15/20 | Loss: 4.5426 | Accuracy: 0.9818
# Task 4 | Backbone 10 | Epoch 16/20 | Loss: 4.4434 | Accuracy: 0.9818
# Task 4 | Backbone 10 | Epoch 17/20 | Loss: 4.3519 | Accuracy: 0.9825
# Task 4 | Backbone 10 | Epoch 18/20 | Loss: 4.3025 | Accuracy: 0.9825
# Task 4 | Backbone 10 | Epoch 19/20 | Loss: 4.2457 | Accuracy: 0.9825
# Task 4 | Backbone 10 | Epoch 20/20 | Loss: 4.1415 | Accuracy: 0.9825
# Successfully applied backbone weights for Text task.
# Task 5 | Backbone 4 | Epoch 1/20 | Loss: 77.0595 | Accuracy: 0.3535
# Task 5 | Backbone 4 | Epoch 2/20 | Loss: 43.2560 | Accuracy: 0.4967
# Task 5 | Backbone 4 | Epoch 3/20 | Loss: 40.8042 | Accuracy: 0.5658
# Task 5 | Backbone 4 | Epoch 4/20 | Loss: 38.6745 | Accuracy: 0.6036
# Task 5 | Backbone 4 | Epoch 5/20 | Loss: 36.9392 | Accuracy: 0.6291
# Task 5 | Backbone 4 | Epoch 6/20 | Loss: 35.4372 | Accuracy: 0.6524
# Task 5 | Backbone 4 | Epoch 7/20 | Loss: 33.9585 | Accuracy: 0.6822
# Task 5 | Backbone 4 | Epoch 8/20 | Loss: 32.5547 | Accuracy: 0.7062
# Task 5 | Backbone 4 | Epoch 9/20 | Loss: 31.1222 | Accuracy: 0.7251
# Task 5 | Backbone 4 | Epoch 10/20 | Loss: 29.6523 | Accuracy: 0.7440
# Task 5 | Backbone 4 | Epoch 11/20 | Loss: 28.2128 | Accuracy: 0.7673
# Task 5 | Backbone 4 | Epoch 12/20 | Loss: 26.9104 | Accuracy: 0.7847
# Task 5 | Backbone 4 | Epoch 13/20 | Loss: 25.7920 | Accuracy: 0.7978
# Task 5 | Backbone 4 | Epoch 14/20 | Loss: 24.8555 | Accuracy: 0.8080
# Task 5 | Backbone 4 | Epoch 15/20 | Loss: 24.0411 | Accuracy: 0.8204
# Task 5 | Backbone 4 | Epoch 16/20 | Loss: 23.4083 | Accuracy: 0.8305
# Task 5 | Backbone 4 | Epoch 17/20 | Loss: 22.8529 | Accuracy: 0.8335
# Task 5 | Backbone 4 | Epoch 18/20 | Loss: 22.3742 | Accuracy: 0.8378
# Task 5 | Backbone 4 | Epoch 19/20 | Loss: 21.8884 | Accuracy: 0.8407
# Task 5 | Backbone 4 | Epoch 20/20 | Loss: 21.3969 | Accuracy: 0.8458
# Successfully applied backbone weights for Image task.
# Task 6 | Backbone 10 | Epoch 1/20 | Loss: 26.7528 | Accuracy: 0.7503
# Task 6 | Backbone 10 | Epoch 2/20 | Loss: 26.7599 | Accuracy: 0.7531
# Task 6 | Backbone 10 | Epoch 3/20 | Loss: 25.6970 | Accuracy: 0.7682
# Task 6 | Backbone 10 | Epoch 4/20 | Loss: 25.3912 | Accuracy: 0.7785
# Task 6 | Backbone 10 | Epoch 5/20 | Loss: 24.3795 | Accuracy: 0.7901
# Task 6 | Backbone 10 | Epoch 6/20 | Loss: 23.7633 | Accuracy: 0.7970
# Task 6 | Backbone 10 | Epoch 7/20 | Loss: 25.0885 | Accuracy: 0.7908
# Task 6 | Backbone 10 | Epoch 8/20 | Loss: 25.3490 | Accuracy: 0.7737
# Task 6 | Backbone 10 | Epoch 9/20 | Loss: 25.8107 | Accuracy: 0.7805
# Task 6 | Backbone 10 | Epoch 10/20 | Loss: 25.4266 | Accuracy: 0.7826
# Task 6 | Backbone 10 | Epoch 11/20 | Loss: 25.3729 | Accuracy: 0.7846
# Task 6 | Backbone 10 | Epoch 12/20 | Loss: 23.6987 | Accuracy: 0.8011
# Task 6 | Backbone 10 | Epoch 13/20 | Loss: 22.4319 | Accuracy: 0.8128
# Task 6 | Backbone 10 | Epoch 14/20 | Loss: 22.6366 | Accuracy: 0.8080
# Task 6 | Backbone 10 | Epoch 15/20 | Loss: 20.7805 | Accuracy: 0.8320
# Task 6 | Backbone 10 | Epoch 16/20 | Loss: 21.3679 | Accuracy: 0.8251
# Task 6 | Backbone 10 | Epoch 17/20 | Loss: 23.4469 | Accuracy: 0.7908
# Task 6 | Backbone 10 | Epoch 18/20 | Loss: 22.1539 | Accuracy: 0.8169
# Task 6 | Backbone 10 | Epoch 19/20 | Loss: 20.1208 | Accuracy: 0.8368
# Task 6 | Backbone 10 | Epoch 20/20 | Loss: 20.2205 | Accuracy: 0.8374
# Successfully applied backbone weights for Image task.
# Task 7 | Backbone 11 | Epoch 1/20 | Loss: 29.3311 | Accuracy: 0.6977
# Task 7 | Backbone 11 | Epoch 2/20 | Loss: 28.2704 | Accuracy: 0.7122
# Task 7 | Backbone 11 | Epoch 3/20 | Loss: 27.6021 | Accuracy: 0.7191
# Task 7 | Backbone 11 | Epoch 4/20 | Loss: 27.0238 | Accuracy: 0.7246
# Task 7 | Backbone 11 | Epoch 5/20 | Loss: 26.9377 | Accuracy: 0.7322
# Task 7 | Backbone 11 | Epoch 6/20 | Loss: 30.0636 | Accuracy: 0.6991
# Task 7 | Backbone 11 | Epoch 7/20 | Loss: 27.7205 | Accuracy: 0.7246
# Task 7 | Backbone 11 | Epoch 8/20 | Loss: 27.1857 | Accuracy: 0.7239
# Task 7 | Backbone 11 | Epoch 9/20 | Loss: 27.9626 | Accuracy: 0.7219
# Task 7 | Backbone 11 | Epoch 10/20 | Loss: 25.3435 | Accuracy: 0.7467
# Task 7 | Backbone 11 | Epoch 11/20 | Loss: 24.5455 | Accuracy: 0.7578
# Task 7 | Backbone 11 | Epoch 12/20 | Loss: 26.7031 | Accuracy: 0.7295
# Task 7 | Backbone 11 | Epoch 13/20 | Loss: 24.7095 | Accuracy: 0.7564
# Task 7 | Backbone 11 | Epoch 14/20 | Loss: 26.2377 | Accuracy: 0.7447
# Task 7 | Backbone 11 | Epoch 15/20 | Loss: 24.6602 | Accuracy: 0.7674
# Task 7 | Backbone 11 | Epoch 16/20 | Loss: 26.1741 | Accuracy: 0.7488
# Task 7 | Backbone 11 | Epoch 17/20 | Loss: 26.0534 | Accuracy: 0.7447
# Task 7 | Backbone 11 | Epoch 18/20 | Loss: 23.3573 | Accuracy: 0.7743
# Task 7 | Backbone 11 | Epoch 19/20 | Loss: 24.0581 | Accuracy: 0.7647
# Task 7 | Backbone 11 | Epoch 20/20 | Loss: 24.0248 | Accuracy: 0.7612
# Successfully applied backbone weights for Image task.
# Task 8 | Backbone 6 | Epoch 1/20 | Loss: 34.1453 | Accuracy: 0.7033
# Task 8 | Backbone 6 | Epoch 2/20 | Loss: 37.0100 | Accuracy: 0.6625
# Task 8 | Backbone 6 | Epoch 3/20 | Loss: 34.0736 | Accuracy: 0.7026
# Task 8 | Backbone 6 | Epoch 4/20 | Loss: 33.1369 | Accuracy: 0.7178
# Task 8 | Backbone 6 | Epoch 5/20 | Loss: 32.3068 | Accuracy: 0.7165
# Task 8 | Backbone 6 | Epoch 6/20 | Loss: 31.5042 | Accuracy: 0.7317
# Task 8 | Backbone 6 | Epoch 7/20 | Loss: 31.9658 | Accuracy: 0.7241
# Task 8 | Backbone 6 | Epoch 8/20 | Loss: 32.0201 | Accuracy: 0.7220
# Task 8 | Backbone 6 | Epoch 9/20 | Loss: 32.3269 | Accuracy: 0.7172
# Task 8 | Backbone 6 | Epoch 10/20 | Loss: 31.8635 | Accuracy: 0.7241
# Task 8 | Backbone 6 | Epoch 11/20 | Loss: 31.4434 | Accuracy: 0.7282
# Task 8 | Backbone 6 | Epoch 12/20 | Loss: 32.9026 | Accuracy: 0.7130
# Task 8 | Backbone 6 | Epoch 13/20 | Loss: 30.0503 | Accuracy: 0.7441
# Task 8 | Backbone 6 | Epoch 14/20 | Loss: 30.8839 | Accuracy: 0.7344
# Task 8 | Backbone 6 | Epoch 15/20 | Loss: 29.3222 | Accuracy: 0.7490
# Task 8 | Backbone 6 | Epoch 16/20 | Loss: 26.9656 | Accuracy: 0.7801
# Task 8 | Backbone 6 | Epoch 17/20 | Loss: 27.2345 | Accuracy: 0.7828
# Task 8 | Backbone 6 | Epoch 18/20 | Loss: 26.8283 | Accuracy: 0.7863
# Task 8 | Backbone 6 | Epoch 19/20 | Loss: 26.0873 | Accuracy: 0.7828
# Task 8 | Backbone 6 | Epoch 20/20 | Loss: 25.1255 | Accuracy: 0.8071
# Successfully applied backbone weights for Image task.
# Task 9 | Backbone 10 | Epoch 1/20 | Loss: 25.0720 | Accuracy: 0.7786
# Task 9 | Backbone 10 | Epoch 2/20 | Loss: 24.2827 | Accuracy: 0.7772
# Task 9 | Backbone 10 | Epoch 3/20 | Loss: 24.3963 | Accuracy: 0.7848
# Task 9 | Backbone 10 | Epoch 4/20 | Loss: 23.2098 | Accuracy: 0.7862
# Task 9 | Backbone 10 | Epoch 5/20 | Loss: 23.0260 | Accuracy: 0.7994
# Task 9 | Backbone 10 | Epoch 6/20 | Loss: 22.5560 | Accuracy: 0.8057
# Task 9 | Backbone 10 | Epoch 7/20 | Loss: 22.6163 | Accuracy: 0.8008
# Task 9 | Backbone 10 | Epoch 8/20 | Loss: 26.4112 | Accuracy: 0.7779
# Task 9 | Backbone 10 | Epoch 9/20 | Loss: 22.1471 | Accuracy: 0.7981
# Task 9 | Backbone 10 | Epoch 10/20 | Loss: 21.4942 | Accuracy: 0.8162
# Task 9 | Backbone 10 | Epoch 11/20 | Loss: 19.8466 | Accuracy: 0.8273
# Task 9 | Backbone 10 | Epoch 12/20 | Loss: 18.8913 | Accuracy: 0.8364
# Task 9 | Backbone 10 | Epoch 13/20 | Loss: 19.6926 | Accuracy: 0.8266
# Task 9 | Backbone 10 | Epoch 14/20 | Loss: 18.1966 | Accuracy: 0.8440
# Task 9 | Backbone 10 | Epoch 15/20 | Loss: 18.1151 | Accuracy: 0.8510
# Task 9 | Backbone 10 | Epoch 16/20 | Loss: 20.1005 | Accuracy: 0.8419
# Task 9 | Backbone 10 | Epoch 17/20 | Loss: 17.2579 | Accuracy: 0.8517
# Task 9 | Backbone 10 | Epoch 18/20 | Loss: 16.1297 | Accuracy: 0.8677
# Task 9 | Backbone 10 | Epoch 19/20 | Loss: 16.7210 | Accuracy: 0.8670
# Task 9 | Backbone 10 | Epoch 20/20 | Loss: 16.3781 | Accuracy: 0.8670
# Successfully applied backbone weights for Image task.
# Task 10 | Backbone 6 | Epoch 1/20 | Loss: 33.0743 | Accuracy: 0.6424
# Task 10 | Backbone 6 | Epoch 2/20 | Loss: 33.3533 | Accuracy: 0.6424
# Task 10 | Backbone 6 | Epoch 3/20 | Loss: 32.9535 | Accuracy: 0.6557
# Task 10 | Backbone 6 | Epoch 4/20 | Loss: 33.2042 | Accuracy: 0.6606
# Task 10 | Backbone 6 | Epoch 5/20 | Loss: 33.1359 | Accuracy: 0.6564
# Task 10 | Backbone 6 | Epoch 6/20 | Loss: 32.8200 | Accuracy: 0.6578
# Task 10 | Backbone 6 | Epoch 7/20 | Loss: 32.3076 | Accuracy: 0.6732
# Task 10 | Backbone 6 | Epoch 8/20 | Loss: 32.7274 | Accuracy: 0.6606
# Task 10 | Backbone 6 | Epoch 9/20 | Loss: 31.5273 | Accuracy: 0.6914
# Task 10 | Backbone 6 | Epoch 10/20 | Loss: 31.4431 | Accuracy: 0.6865
# Task 10 | Backbone 6 | Epoch 11/20 | Loss: 31.3997 | Accuracy: 0.6865
# Task 10 | Backbone 6 | Epoch 12/20 | Loss: 32.5238 | Accuracy: 0.6809
# Task 10 | Backbone 6 | Epoch 13/20 | Loss: 32.7884 | Accuracy: 0.6823
# Task 10 | Backbone 6 | Epoch 14/20 | Loss: 31.2167 | Accuracy: 0.6879
# Task 10 | Backbone 6 | Epoch 15/20 | Loss: 29.6922 | Accuracy: 0.7082
# Task 10 | Backbone 6 | Epoch 16/20 | Loss: 29.2427 | Accuracy: 0.7145
# Task 10 | Backbone 6 | Epoch 17/20 | Loss: 28.7758 | Accuracy: 0.7222
# Task 10 | Backbone 6 | Epoch 18/20 | Loss: 29.2275 | Accuracy: 0.7306
# Task 10 | Backbone 6 | Epoch 19/20 | Loss: 28.2318 | Accuracy: 0.7383
# Task 10 | Backbone 6 | Epoch 20/20 | Loss: 29.0834 | Accuracy: 0.7257
# Successfully applied backbone weights for Image task.
# Task 11 | Backbone 10 | Epoch 1/20 | Loss: 33.9551 | Accuracy: 0.6538
# Task 11 | Backbone 10 | Epoch 2/20 | Loss: 35.9292 | Accuracy: 0.6291
# Task 11 | Backbone 10 | Epoch 3/20 | Loss: 33.3643 | Accuracy: 0.6611
# Task 11 | Backbone 10 | Epoch 4/20 | Loss: 33.6041 | Accuracy: 0.6618
# Task 11 | Backbone 10 | Epoch 5/20 | Loss: 32.3424 | Accuracy: 0.6764
# Task 11 | Backbone 10 | Epoch 6/20 | Loss: 32.4534 | Accuracy: 0.6829
# Task 11 | Backbone 10 | Epoch 7/20 | Loss: 32.0538 | Accuracy: 0.6764
# Task 11 | Backbone 10 | Epoch 8/20 | Loss: 30.1723 | Accuracy: 0.7025
# Task 11 | Backbone 10 | Epoch 9/20 | Loss: 30.3885 | Accuracy: 0.6975
# Task 11 | Backbone 10 | Epoch 10/20 | Loss: 30.3665 | Accuracy: 0.7040
# Task 11 | Backbone 10 | Epoch 11/20 | Loss: 30.0883 | Accuracy: 0.6982
# Task 11 | Backbone 10 | Epoch 12/20 | Loss: 29.7350 | Accuracy: 0.7127
# Task 11 | Backbone 10 | Epoch 13/20 | Loss: 31.6708 | Accuracy: 0.6836
# Task 11 | Backbone 10 | Epoch 14/20 | Loss: 28.7076 | Accuracy: 0.7287
# Task 11 | Backbone 10 | Epoch 15/20 | Loss: 27.9640 | Accuracy: 0.7411
# Task 11 | Backbone 10 | Epoch 16/20 | Loss: 27.4489 | Accuracy: 0.7440
# Task 11 | Backbone 10 | Epoch 17/20 | Loss: 27.0566 | Accuracy: 0.7513
# Task 11 | Backbone 10 | Epoch 18/20 | Loss: 28.3881 | Accuracy: 0.7367
# Task 11 | Backbone 10 | Epoch 19/20 | Loss: 29.3037 | Accuracy: 0.7185
# Task 11 | Backbone 10 | Epoch 20/20 | Loss: 26.1120 | Accuracy: 0.7535
# Evaluating final results...
# Task 0 (Text) | Test Loss: 0.4332, Test Accuracy: 0.8621
# Task 1 (Text) | Test Loss: 0.6354, Test Accuracy: 0.7143
# Task 2 (Text) | Test Loss: 0.0880, Test Accuracy: 0.9820
# Task 3 (Text) | Test Loss: 0.6730, Test Accuracy: 0.7493
# Task 4 (Text) | Test Loss: 0.0923, Test Accuracy: 0.9825
# Task 5 (Text) | Test Loss: 0.4818, Test Accuracy: 0.8516
# Task 6 (Image) | Test Loss: 0.4113, Test Accuracy: 0.8477
# Task 7 (Image) | Test Loss: 0.5326, Test Accuracy: 0.7598
# Task 8 (Image) | Test Loss: 0.5646, Test Accuracy: 0.8008
# Task 9 (Image) | Test Loss: 0.4279, Test Accuracy: 0.8398
# Task 10 (Image) | Test Loss: 0.6658, Test Accuracy: 0.7425
# Task 11 (Image) | Test Loss: 0.6722, Test Accuracy: 0.7258

# %%
import pickle

file_path = "/home/youlee/perceiver/perceiver/checkpoints_pruned/text_model_1_pruned.pkl"

try:
    with open(file_path, 'rb') as f:
        model_data = pickle.load(f)
    print("Successfully loaded the file. Keys in the file:")
    print(model_data.keys())
except Exception as e:
    print(f"Error while opening the file: {e}")


# model_state_dict 내부 키 확인
state_dict = model_data["model_state_dict"]
print("Keys in model_state_dict:")
print(list(state_dict.keys())[:10])  # 첫 10개의 키

# masks 내부 키 확인
masks = model_data["masks"]
print("Keys in masks:")
print(list(masks.keys())[:10])  # 첫 10개의 키
# Out:
# Successfully loaded the file. Keys in the file:
# dict_keys(['model_state_dict', 'masks'])
# Keys in model_state_dict:
# ['model.embedding.weight', 'model.perceiver.latents', 'model.perceiver.input_projection.weight', 'model.perceiver.input_projection.bias', 'model.perceiver.blocks.0.cross_attn.in_proj_weight', 'model.perceiver.blocks.0.cross_attn.in_proj_bias', 'model.perceiver.blocks.0.cross_attn.out_proj.weight', 'model.perceiver.blocks.0.cross_attn.out_proj.bias', 'model.perceiver.blocks.0.cross_ln.weight', 'model.perceiver.blocks.0.cross_ln.bias']
# Keys in masks:
# ['text_task_1']

# %%
import pickle

file_path = "/home/youlee/perceiver/perceiver/checkpoints_pruned/image_model_1_pruned.pkl"

try:
    with open(file_path, 'rb') as f:
        model_data = pickle.load(f)
    print("Successfully loaded the file. Keys in the file:")
    print(model_data.keys())
except Exception as e:
    print(f"Error while opening the file: {e}")


# model_state_dict 내부 키 확인
state_dict = model_data["model_state_dict"]
print("Keys in model_state_dict:")
print(list(state_dict.keys())[:10])  # 첫 10개의 키

# masks 내부 키 확인
masks = model_data["masks"]
print("Keys in masks:")
print(list(masks.keys())[:10])  # 첫 10개의 키
# Out:
# Successfully loaded the file. Keys in the file:
# dict_keys(['model_state_dict', 'masks'])
# Keys in model_state_dict:
# ['model.latents', 'model.input_projection.weight', 'model.input_projection.bias', 'model.blocks.0.cross_attn.in_proj_weight', 'model.blocks.0.cross_attn.in_proj_bias', 'model.blocks.0.cross_attn.out_proj.weight', 'model.blocks.0.cross_attn.out_proj.bias', 'model.blocks.0.cross_ln.weight', 'model.blocks.0.cross_ln.bias', 'model.blocks.0.self_attn_layers.0.self_attn.in_proj_weight']
# Keys in masks:
# ['image_task_1']
