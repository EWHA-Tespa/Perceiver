# %% [markdown]
# # Setting

# %%
# !pip install datasets
# !pip install transformers

# %%
import os
import glob
import random
import time
import torch
import torch.nn as nn
import torch.optim as optim
import pickle
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from collections import Counter
from sklearn.preprocessing import LabelEncoder

from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

import torchvision.transforms as T

from perceiver import crop, patchify, get_patch_coords, ImageDataset, PerceiverBlock, Perceiver

# %%
def seed_everything(seed):
    torch.manual_seed(seed) #torch를 거치는 모든 난수들의 생성순서를 고정한다
    torch.cuda.manual_seed(seed) #cuda를 사용하는 메소드들의 난수시드는 따로 고정해줘야한다 
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True #딥러닝에 특화된 CuDNN의 난수시드도 고정 
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed) #numpy를 사용할 경우 고정
    random.seed(seed) #파이썬 자체 모듈 random 모듈의 시드 고정

def seed_worker(worker_id): #데이터로더 난수고정
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

seed_everything(42)
g = torch.Generator()
g.manual_seed(42)
NUM_WORKERS = 4 # 서브프로세스관리자 수. 난수생성과 관련있습니다. 일단은 4로 고정합니다.

# %% [markdown]
# # Load Data

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, epochs, device, scheduler=None):
    best_model = None 
    best_val_score = 0
    model.train()
    train_losses = []
    val_accuracies = []
    start = time.perf_counter()
    for epoch in range(epochs):
        total_loss = 0.0
        for images, labels in train_loader:
            # GPU로 옮기기
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        accuracy = evaluate_model(model, valid_loader, device=device, log_results=False)
        val_accuracies.append(accuracy)

        # Scheduler step 추가
        if scheduler:
            scheduler.step()

        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}, Val Accuracy: {accuracy:.2f}%")
        if accuracy > best_val_score:
            best_val_score = accuracy
            best_model_state = model.state_dict()  # 모델 상태 저장
            best_model = copy.deepcopy(model) 
            print(f"New best model found at epoch {epoch+1} with accuracy: {best_val_score:.2f}%")

    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Total Train time: {hour}h {min}m {sec}s")

    return train_losses, val_accuracies, best_model

def evaluate_model(model, data_loader, device, log_results=True):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        start = time.perf_counter()
        for images, labels in data_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        end = time.perf_counter()
        hour = (end-start) // 3600
        min = ((end-start) % 3600) // 60
        sec = (end-start) % 60
        print(f"Elapsed time on CPU: {hour}h {min}m {sec}s")

    accuracy = 100.0 * correct / total
    if log_results:
        print(f"Test Accuracy: {accuracy:.2f}%")
    return accuracy

# %%
def plot_learning_curve(train_losses, val_accuracies):
    fig, ax1 = plt.subplots()

    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Train Loss', color='tab:blue')
    ax1.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss', color='tab:blue')
    ax1.tick_params(axis='y', labelcolor='tab:blue')

    ax2 = ax1.twinx()
    ax2.set_ylabel('Validation Accuracy (%)', color='tab:orange')
    ax2.plot(range(1, len(val_accuracies) + 1), val_accuracies, label='Validation Accuracy', color='tab:orange')
    ax2.tick_params(axis='y', labelcolor='tab:orange')

    fig.tight_layout()
    plt.title('Learning Curve')
    plt.show()

# %%
data_dir = '/home/youlee/n24news/n24news/image'
crop_size = 0
patch_size = 16
batch_size = 32
epochs = 20
group_class = 3

# dataset = ImageDataset(root_dir=data_dir, transform=transform, crop_size=crop_size, patch_size=patch_size)
# label_encoder = dataset.label_encoder
# class_labels = label_encoder.classes_

# class_counts = {label:0 for label in class_labels}
# for _, label in dataset.data:
#     class_counts[label_encoder.inverse_transform([label])[0]] += 1

# target_classes = [label for label, count in class_counts.items() if count >= 2100]
# for label, count in class_counts.items():
#     if count>=2100:
#        print(f'{label}: {count}')

# %%
#random.shuffle(target_classes)
target_classes = [ # 임의로 순서지정
    "Opinion", "Art & Design", "Television",
    "Music", "Travel", "Real Estate",
    "Books", "Theater", "Health",
    "Sports", "Science", "Food",
    "Fashion & Style", "Movies", "Technology",
    "Dance", "Media", "Style"
]
target_classes
# Out:
# ['Opinion',
#  'Art & Design',
#  'Television',
#  'Music',
#  'Travel',
#  'Real Estate',
#  'Books',
#  'Theater',
#  'Health',
#  'Sports',
#  'Science',
#  'Food',
#  'Fashion & Style',
#  'Movies',
#  'Technology',
#  'Dance',
#  'Media',
#  'Style']

# %%
output_path = '/home/youlee/perceiver/perceiver/model'
loader_path = '/home/youlee/perceiver/perceiver/loader'

# %%
group_class
# Out:
# 3

# %%
for i in range(0, len(target_classes), group_class):  
    print(f"실험 {i//group_class + 1} 시작")
    selected_classes = target_classes[i:i+group_class]
    print(f"Selected Feature: {selected_classes}")

    filtered_dataset = ImageDataset(root_dir=data_dir, 
                                    transform=transform, 
                                    crop_size=crop_size, 
                                    patch_size=patch_size,
                                    selected_classes=selected_classes)
    all_labels = [label_idx for (_, label_idx) in filtered_dataset.data]

    # 1) 유니크 라벨과 개수
    unique_label_ids = np.unique(all_labels)
    print("Unique numeric labels:", unique_label_ids)
    print("Number of unique numeric labels:", len(unique_label_ids))

    # 2) 라벨별 개수 (분포)
    label_counts = Counter(all_labels)
    print("Label distribution (index: count):", label_counts)
    
    train_ratio = 0.8
    train_size = int(len(filtered_dataset) * train_ratio)
    valid_size = len(filtered_dataset) - train_size

    train_dataset, valid_dataset = random_split(filtered_dataset, [train_size, valid_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
                              num_workers=NUM_WORKERS, worker_init_fn=seed_worker, generator=g)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,
                              num_workers=NUM_WORKERS, worker_init_fn=seed_worker, generator=g)


    print(f"train: {train_size}, valid: {valid_size}")
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    NUM_CLASSES = len(filtered_dataset.label_encoder.classes_)
    model = Perceiver(input_dim=(patch_size**2) * 3 + 2,
                        latent_dim=64, 
                        latent_size=64, 
                        num_classes=NUM_CLASSES, 
                        num_blocks=4, 
                        self_attn_layers_per_block=10).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=1e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)  # Learning rate decay 추가

    start = time.perf_counter()
    train_losses, val_accuracies, best_model = train_model(
        model, train_loader, valid_loader,
        criterion, optimizer, epochs,
        device=device,
        scheduler=scheduler  
    )
    
    final_acc = evaluate_model(best_model, valid_loader, device=device, log_results=True)
    end = time.perf_counter()
    hour = (end-start) // 3600
    min = ((end-start) % 3600) // 60
    sec = int((end-start) % 60)
    print(f"Train time: {hour}h {min}m {sec}s")
    print(f"Final Validation Accuracy: {final_acc:.2f}%")
    print("----------------------------------------------------------")
    
    torch.save(best_model, f'{output_path}/image_model_{i//group_class+1}.pkl')

    val_loader_save_path = f"{loader_path}/image_val_loader_{i//group_class+1}.pkl"
    with open(val_loader_save_path, 'wb') as f:
        pickle.dump(valid_dataset, f)
# Out:
# 실험 1 시작
# Selected Feature: ['Opinion', 'Art & Design', 'Television']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(1): 2437, np.int64(0): 2431, np.int64(2): 2419})
# train: 5829, valid: 1458
# Elapsed time on CPU: 0.0h 0.0m 3.6826627729460597s
# Epoch 1/20, Loss: 1.0751, Val Accuracy: 42.80%
# New best model found at epoch 1 with accuracy: 42.80%
# Elapsed time on CPU: 0.0h 0.0m 4.1497489111498s
# Epoch 2/20, Loss: 1.0550, Val Accuracy: 42.04%
# Elapsed time on CPU: 0.0h 0.0m 4.235804952215403s
# Epoch 3/20, Loss: 1.0497, Val Accuracy: 42.32%
# Elapsed time on CPU: 0.0h 0.0m 4.129676366224885s
# Epoch 4/20, Loss: 1.0485, Val Accuracy: 42.66%
# Elapsed time on CPU: 0.0h 0.0m 4.234542198013514s
# Epoch 5/20, Loss: 1.0446, Val Accuracy: 44.17%
# New best model found at epoch 5 with accuracy: 44.17%
# Elapsed time on CPU: 0.0h 0.0m 4.1339484681375325s
# Epoch 6/20, Loss: 1.0324, Val Accuracy: 46.09%
# New best model found at epoch 6 with accuracy: 46.09%
# Elapsed time on CPU: 0.0h 0.0m 3.724106891080737s
# Epoch 7/20, Loss: 1.0236, Val Accuracy: 45.47%
# Elapsed time on CPU: 0.0h 0.0m 4.333912662230432s
# Epoch 8/20, Loss: 1.0225, Val Accuracy: 45.40%
# Elapsed time on CPU: 0.0h 0.0m 4.246997078880668s
# Epoch 9/20, Loss: 1.0151, Val Accuracy: 47.94%
# New best model found at epoch 9 with accuracy: 47.94%
# Elapsed time on CPU: 0.0h 0.0m 3.9917428200133145s
# Epoch 10/20, Loss: 0.9958, Val Accuracy: 53.64%
# New best model found at epoch 10 with accuracy: 53.64%
# Elapsed time on CPU: 0.0h 0.0m 3.93187585612759s
# Epoch 11/20, Loss: 0.7992, Val Accuracy: 64.61%
# New best model found at epoch 11 with accuracy: 64.61%
# Elapsed time on CPU: 0.0h 0.0m 4.123426536098123s
# Epoch 12/20, Loss: 0.7344, Val Accuracy: 65.16%
# New best model found at epoch 12 with accuracy: 65.16%
# Elapsed time on CPU: 0.0h 0.0m 4.412036264780909s
# Epoch 13/20, Loss: 0.7152, Val Accuracy: 67.42%
# New best model found at epoch 13 with accuracy: 67.42%
# Elapsed time on CPU: 0.0h 0.0m 4.0162873971275985s
# Epoch 14/20, Loss: 0.7014, Val Accuracy: 69.27%
# New best model found at epoch 14 with accuracy: 69.27%
# Elapsed time on CPU: 0.0h 0.0m 4.024852680973709s
# Epoch 15/20, Loss: 0.6943, Val Accuracy: 67.08%
# Elapsed time on CPU: 0.0h 0.0m 4.331150793004781s
# Epoch 16/20, Loss: 0.6761, Val Accuracy: 69.41%
# New best model found at epoch 16 with accuracy: 69.41%
# Elapsed time on CPU: 0.0h 0.0m 4.330474369227886s
# Epoch 17/20, Loss: 0.6669, Val Accuracy: 69.34%
# Elapsed time on CPU: 0.0h 0.0m 3.862102605868131s
# Epoch 18/20, Loss: 0.6633, Val Accuracy: 68.45%
# Elapsed time on CPU: 0.0h 0.0m 4.367518812883645s
# Epoch 19/20, Loss: 0.6596, Val Accuracy: 69.34%
# Elapsed time on CPU: 0.0h 0.0m 4.020602856762707s
# Epoch 20/20, Loss: 0.6556, Val Accuracy: 70.03%
# New best model found at epoch 20 with accuracy: 70.03%
# Total Train time: 0.0h 7.0m 42s
# Elapsed time on CPU: 0.0h 0.0m 3.953790200408548s
# Test Accuracy: 70.03%
# Train time: 0.0h 7.0m 46s
# Final Validation Accuracy: 70.03%
# ----------------------------------------------------------
# 실험 2 시작
# Selected Feature: ['Music', 'Travel', 'Real Estate']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2416, np.int64(2): 2413, np.int64(1): 2413})
# train: 5793, valid: 1449
# Elapsed time on CPU: 0.0h 0.0m 3.614433583803475s
# Epoch 1/20, Loss: 1.0011, Val Accuracy: 50.24%
# New best model found at epoch 1 with accuracy: 50.24%
# Elapsed time on CPU: 0.0h 0.0m 3.961472057271749s
# Epoch 2/20, Loss: 0.9740, Val Accuracy: 51.41%
# New best model found at epoch 2 with accuracy: 51.41%
# Elapsed time on CPU: 0.0h 0.0m 3.8774924343451858s
# Epoch 3/20, Loss: 0.9501, Val Accuracy: 51.62%
# New best model found at epoch 3 with accuracy: 51.62%
# Elapsed time on CPU: 0.0h 0.0m 3.259020004887134s
# Epoch 4/20, Loss: 0.9353, Val Accuracy: 52.52%
# New best model found at epoch 4 with accuracy: 52.52%
# Elapsed time on CPU: 0.0h 0.0m 4.128545382060111s
# Epoch 5/20, Loss: 0.9178, Val Accuracy: 56.38%
# New best model found at epoch 5 with accuracy: 56.38%
# Elapsed time on CPU: 0.0h 0.0m 3.7554399417713284s
# Epoch 6/20, Loss: 0.8522, Val Accuracy: 59.63%
# New best model found at epoch 6 with accuracy: 59.63%
# Elapsed time on CPU: 0.0h 0.0m 3.5864231106825173s
# Epoch 7/20, Loss: 0.8144, Val Accuracy: 58.87%
# Elapsed time on CPU: 0.0h 0.0m 3.725421503186226s
# Epoch 8/20, Loss: 0.7935, Val Accuracy: 61.35%
# New best model found at epoch 8 with accuracy: 61.35%
# Elapsed time on CPU: 0.0h 0.0m 4.084059726912528s
# Epoch 9/20, Loss: 0.7952, Val Accuracy: 60.39%
# Elapsed time on CPU: 0.0h 0.0m 3.6650529950857162s
# Epoch 10/20, Loss: 0.7859, Val Accuracy: 61.15%
# Elapsed time on CPU: 0.0h 0.0m 4.3548306920565665s
# Epoch 11/20, Loss: 0.7651, Val Accuracy: 60.87%
# Elapsed time on CPU: 0.0h 0.0m 3.9541444638743997s
# Epoch 12/20, Loss: 0.7628, Val Accuracy: 60.87%
# Elapsed time on CPU: 0.0h 0.0m 3.8627929631620646s
# Epoch 13/20, Loss: 0.7681, Val Accuracy: 62.39%
# New best model found at epoch 13 with accuracy: 62.39%
# Elapsed time on CPU: 0.0h 0.0m 3.59446702292189s
# Epoch 14/20, Loss: 0.7474, Val Accuracy: 61.97%
# Elapsed time on CPU: 0.0h 0.0m 3.9121471629478037s
# Epoch 15/20, Loss: 0.7486, Val Accuracy: 61.97%
# Elapsed time on CPU: 0.0h 0.0m 3.765008247923106s
# Epoch 16/20, Loss: 0.7252, Val Accuracy: 62.87%
# New best model found at epoch 16 with accuracy: 62.87%
# Elapsed time on CPU: 0.0h 0.0m 3.9500315599143505s
# Epoch 17/20, Loss: 0.7248, Val Accuracy: 62.80%
# Elapsed time on CPU: 0.0h 0.0m 3.974223884753883s
# Epoch 18/20, Loss: 0.7260, Val Accuracy: 62.73%
# Elapsed time on CPU: 0.0h 0.0m 3.8282387228682637s
# Epoch 19/20, Loss: 0.7182, Val Accuracy: 63.56%
# New best model found at epoch 19 with accuracy: 63.56%
# Elapsed time on CPU: 0.0h 0.0m 3.7502322448417544s
# Epoch 20/20, Loss: 0.7134, Val Accuracy: 62.94%
# Total Train time: 0.0h 7.0m 34s
# Elapsed time on CPU: 0.0h 0.0m 4.0476098959334195s
# Test Accuracy: 63.56%
# Train time: 0.0h 7.0m 38s
# Final Validation Accuracy: 63.56%
# ----------------------------------------------------------
# 실험 3 시작
# Selected Feature: ['Books', 'Theater', 'Health']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2412, np.int64(1): 2409, np.int64(2): 2409})
# train: 5784, valid: 1446
# Elapsed time on CPU: 0.0h 0.0m 3.708134362939745s
# Epoch 1/20, Loss: 1.0140, Val Accuracy: 47.99%
# New best model found at epoch 1 with accuracy: 47.99%
# Elapsed time on CPU: 0.0h 0.0m 3.8864811901003122s
# Epoch 2/20, Loss: 1.0001, Val Accuracy: 48.55%
# New best model found at epoch 2 with accuracy: 48.55%
# Elapsed time on CPU: 0.0h 0.0m 3.9243131349794567s
# Epoch 3/20, Loss: 0.9723, Val Accuracy: 50.00%
# New best model found at epoch 3 with accuracy: 50.00%
# Elapsed time on CPU: 0.0h 0.0m 3.4612621162086725s
# Epoch 4/20, Loss: 0.9727, Val Accuracy: 50.41%
# New best model found at epoch 4 with accuracy: 50.41%
# Elapsed time on CPU: 0.0h 0.0m 3.882237059995532s
# Epoch 5/20, Loss: 0.9655, Val Accuracy: 50.76%
# New best model found at epoch 5 with accuracy: 50.76%
# Elapsed time on CPU: 0.0h 0.0m 3.894996739923954s
# Epoch 6/20, Loss: 0.9414, Val Accuracy: 53.32%
# New best model found at epoch 6 with accuracy: 53.32%
# Elapsed time on CPU: 0.0h 0.0m 3.6630788729526103s
# Epoch 7/20, Loss: 0.9358, Val Accuracy: 52.84%
# Elapsed time on CPU: 0.0h 0.0m 3.699625175911933s
# Epoch 8/20, Loss: 0.9318, Val Accuracy: 52.97%
# Elapsed time on CPU: 0.0h 0.0m 3.3204905348829925s
# Epoch 9/20, Loss: 0.9285, Val Accuracy: 53.46%
# New best model found at epoch 9 with accuracy: 53.46%
# Elapsed time on CPU: 0.0h 0.0m 3.9980449699796736s
# Epoch 10/20, Loss: 0.9213, Val Accuracy: 53.53%
# New best model found at epoch 10 with accuracy: 53.53%
# Elapsed time on CPU: 0.0h 0.0m 3.6007249508984387s
# Epoch 11/20, Loss: 0.9096, Val Accuracy: 53.60%
# New best model found at epoch 11 with accuracy: 53.60%
# Elapsed time on CPU: 0.0h 0.0m 3.7296405900269747s
# Epoch 12/20, Loss: 0.9042, Val Accuracy: 55.53%
# New best model found at epoch 12 with accuracy: 55.53%
# Elapsed time on CPU: 0.0h 0.0m 3.8755815089680254s
# Epoch 13/20, Loss: 0.9011, Val Accuracy: 54.50%
# Elapsed time on CPU: 0.0h 0.0m 3.574559629894793s
# Epoch 14/20, Loss: 0.8942, Val Accuracy: 54.84%
# Elapsed time on CPU: 0.0h 0.0m 3.8674396499991417s
# Epoch 15/20, Loss: 0.8892, Val Accuracy: 54.63%
# Elapsed time on CPU: 0.0h 0.0m 4.082605705130845s
# Epoch 16/20, Loss: 0.8787, Val Accuracy: 55.60%
# New best model found at epoch 16 with accuracy: 55.60%
# Elapsed time on CPU: 0.0h 0.0m 3.937509431038052s
# Epoch 17/20, Loss: 0.8758, Val Accuracy: 55.81%
# New best model found at epoch 17 with accuracy: 55.81%
# Elapsed time on CPU: 0.0h 0.0m 3.9430883498862386s
# Epoch 18/20, Loss: 0.8705, Val Accuracy: 57.40%
# New best model found at epoch 18 with accuracy: 57.40%
# Elapsed time on CPU: 0.0h 0.0m 4.017907910048962s
# Epoch 19/20, Loss: 0.8689, Val Accuracy: 57.40%
# Elapsed time on CPU: 0.0h 0.0m 3.897318224888295s
# Epoch 20/20, Loss: 0.8655, Val Accuracy: 58.09%
# New best model found at epoch 20 with accuracy: 58.09%
# Total Train time: 0.0h 7.0m 34s
# Elapsed time on CPU: 0.0h 0.0m 4.2461699531413615s
# Test Accuracy: 58.09%
# Train time: 0.0h 7.0m 39s
# Final Validation Accuracy: 58.09%
# ----------------------------------------------------------
# 실험 4 시작
# Selected Feature: ['Sports', 'Science', 'Food']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(2): 2407, np.int64(1): 2387, np.int64(0): 2385})
# train: 5743, valid: 1436
# Elapsed time on CPU: 0.0h 0.0m 3.6364973350428045s
# Epoch 1/20, Loss: 1.0866, Val Accuracy: 41.23%
# New best model found at epoch 1 with accuracy: 41.23%
# Elapsed time on CPU: 0.0h 0.0m 4.0070897857658565s
# Epoch 2/20, Loss: 1.0698, Val Accuracy: 39.69%
# Elapsed time on CPU: 0.0h 0.0m 4.313535137102008s
# Epoch 3/20, Loss: 1.0582, Val Accuracy: 44.29%
# New best model found at epoch 3 with accuracy: 44.29%
# Elapsed time on CPU: 0.0h 0.0m 4.1297921990044415s
# Epoch 4/20, Loss: 1.0241, Val Accuracy: 46.80%
# New best model found at epoch 4 with accuracy: 46.80%
# Elapsed time on CPU: 0.0h 0.0m 3.9521769150160253s
# Epoch 5/20, Loss: 1.0017, Val Accuracy: 47.35%
# New best model found at epoch 5 with accuracy: 47.35%
# Elapsed time on CPU: 0.0h 0.0m 4.090415899176151s
# Epoch 6/20, Loss: 0.9877, Val Accuracy: 49.09%
# New best model found at epoch 6 with accuracy: 49.09%
# Elapsed time on CPU: 0.0h 0.0m 3.905539487954229s
# Epoch 7/20, Loss: 0.9719, Val Accuracy: 50.21%
# New best model found at epoch 7 with accuracy: 50.21%
# Elapsed time on CPU: 0.0h 0.0m 3.9333540769293904s
# Epoch 8/20, Loss: 0.9616, Val Accuracy: 52.30%
# New best model found at epoch 8 with accuracy: 52.30%
# Elapsed time on CPU: 0.0h 0.0m 4.105339477304369s
# Epoch 9/20, Loss: 0.9510, Val Accuracy: 56.13%
# New best model found at epoch 9 with accuracy: 56.13%
# Elapsed time on CPU: 0.0h 0.0m 3.97107175597921s
# Epoch 10/20, Loss: 0.9335, Val Accuracy: 55.99%
# Elapsed time on CPU: 0.0h 0.0m 4.092798228841275s
# Epoch 11/20, Loss: 0.8989, Val Accuracy: 58.84%
# New best model found at epoch 11 with accuracy: 58.84%
# Elapsed time on CPU: 0.0h 0.0m 3.8497136388905346s
# Epoch 12/20, Loss: 0.8828, Val Accuracy: 58.91%
# New best model found at epoch 12 with accuracy: 58.91%
# Elapsed time on CPU: 0.0h 0.0m 3.8087333450093865s
# Epoch 13/20, Loss: 0.8677, Val Accuracy: 57.52%
# Elapsed time on CPU: 0.0h 0.0m 4.4763911799527705s
# Epoch 14/20, Loss: 0.8581, Val Accuracy: 58.91%
# Elapsed time on CPU: 0.0h 0.0m 3.8651045612059534s
# Epoch 15/20, Loss: 0.8499, Val Accuracy: 58.70%
# Elapsed time on CPU: 0.0h 0.0m 3.8141671111807227s
# Epoch 16/20, Loss: 0.8349, Val Accuracy: 59.47%
# New best model found at epoch 16 with accuracy: 59.47%
# Elapsed time on CPU: 0.0h 0.0m 4.162245701998472s
# Epoch 17/20, Loss: 0.8261, Val Accuracy: 60.10%
# New best model found at epoch 17 with accuracy: 60.10%
# Elapsed time on CPU: 0.0h 0.0m 4.375193280167878s
# Epoch 18/20, Loss: 0.8219, Val Accuracy: 58.70%
# Elapsed time on CPU: 0.0h 0.0m 4.2781686540693045s
# Epoch 19/20, Loss: 0.8178, Val Accuracy: 60.03%
# Elapsed time on CPU: 0.0h 0.0m 4.394518042914569s
# Epoch 20/20, Loss: 0.8134, Val Accuracy: 61.21%
# New best model found at epoch 20 with accuracy: 61.21%
# Total Train time: 0.0h 8.0m 5s
# Elapsed time on CPU: 0.0h 0.0m 4.230539177078754s
# Test Accuracy: 61.21%
# Train time: 0.0h 8.0m 9s
# Final Validation Accuracy: 61.21%
# ----------------------------------------------------------
# 실험 5 시작
# Selected Feature: ['Fashion & Style', 'Movies', 'Technology']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2385, np.int64(1): 2384, np.int64(2): 2376})
# train: 5716, valid: 1429
# Elapsed time on CPU: 0.0h 0.0m 4.504228693898767s
# Epoch 1/20, Loss: 1.1039, Val Accuracy: 39.61%
# New best model found at epoch 1 with accuracy: 39.61%
# Elapsed time on CPU: 0.0h 0.0m 4.592724778223783s
# Epoch 2/20, Loss: 1.0852, Val Accuracy: 40.80%
# New best model found at epoch 2 with accuracy: 40.80%
# Elapsed time on CPU: 0.0h 0.0m 4.708676305599511s
# Epoch 3/20, Loss: 1.0812, Val Accuracy: 39.19%
# Elapsed time on CPU: 0.0h 0.0m 4.5440255659632385s
# Epoch 4/20, Loss: 1.0794, Val Accuracy: 41.22%
# New best model found at epoch 4 with accuracy: 41.22%
# Elapsed time on CPU: 0.0h 0.0m 4.855216034222394s
# Epoch 5/20, Loss: 1.0810, Val Accuracy: 40.87%
# Elapsed time on CPU: 0.0h 0.0m 4.146045452915132s
# Epoch 6/20, Loss: 1.0727, Val Accuracy: 41.71%
# New best model found at epoch 6 with accuracy: 41.71%
# Elapsed time on CPU: 0.0h 0.0m 4.5245252419263124s
# Epoch 7/20, Loss: 1.0699, Val Accuracy: 40.45%
# Elapsed time on CPU: 0.0h 0.0m 4.330302513204515s
# Epoch 8/20, Loss: 1.0655, Val Accuracy: 41.85%
# New best model found at epoch 8 with accuracy: 41.85%
# Elapsed time on CPU: 0.0h 0.0m 4.742118946276605s
# Epoch 9/20, Loss: 1.0700, Val Accuracy: 42.69%
# New best model found at epoch 9 with accuracy: 42.69%
# Elapsed time on CPU: 0.0h 0.0m 4.332094970159233s
# Epoch 10/20, Loss: 1.0561, Val Accuracy: 43.32%
# New best model found at epoch 10 with accuracy: 43.32%
# Elapsed time on CPU: 0.0h 0.0m 4.286528128664941s
# Epoch 11/20, Loss: 1.0499, Val Accuracy: 44.30%
# New best model found at epoch 11 with accuracy: 44.30%
# Elapsed time on CPU: 0.0h 0.0m 3.6767252860590816s
# Epoch 12/20, Loss: 1.0419, Val Accuracy: 44.23%
# Elapsed time on CPU: 0.0h 0.0m 3.4113910952582955s
# Epoch 13/20, Loss: 1.0361, Val Accuracy: 45.42%
# New best model found at epoch 13 with accuracy: 45.42%
# Elapsed time on CPU: 0.0h 0.0m 3.9798817527480423s
# Epoch 14/20, Loss: 1.0263, Val Accuracy: 46.54%
# New best model found at epoch 14 with accuracy: 46.54%
# Elapsed time on CPU: 0.0h 0.0m 3.4822609089314938s
# Epoch 15/20, Loss: 1.0012, Val Accuracy: 53.60%
# New best model found at epoch 15 with accuracy: 53.60%
# Elapsed time on CPU: 0.0h 0.0m 4.055209769867361s
# Epoch 16/20, Loss: 0.8908, Val Accuracy: 57.45%
# New best model found at epoch 16 with accuracy: 57.45%
# Elapsed time on CPU: 0.0h 0.0m 4.215404526796192s
# Epoch 17/20, Loss: 0.8493, Val Accuracy: 59.06%
# New best model found at epoch 17 with accuracy: 59.06%
# Elapsed time on CPU: 0.0h 0.0m 3.8609046386554837s
# Epoch 18/20, Loss: 0.8282, Val Accuracy: 61.16%
# New best model found at epoch 18 with accuracy: 61.16%
# Elapsed time on CPU: 0.0h 0.0m 4.134865242987871s
# Epoch 19/20, Loss: 0.8018, Val Accuracy: 61.16%
# Elapsed time on CPU: 0.0h 0.0m 3.675519447773695s
# Epoch 20/20, Loss: 0.7905, Val Accuracy: 61.44%
# New best model found at epoch 20 with accuracy: 61.44%
# Total Train time: 0.0h 9.0m 5s
# Elapsed time on CPU: 0.0h 0.0m 3.955919000785798s
# Test Accuracy: 61.44%
# Train time: 0.0h 9.0m 9s
# Final Validation Accuracy: 61.44%
# ----------------------------------------------------------
# 실험 6 시작
# Selected Feature: ['Dance', 'Media', 'Style']
# Unique numeric labels: [0 1 2]
# Number of unique numeric labels: 3
# Label distribution (index: count): Counter({np.int64(0): 2365, np.int64(1): 2363, np.int64(2): 2147})
# train: 5500, valid: 1375
# Elapsed time on CPU: 0.0h 0.0m 3.598607026040554s
# Epoch 1/20, Loss: 1.0582, Val Accuracy: 44.07%
# New best model found at epoch 1 with accuracy: 44.07%
# Elapsed time on CPU: 0.0h 0.0m 3.2036200622096658s
# Epoch 2/20, Loss: 1.0232, Val Accuracy: 44.80%
# New best model found at epoch 2 with accuracy: 44.80%
# Elapsed time on CPU: 0.0h 0.0m 3.5601159217767417s
# Epoch 3/20, Loss: 1.0161, Val Accuracy: 49.53%
# New best model found at epoch 3 with accuracy: 49.53%
# Elapsed time on CPU: 0.0h 0.0m 3.9061904191039503s
# Epoch 4/20, Loss: 1.0138, Val Accuracy: 49.60%
# New best model found at epoch 4 with accuracy: 49.60%
# Elapsed time on CPU: 0.0h 0.0m 3.629392003174871s
# Epoch 5/20, Loss: 1.0118, Val Accuracy: 45.16%
# Elapsed time on CPU: 0.0h 0.0m 3.6455851458013058s
# Epoch 6/20, Loss: 0.9981, Val Accuracy: 49.16%
# Elapsed time on CPU: 0.0h 0.0m 3.5030116396956146s
# Epoch 7/20, Loss: 0.9899, Val Accuracy: 50.47%
# New best model found at epoch 7 with accuracy: 50.47%
# Elapsed time on CPU: 0.0h 0.0m 3.8415915998630226s
# Epoch 8/20, Loss: 0.9859, Val Accuracy: 50.62%
# New best model found at epoch 8 with accuracy: 50.62%
# Elapsed time on CPU: 0.0h 0.0m 3.787797706667334s
# Epoch 9/20, Loss: 0.9850, Val Accuracy: 48.36%
# Elapsed time on CPU: 0.0h 0.0m 3.504102081991732s
# Epoch 10/20, Loss: 0.9816, Val Accuracy: 52.15%
# New best model found at epoch 10 with accuracy: 52.15%
# Elapsed time on CPU: 0.0h 0.0m 3.4873176347464323s
# Epoch 11/20, Loss: 0.9676, Val Accuracy: 49.96%
# Elapsed time on CPU: 0.0h 0.0m 3.314284964930266s
# Epoch 12/20, Loss: 0.9597, Val Accuracy: 52.80%
# New best model found at epoch 12 with accuracy: 52.80%
# Elapsed time on CPU: 0.0h 0.0m 3.6774012171663344s
# Epoch 13/20, Loss: 0.9568, Val Accuracy: 52.51%
# Elapsed time on CPU: 0.0h 0.0m 3.4874021927826107s
# Epoch 14/20, Loss: 0.9526, Val Accuracy: 53.45%
# New best model found at epoch 14 with accuracy: 53.45%
# Elapsed time on CPU: 0.0h 0.0m 3.833395990077406s
# Epoch 15/20, Loss: 0.9467, Val Accuracy: 53.24%
# Elapsed time on CPU: 0.0h 0.0m 3.5188424149528146s
# Epoch 16/20, Loss: 0.9320, Val Accuracy: 52.87%
# Elapsed time on CPU: 0.0h 0.0m 3.2818510001525283s
# Epoch 17/20, Loss: 0.9282, Val Accuracy: 53.38%
# Elapsed time on CPU: 0.0h 0.0m 3.822645275387913s
# Epoch 18/20, Loss: 0.9238, Val Accuracy: 53.09%
# Elapsed time on CPU: 0.0h 0.0m 3.640059526078403s
# Epoch 19/20, Loss: 0.9161, Val Accuracy: 53.53%
# New best model found at epoch 19 with accuracy: 53.53%
# Elapsed time on CPU: 0.0h 0.0m 3.3634010814130306s
# Epoch 20/20, Loss: 0.9107, Val Accuracy: 52.22%
# Total Train time: 0.0h 7.0m 9s
# Elapsed time on CPU: 0.0h 0.0m 3.441548943053931s
# Test Accuracy: 53.53%
# Train time: 0.0h 7.0m 12s
# Final Validation Accuracy: 53.53%
# ----------------------------------------------------------

# %%
plot_learning_curve(train_losses, val_accuracies)

# %%
# mx = 0
# for i, acc in enumerate(val_accuracies):
#     if(val_accuracies[mx] < acc):
#         mx = i
# print(f'best trial: {mx+1} epoch, train loss: {train_losses[mx]}, val. acc: {val_accuracies[mx]}')
